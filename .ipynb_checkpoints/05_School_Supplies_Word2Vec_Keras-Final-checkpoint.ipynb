# %% [markdown]
# # Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.preprocessing.sequence import pad_sequences
from keras.utils import np_utils
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from  sklearn.metrics import precision_recall_fscore_support
import gensim
import nltk
from gensim.models.word2vec import Word2Vec
from nltk import word_tokenize
import tensorflow as tf
from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
nltk.download('stopwords')
import re
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# [nltk_data] Error loading stopwords: <urlopen error [Errno 8] nodename
# [nltk_data]     nor servname provided, or not known>

# %%
df = pd.read_csv('cleaned_text_school_supplies.csv')

# %%
df.isnull().sum()
# Out:
# customer_ID        0
# product_ID         0
# rating             0
# review_text        0
# rating_class       0
# date_time          0
# normalized_text    1
# tokens             0
# dtype: int64

# %%
df = df.dropna(axis=0)

# %%
# Converting categorical to numerical 
df['rating_class'] = df['rating_class'].replace({'good': 1,'neutral': 0,'bad':0 })

# %%
# Splitting the Data Set into Train and Test Sets
X = df['normalized_text']
y = df['rating_class']

# %%
df['normalized_text'][:4]
# Out:
# 0    honestly believe give merchant one star favor ...
# 1    standard size folder fit standard paper 5x11 f...
# 2    kid love get green ticket take home show paren...
# 3    nice product look quick happy note keep next d...
# Name: normalized_text, dtype: object

# %%
df.shape
# Out:
# (10835, 8)

# %%
df_train = df[:8000]
df_test = df[8000:]

# %%
df_train.shape
# Out:
# (8000, 8)

# %%
df_test.shape
# Out:
# (2835, 8)

# %% [markdown]
# # Tokenizer

# %%
from keras.preprocessing.text import Tokenizer

samples = X

# %%
tokenizer = Tokenizer(lower=True, split=' ') # creates tokenizer

# %%
tokenizer.fit_on_texts(samples)  # builds the word index

# %%
sequences = tokenizer.texts_to_sequences(samples) #turns strings into list of integers

# %%
len(sequences)
# Out:
# 10835

# %%
# word_index is a dictionary mapping words to an integer index
word_index = tokenizer.word_index

# %%
type(samples)
# Out:
# pandas.core.series.Series

# %%
samples
# Out:
# 0        honestly believe give merchant one star favor ...
# 1        standard size folder fit standard paper 5x11 f...
# 2        kid love get green ticket take home show paren...
# 3        nice product look quick happy note keep next d...
# 4        love get give prize later motivate student cut...
# 5        use coupon end cycle student receive hw comple...
# 6        like look paper see online upon receive surpri...
# 7        perfect calendar particular year graphic brill...
# 8        can not wait arrive picture look fantastic fun...
# 9        artwork great creative piece cubicle wall purc...
# 10       cool calendar order several give gift idea art...
# 11       seeen calendar person rock put santa list grap...
# 12       whoever create serious niche not sure come pho...
# 13       receive calendar quickly love graphic look for...
# 14       beautiful calendar give lovely man kentucky li...
# 15       well worth money fantastic large photo nice pa...
# 16       room call red room dedicate secretariat calend...
# 17       secretariat favorite athelete time picture bea...
# 18       know tony leonard see many famous portrait equ...
# 19       not buy calendar buy source horse pimcture alw...
# 20       nice look wallet love crocodile emboss leather...
# 21       galison mudpuppy file recently buy cute sturdy...
# 22       work well us year new homeschool look curricul...
# 23       purchase first time homeschoole awful incredib...
# 24       use sos homeschooling year version horrible ma...
# 25       easy install easy child access subject lean ma...
# 26       good solid homeschool program take time set in...
# 27       spanish great super fun game little quiz help ...
# 28                                student love lessongreat
# 29       book good condition first book no cd no use wi...
#                                ...
# 10806    hallmark valentine come across sound much high...
# 10807    son love seller honorable good go valentine da...
# 10808    buy one staple fraction price still waste mone...
# 10809    would give zero star possible size need son lo...
# 10810    bra always fall zipper unzipped washing materi...
# 10811    use kitchen counter keep food dog reach five star
# 10812    beautiful arrive promptly well wrap would look...
# 10813    pretty get realize use side hole run ribbon th...
# 10814    cool mouse know ordering take exceedingly lonn...
# 10815    paper work fine however canon s2 stop working ...
# 10816    case good size without massive get new sunglas...
# 10817    adorable little crab stamp work well definitel...
# 10818    not heavy expect subsequently not stop door tw...
# 10819    use twice hat stay shaper clean design seem li...
# 10820    good deal timelyshippe sure cheap dry cleaner ...
# 10821    ok first time wash hat come undo give second t...
# 10822    pleased impression hot wax daisy / wax seal st...
# 10823    nice one place wish hold may order another one...
# 10824    pretty enough fabric almost transparent thin c...
# 10825    open today meet expectation perfectly look lik...
# 10826    tank top similar expensive brand usual buy qua...
# 10827                          cute great baggie four star
# 10828    use product client treatment session great suc...
# 10829    love thing teacher parent child adhd child mov...
# 10830    simple solution second grade nephew trouble si...
# 10831    young son really struggle kindergarten adhd us...
# 10832    like appreciate bouncy band classroom really h...
# 10833                                    homeshooler dream
# 10834    schedule awesome quality highest completely fl...
# 10835    schedule awesome quality highest completely fl...
# Name: normalized_text, Length: 10835, dtype: object

# %%
word_index
# Out:
# {'not': 1,
#  'use': 2,
#  'great': 3,
#  'work': 4,
#  'one': 5,
#  'good': 6,
#  'product': 7,
#  'get': 8,
#  'would': 9,
#  'buy': 10,
#  'like': 11,
#  'well': 12,
#  'make': 13,
#  'paper': 14,
#  'love': 15,
#  'look': 16,
#  'need': 17,
#  'pen': 18,
#  'price': 19,
#  'time': 20,
#  'quality': 21,
#  'no': 22,
#  'nice': 23,
#  'easy': 24,
#  'find': 25,
#  'really': 26,
#  'go': 27,
#  'come': 28,
#  'little': 29,
#  'order': 30,
#  'also': 31,
#  'purchase': 32,
#  'much': 33,
#  'color': 34,
#  'year': 35,
#  'perfect': 36,
#  'want': 37,
#  'item': 38,
#  'hold': 39,
#  'small': 40,
#  'thing': 41,
#  'keep': 42,
#  'cable': 43,
#  'could': 44,
#  'recommend': 45,
#  'even': 46,
#  'take': 47,
#  'think': 48,
#  'label': 49,
#  'see': 50,
#  'size': 51,
#  'back': 52,
#  'write': 53,
#  'fit': 54,
#  'card': 55,
#  'say': 56,
#  'cover': 57,
#  'put': 58,
#  'way': 59,
#  'two': 60,
#  'give': 61,
#  'binder': 62,
#  'day': 63,
#  'lot': 64,
#  'calendar': 65,
#  'ink': 66,
#  'try': 67,
#  'set': 68,
#  'box': 69,
#  'print': 70,
#  'plastic': 71,
#  'enough': 72,
#  'table': 73,
#  'many': 74,
#  'book': 75,
#  'cord': 76,
#  'still': 77,
#  'first': 78,
#  'problem': 79,
#  'gift': 80,
#  'money': 81,
#  'expect': 82,
#  'know': 83,
#  'pocket': 84,
#  'picture': 85,
#  'large': 86,
#  'seem': 87,
#  'cheap': 88,
#  'store': 89,
#  'board': 90,
#  'around': 91,
#  'amazon': 92,
#  'fine': 93,
#  'right': 94,
#  'long': 95,
#  'big': 96,
#  'old': 97,
#  'last': 98,
#  'can': 99,
#  'something': 100,
#  'bag': 101,
#  'case': 102,
#  'place': 103,
#  'another': 104,
#  'easily': 105,
#  'new': 106,
#  'page': 107,
#  'may': 108,
#  'every': 109,
#  'receive': 110,
#  'sturdy': 111,
#  'printer': 112,
#  'pretty': 113,
#  'tie': 114,
#  'design': 115,
#  'feel': 116,
#  'star': 117,
#  'excellent': 118,
#  'happy': 119,
#  'arrive': 120,
#  'hard': 121,
#  'since': 122,
#  'different': 123,
#  'without': 124,
#  'review': 125,
#  'bit': 126,
#  'school': 127,
#  'high': 128,
#  'side': 129,
#  'office': 130,
#  'exactly': 131,
#  'never': 132,
#  'worth': 133,
#  'piece': 134,
#  'break': 135,
#  'desk': 136,
#  'open': 137,
#  'help': 138,
#  'sure': 139,
#  'however': 140,
#  'month': 141,
#  'note': 142,
#  'top': 143,
#  'though': 144,
#  'black': 145,
#  'job': 146,
#  'line': 147,
#  'carry': 148,
#  'clean': 149,
#  'phone': 150,
#  'stick': 151,
#  'kid': 152,
#  'ring': 153,
#  'end': 154,
#  'pay': 155,
#  'light': 156,
#  'hand': 157,
#  'far': 158,
#  'tape': 159,
#  'shipping': 160,
#  'always': 161,
#  'read': 162,
#  'leave': 163,
#  'erase': 164,
#  'cartridge': 165,
#  'stuff': 166,
#  'package': 167,
#  'add': 168,
#  'notebook': 169,
#  'sheet': 170,
#  'home': 171,
#  'beautiful': 172,
#  'hole': 173,
#  'dry': 174,
#  'everything': 175,
#  'room': 176,
#  'fun': 177,
#  'less': 178,
#  'pack': 179,
#  'heavy': 180,
#  'several': 181,
#  'computer': 182,
#  'able': 183,
#  'perfectly': 184,
#  'together': 185,
#  'people': 186,
#  'bad': 187,
#  'etc': 188,
#  'weight': 189,
#  'eraser': 190,
#  'ever': 191,
#  'space': 192,
#  'cut': 193,
#  'wrap': 194,
#  'brand': 195,
#  'better': 196,
#  'wall': 197,
#  'part': 198,
#  'highly': 199,
#  'inside': 200,
#  'awesome': 201,
#  'cost': 202,
#  'organize': 203,
#  'actually': 204,
#  'send': 205,
#  'company': 206,
#  'quite': 207,
#  'three': 208,
#  'thank': 209,
#  'show': 210,
#  'start': 211,
#  'do': 212,
#  'marker': 213,
#  'week': 214,
#  'velcro': 215,
#  'anything': 216,
#  'daughter': 217,
#  'run': 218,
#  'definitely': 219,
#  'wish': 220,
#  'return': 221,
#  'pencil': 222,
#  'stand': 223,
#  'wire': 224,
#  'waste': 225,
#  'include': 226,
#  'white': 227,
#  'thin': 228,
#  'away': 229,
#  'ship': 230,
#  'fall': 231,
#  'expensive': 232,
#  'scale': 233,
#  'fast': 234,
#  'son': 235,
#  'material': 236,
#  'service': 237,
#  'project': 238,
#  'photo': 239,
#  'stay': 240,
#  'seller': 241,
#  'extra': 242,
#  'deal': 243,
#  'refill': 244,
#  'letter': 245,
#  'simple': 246,
#  'issue': 247,
#  'point': 248,
#  'inch': 249,
#  'business': 250,
#  'idea': 251,
#  'cute': 252,
#  'pad': 253,
#  'friend': 254,
#  'low': 255,
#  'handy': 256,
#  'strong': 257,
#  'probably': 258,
#  'holder': 259,
#  'tell': 260,
#  'handle': 261,
#  'type': 262,
#  'useful': 263,
#  'anyone': 264,
#  'overall': 265,
#  'easel': 266,
#  'value': 267,
#  'student': 268,
#  'remove': 269,
#  'quickly': 270,
#  'move': 271,
#  'kind': 272,
#  'height': 273,
#  'child': 274,
#  'clear': 275,
#  'almost': 276,
#  'check': 277,
#  'number': 278,
#  'purpose': 279,
#  'tool': 280,
#  'roll': 281,
#  'hope': 282,
#  'durable': 283,
#  'yet': 284,
#  'thick': 285,
#  'wonderful': 286,
#  'close': 287,
#  'must': 288,
#  'clip': 289,
#  'machine': 290,
#  'allow': 291,
#  'replace': 292,
#  'unit': 293,
#  'second': 294,
#  'nothing': 295,
#  'front': 296,
#  'couple': 297,
#  'hang': 298,
#  'play': 299,
#  'half': 300,
#  'chair': 301,
#  'turn': 302,
#  'instead': 303,
#  'battery': 304,
#  'bottom': 305,
#  'pull': 306,
#  'folder': 307,
#  'damage': 308,
#  'ok': 309,
#  'next': 310,
#  'customer': 311,
#  'real': 312,
#  'pleased': 313,
#  'bible': 314,
#  'feature': 315,
#  'change': 316,
#  'file': 317,
#  'full': 318,
#  'let': 319,
#  'attach': 320,
#  'metal': 321,
#  'else': 322,
#  'cool': 323,
#  'house': 324,
#  'standard': 325,
#  'save': 326,
#  'punch': 327,
#  'us': 328,
#  'fact': 329,
#  'call': 330,
#  'other': 331,
#  'mine': 332,
#  'leather': 333,
#  'chart': 334,
#  'mean': 335,
#  'surface': 336,
#  'zipper': 337,
#  'fold': 338,
#  'coffee': 339,
#  'spend': 340,
#  'sell': 341,
#  'christmas': 342,
#  'describe': 343,
#  'super': 344,
#  'smooth': 345,
#  'sticker': 346,
#  'wrong': 347,
#  'blue': 348,
#  'plus': 349,
#  'especially': 350,
#  'class': 351,
#  'description': 352,
#  'lose': 353,
#  'regular': 354,
#  'difficult': 355,
#  'enjoy': 356,
#  'tag': 357,
#  'already': 358,
#  'learn': 359,
#  'least': 360,
#  'ago': 361,
#  'tip': 362,
#  'sit': 363,
#  'name': 364,
#  'system': 365,
#  'complaint': 366,
#  'display': 367,
#  'strap': 368,
#  'five': 369,
#  'art': 370,
#  'wallet': 371,
#  'build': 372,
#  'nicely': 373,
#  'reason': 374,
#  'solid': 375,
#  'fan': 376,
#  'free': 377,
#  'wear': 378,
#  'power': 379,
#  'leg': 380,
#  'word': 381,
#  'model': 382,
#  'maybe': 383,
#  'supply': 384,
#  'apart': 385,
#  'ask': 386,
#  'storage': 387,
#  'red': 388,
#  'provide': 389,
#  'someone': 390,
#  'advertise': 391,
#  'decide': 392,
#  'replacement': 393,
#  'x': 394,
#  'key': 395,
#  'life': 396,
#  'software': 397,
#  'completely': 398,
#  'minute': 399,
#  'chalk': 400,
#  'amount': 401,
#  'husband': 402,
#  'envelope': 403,
#  'tv': 404,
#  'favorite': 405,
#  'flat': 406,
#  'craft': 407,
#  'create': 408,
#  'frame': 409,
#  'quick': 410,
#  'writing': 411,
#  'require': 412,
#  'absolutely': 413,
#  'condition': 414,
#  'glad': 415,
#  'poster': 416,
#  'water': 417,
#  'seal': 418,
#  'packaging': 419,
#  'available': 420,
#  'air': 421,
#  'wait': 422,
#  'slide': 423,
#  'longer': 424,
#  'rather': 425,
#  'short': 426,
#  'list': 427,
#  'protect': 428,
#  'teacher': 429,
#  'although': 430,
#  'stock': 431,
#  'paint': 432,
#  'amazing': 433,
#  'either': 434,
#  'loose': 435,
#  'finally': 436,
#  'hour': 437,
#  'laptop': 438,
#  'soft': 439,
#  'car': 440,
#  'whole': 441,
#  'online': 442,
#  'four': 443,
#  'foot': 444,
#  'flimsy': 445,
#  'everyone': 446,
#  'touch': 447,
#  'glue': 448,
#  'cube': 449,
#  'bright': 450,
#  'family': 451,
#  'stamp': 452,
#  'extremely': 453,
#  'plan': 454,
#  'professional': 455,
#  'draw': 456,
#  'version': 457,
#  'area': 458,
#  'guess': 459,
#  'often': 460,
#  'device': 461,
#  'mount': 462,
#  'tear': 463,
#  'bottle': 464,
#  'adjust': 465,
#  'poor': 466,
#  'smell': 467,
#  'glitter': 468,
#  'disappointed': 469,
#  'fantastic': 470,
#  'shape': 471,
#  'delivery': 472,
#  'throw': 473,
#  'person': 474,
#  'travel': 475,
#  'behind': 476,
#  'contact': 477,
#  'bring': 478,
#  'copy': 479,
#  'finish': 480,
#  'screw': 481,
#  'fill': 482,
#  'style': 483,
#  'classroom': 484,
#  'local': 485,
#  'insert': 486,
#  'within': 487,
#  'edge': 488,
#  'secure': 489,
#  'tray': 490,
#  'pick': 491,
#  'brother': 492,
#  'journal': 493,
#  'option': 494,
#  'charge': 495,
#  'zip': 496,
#  'snap': 497,
#  'adjustable': 498,
#  'instruction': 499,
#  'believe': 500,
#  'please': 501,
#  'laminate': 502,
#  'game': 503,
#  'birthday': 504,
#  'simply': 505,
#  'along': 506,
#  'usually': 507,
#  'sometimes': 508,
#  'original': 509,
#  'purse': 510,
#  'base': 511,
#  'become': 512,
#  'match': 513,
#  'strip': 514,
#  'button': 515,
#  'huge': 516,
#  'best': 517,
#  'rubber': 518,
#  'chalkboard': 519,
#  'date': 520,
#  'flip': 521,
#  'offer': 522,
#  'tab': 523,
#  'suppose': 524,
#  'fix': 525,
#  'flexible': 526,
#  'slightly': 527,
#  'adhesive': 528,
#  'coin': 529,
#  'choose': 530,
#  'i': 531,
#  'comfortable': 532,
#  'daily': 533,
#  'staple': 534,
#  'mark': 535,
#  'kit': 536,
#  'length': 537,
#  'figure': 538,
#  'stop': 539,
#  'toy': 540,
#  'organizer': 541,
#  'grip': 542,
#  'anyway': 543,
#  'wax': 544,
#  'live': 545,
#  'mess': 546,
#  'drop': 547,
#  'addition': 548,
#  'outside': 549,
#  'compare': 550,
#  'rip': 551,
#  'laser': 552,
#  'wipe': 553,
#  'soon': 554,
#  'taste': 555,
#  'slip': 556,
#  'result': 557,
#  'duty': 558,
#  'appear': 559,
#  'experience': 560,
#  'decent': 561,
#  'install': 562,
#  'planner': 563,
#  'thought': 564,
#  'wood': 565,
#  'past': 566,
#  'fabric': 567,
#  'miss': 568,
#  'convenient': 569,
#  'image': 570,
#  'disappoint': 571,
#  'fountain': 572,
#  'slot': 573,
#  'drawer': 574,
#  'helpful': 575,
#  'satisfied': 576,
#  'choice': 577,
#  'neat': 578,
#  'loop': 579,
#  'blade': 580,
#  'due': 581,
#  'mail': 582,
#  'serve': 583,
#  'kitchen': 584,
#  'screen': 585,
#  'functional': 586,
#  'tight': 587,
#  'door': 588,
#  'green': 589,
#  'correct': 590,
#  'dollar': 591,
#  'wife': 592,
#  'mouse': 593,
#  'later': 594,
#  'deliver': 595,
#  'mini': 596,
#  'sticky': 597,
#  'similar': 598,
#  'non': 599,
#  'hook': 600,
#  'information': 601,
#  'lead': 602,
#  'center': 603,
#  'plug': 604,
#  'future': 605,
#  'consider': 606,
#  'otherwise': 607,
#  'glass': 608,
#  'support': 609,
#  'cause': 610,
#  'solution': 611,
#  'care': 612,
#  'email': 613,
#  'state': 614,
#  'remember': 615,
#  'wet': 616,
#  'bundle': 617,
#  'beat': 618,
#  'dark': 619,
#  'sort': 620,
#  'shelf': 621,
#  'pink': 622,
#  'scratch': 623,
#  'program': 624,
#  'finger': 625,
#  'okay': 626,
#  'middle': 627,
#  'mention': 628,
#  'true': 629,
#  'pouch': 630,
#  'address': 631,
#  'sound': 632,
#  'course': 633,
#  'variety': 634,
#  'inexpensive': 635,
#  'yes': 636,
#  'single': 637,
#  'hp': 638,
#  'luggage': 639,
#  'college': 640,
#  'spray': 641,
#  'lightweight': 642,
#  'post': 643,
#  'plenty': 644,
#  'multiple': 645,
#  'lock': 646,
#  'cap': 647,
#  'divider': 648,
#  'happen': 649,
#  'document': 650,
#  'reasonable': 651,
#  'onto': 652,
#  'unless': 653,
#  'per': 654,
#  'present': 655,
#  'pop': 656,
#  'shop': 657,
#  'sized': 658,
#  'usb': 659,
#  'cd': 660,
#  'whatever': 661,
#  'face': 662,
#  'double': 663,
#  'printing': 664,
#  'worry': 665,
#  'corner': 666,
#  'immediately': 667,
#  'special': 668,
#  'step': 669,
#  'pro': 670,
#  'record': 671,
#  'search': 672,
#  'unfortunately': 673,
#  'sleeve': 674,
#  'terrible': 675,
#  'floor': 676,
#  'bill': 677,
#  'tiny': 678,
#  'refund': 679,
#  'anywhere': 680,
#  'cup': 681,
#  'crack': 682,
#  'matter': 683,
#  'complete': 684,
#  'epson': 685,
#  'process': 686,
#  'notice': 687,
#  'girl': 688,
#  'guy': 689,
#  'track': 690,
#  'careful': 691,
#  'rate': 692,
#  'pc': 693,
#  'realize': 694,
#  'across': 695,
#  'band': 696,
#  'research': 697,
#  'steel': 698,
#  'whiteboard': 699,
#  'important': 700,
#  'drive': 701,
#  'apply': 702,
#  'ball': 703,
#  'credit': 704,
#  'certainly': 705,
#  'level': 706,
#  'separate': 707,
#  'laminator': 708,
#  'cat': 709,
#  'roller': 710,
#  'push': 711,
#  'cart': 712,
#  'test': 713,
#  'bind': 714,
#  'fairly': 715,
#  'rest': 716,
#  'wide': 717,
#  'function': 718,
#  'plate': 719,
#  'notebinder': 720,
#  'surprise': 721,
#  'grade': 722,
#  'manufacturer': 723,
#  'various': 724,
#  'instal': 725,
#  'eye': 726,
#  'medium': 727,
#  'head': 728,
#  'section': 729,
#  'today': 730,
#  'sign': 731,
#  'calculator': 732,
#  'hot': 733,
#  'mm': 734,
#  'mind': 735,
#  'properly': 736,
#  'entire': 737,
#  'assemble': 738,
#  'maker': 739,
#  'collection': 740,
#  'comment': 741,
#  'form': 742,
#  'totally': 743,
#  'total': 744,
#  'prefer': 745,
#  'mood': 746,
#  'control': 747,
#  'answer': 748,
#  'follow': 749,
#  'cloth': 750,
#  'tower': 751,
#  'backpack': 752,
#  'reviewer': 753,
#  'magnet': 754,
#  'heat': 755,
#  'cardboard': 756,
#  'attractive': 757,
#  'counter': 758,
#  'stainless': 759,
#  'intend': 760,
#  'magnetic': 761,
#  'window': 762,
#  'bunch': 763,
#  'ipod': 764,
#  'difference': 765,
#  'detail': 766,
#  'world': 767,
#  'expectation': 768,
#  'tend': 769,
#  'party': 770,
#  'bend': 771,
#  'electronic': 772,
#  'trouble': 773,
#  'actual': 774,
#  'basic': 775,
#  'personal': 776,
#  'self': 777,
#  'trip': 778,
#  'construction': 779,
#  'keyboard': 780,
#  'ton': 781,
#  'unique': 782,
#  'suggest': 783,
#  'container': 784,
#  'flow': 785,
#  'creamer': 786,
#  'continue': 787,
#  'pattern': 788,
#  'ready': 789,
#  'charger': 790,
#  'dust': 791,
#  'recently': 792,
#  'user': 793,
#  'unlike': 794,
#  'film': 795,
#  'contain': 796,
#  'hate': 797,
#  'weigh': 798,
#  'map': 799,
#  'meet': 800,
#  'spot': 801,
#  'flower': 802,
#  'mead': 803,
#  'sew': 804,
#  'age': 805,
#  'horrible': 806,
#  'site': 807,
#  'measure': 808,
#  'iron': 809,
#  'gold': 810,
#  'count': 811,
#  'switch': 812,
#  'shine': 813,
#  'negative': 814,
#  'buying': 815,
#  'pass': 816,
#  'wedding': 817,
#  'imagine': 818,
#  'bubble': 819,
#  'sharp': 820,
#  'bulky': 821,
#  'website': 822,
#  'hear': 823,
#  'trash': 824,
#  'e': 825,
#  'everyday': 826,
#  'useless': 827,
#  'press': 828,
#  'chore': 829,
#  'nearly': 830,
#  'jack': 831,
#  'peel': 832,
#  'sale': 833,
#  'everywhere': 834,
#  'cross': 835,
#  'bleed': 836,
#  'yellow': 837,
#  'smoothly': 838,
#  'transparency': 839,
#  'leak': 840,
#  'brush': 841,
#  'odor': 842,
#  'canon': 843,
#  'junk': 844,
#  'compartment': 845,
#  'anymore': 846,
#  'young': 847,
#  'forward': 848,
#  'lovely': 849,
#  'fail': 850,
#  'begin': 851,
#  'night': 852,
#  'jam': 853,
#  'con': 854,
#  'artist': 855,
#  'accurate': 856,
#  'stable': 857,
#  'chance': 858,
#  'breadboard': 859,
#  'code': 860,
#  'man': 861,
#  'presentation': 862,
#  'solve': 863,
#  'straight': 864,
#  'purple': 865,
#  'talk': 866,
#  'hit': 867,
#  'compact': 868,
#  'timely': 869,
#  'practice': 870,
#  'meeting': 871,
#  'update': 872,
#  'possible': 873,
#  'effort': 874,
#  'application': 875,
#  'except': 876,
#  'vendor': 877,
#  'wash': 878,
#  'exact': 879,
#  'portable': 880,
#  'grommet': 881,
#  'mom': 882,
#  'market': 883,
#  'complain': 884,
#  'twice': 885,
#  'boy': 886,
#  'main': 887,
#  'colorful': 888,
#  'practical': 889,
#  'tall': 890,
#  'event': 891,
#  'ease': 892,
#  'organization': 893,
#  'arm': 894,
#  'putty': 895,
#  'smoke': 896,
#  'sarah': 897,
#  'previous': 898,
#  'bargain': 899,
#  'plain': 900,
#  'connect': 901,
#  'wonder': 902,
#  'drawing': 903,
#  'surprised': 904,
#  'trick': 905,
#  'warm': 906,
#  'perhaps': 907,
#  'stuck': 908,
#  'lid': 909,
#  'truly': 910,
#  'normal': 911,
#  'safe': 912,
#  'palin': 913,
#  'woman': 914,
#  'promise': 915,
#  'additional': 916,
#  'nee': 917,
#  'colored': 918,
#  'seat': 919,
#  'buck': 920,
#  'bar': 921,
#  'buddy': 922,
#  'alone': 923,
#  'dimension': 924,
#  'hardware': 925,
#  'own': 926,
#  'watch': 927,
#  'understand': 928,
#  'avoid': 929,
#  'load': 930,
#  'garbage': 931,
#  'six': 932,
#  'none': 933,
#  'music': 934,
#  'mostly': 935,
#  'protector': 936,
#  'stapler': 937,
#  'stationery': 938,
#  'gray': 939,
#  'labeler': 940,
#  'question': 941,
#  'holiday': 942,
#  'reusable': 943,
#  'beautifully': 944,
#  'bent': 945,
#  'impressed': 946,
#  'oh': 947,
#  'effective': 948,
#  'fault': 949,
#  'mat': 950,
#  'manner': 951,
#  'catch': 952,
#  'prevent': 953,
#  'compliment': 954,
#  'tote': 955,
#  'coupon': 956,
#  'hair': 957,
#  'spiral': 958,
#  'pound': 959,
#  'text': 960,
#  'lie': 961,
#  'alternative': 962,
#  'smear': 963,
#  'cell': 964,
#  'forever': 965,
#  'sand': 966,
#  'manual': 967,
#  'repair': 968,
#  'equipment': 969,
#  'silver': 970,
#  'invitation': 971,
#  'tracfone': 972,
#  'be': 973,
#  'beware': 974,
#  'glossy': 975,
#  'hide': 976,
#  'impossible': 977,
#  'tough': 978,
#  'clearly': 979,
#  'cabinet': 980,
#  'flap': 981,
#  'dog': 982,
#  'particular': 983,
#  'friendly': 984,
#  'third': 985,
#  'template': 986,
#  'versatile': 987,
#  'produce': 988,
#  'remain': 989,
#  'dvd': 990,
#  'basically': 991,
#  'poorly': 992,
#  'perform': 993,
#  'funny': 994,
#  'pressure': 995,
#  'management': 996,
#  'pre': 997,
#  'ticket': 998,
#  'teach': 999,
#  'church': 1000,
#  ...}

# %%
print(f'Found {len(word_index)} unique tokens. ')
# Out:
# Found 16456 unique tokens.

# %%
max([max(sequence) for sequence in sequences])
# Out:
# 16456

# %%
# We reverse it, mapping integer indices to words
reverse_word_index = dict((value, key) for (key, value) in word_index.items())

# %%
reverse_word_index
# Out:
# {1: 'not',
#  2: 'use',
#  3: 'great',
#  4: 'work',
#  5: 'one',
#  6: 'good',
#  7: 'product',
#  8: 'get',
#  9: 'would',
#  10: 'buy',
#  11: 'like',
#  12: 'well',
#  13: 'make',
#  14: 'paper',
#  15: 'love',
#  16: 'look',
#  17: 'need',
#  18: 'pen',
#  19: 'price',
#  20: 'time',
#  21: 'quality',
#  22: 'no',
#  23: 'nice',
#  24: 'easy',
#  25: 'find',
#  26: 'really',
#  27: 'go',
#  28: 'come',
#  29: 'little',
#  30: 'order',
#  31: 'also',
#  32: 'purchase',
#  33: 'much',
#  34: 'color',
#  35: 'year',
#  36: 'perfect',
#  37: 'want',
#  38: 'item',
#  39: 'hold',
#  40: 'small',
#  41: 'thing',
#  42: 'keep',
#  43: 'cable',
#  44: 'could',
#  45: 'recommend',
#  46: 'even',
#  47: 'take',
#  48: 'think',
#  49: 'label',
#  50: 'see',
#  51: 'size',
#  52: 'back',
#  53: 'write',
#  54: 'fit',
#  55: 'card',
#  56: 'say',
#  57: 'cover',
#  58: 'put',
#  59: 'way',
#  60: 'two',
#  61: 'give',
#  62: 'binder',
#  63: 'day',
#  64: 'lot',
#  65: 'calendar',
#  66: 'ink',
#  67: 'try',
#  68: 'set',
#  69: 'box',
#  70: 'print',
#  71: 'plastic',
#  72: 'enough',
#  73: 'table',
#  74: 'many',
#  75: 'book',
#  76: 'cord',
#  77: 'still',
#  78: 'first',
#  79: 'problem',
#  80: 'gift',
#  81: 'money',
#  82: 'expect',
#  83: 'know',
#  84: 'pocket',
#  85: 'picture',
#  86: 'large',
#  87: 'seem',
#  88: 'cheap',
#  89: 'store',
#  90: 'board',
#  91: 'around',
#  92: 'amazon',
#  93: 'fine',
#  94: 'right',
#  95: 'long',
#  96: 'big',
#  97: 'old',
#  98: 'last',
#  99: 'can',
#  100: 'something',
#  101: 'bag',
#  102: 'case',
#  103: 'place',
#  104: 'another',
#  105: 'easily',
#  106: 'new',
#  107: 'page',
#  108: 'may',
#  109: 'every',
#  110: 'receive',
#  111: 'sturdy',
#  112: 'printer',
#  113: 'pretty',
#  114: 'tie',
#  115: 'design',
#  116: 'feel',
#  117: 'star',
#  118: 'excellent',
#  119: 'happy',
#  120: 'arrive',
#  121: 'hard',
#  122: 'since',
#  123: 'different',
#  124: 'without',
#  125: 'review',
#  126: 'bit',
#  127: 'school',
#  128: 'high',
#  129: 'side',
#  130: 'office',
#  131: 'exactly',
#  132: 'never',
#  133: 'worth',
#  134: 'piece',
#  135: 'break',
#  136: 'desk',
#  137: 'open',
#  138: 'help',
#  139: 'sure',
#  140: 'however',
#  141: 'month',
#  142: 'note',
#  143: 'top',
#  144: 'though',
#  145: 'black',
#  146: 'job',
#  147: 'line',
#  148: 'carry',
#  149: 'clean',
#  150: 'phone',
#  151: 'stick',
#  152: 'kid',
#  153: 'ring',
#  154: 'end',
#  155: 'pay',
#  156: 'light',
#  157: 'hand',
#  158: 'far',
#  159: 'tape',
#  160: 'shipping',
#  161: 'always',
#  162: 'read',
#  163: 'leave',
#  164: 'erase',
#  165: 'cartridge',
#  166: 'stuff',
#  167: 'package',
#  168: 'add',
#  169: 'notebook',
#  170: 'sheet',
#  171: 'home',
#  172: 'beautiful',
#  173: 'hole',
#  174: 'dry',
#  175: 'everything',
#  176: 'room',
#  177: 'fun',
#  178: 'less',
#  179: 'pack',
#  180: 'heavy',
#  181: 'several',
#  182: 'computer',
#  183: 'able',
#  184: 'perfectly',
#  185: 'together',
#  186: 'people',
#  187: 'bad',
#  188: 'etc',
#  189: 'weight',
#  190: 'eraser',
#  191: 'ever',
#  192: 'space',
#  193: 'cut',
#  194: 'wrap',
#  195: 'brand',
#  196: 'better',
#  197: 'wall',
#  198: 'part',
#  199: 'highly',
#  200: 'inside',
#  201: 'awesome',
#  202: 'cost',
#  203: 'organize',
#  204: 'actually',
#  205: 'send',
#  206: 'company',
#  207: 'quite',
#  208: 'three',
#  209: 'thank',
#  210: 'show',
#  211: 'start',
#  212: 'do',
#  213: 'marker',
#  214: 'week',
#  215: 'velcro',
#  216: 'anything',
#  217: 'daughter',
#  218: 'run',
#  219: 'definitely',
#  220: 'wish',
#  221: 'return',
#  222: 'pencil',
#  223: 'stand',
#  224: 'wire',
#  225: 'waste',
#  226: 'include',
#  227: 'white',
#  228: 'thin',
#  229: 'away',
#  230: 'ship',
#  231: 'fall',
#  232: 'expensive',
#  233: 'scale',
#  234: 'fast',
#  235: 'son',
#  236: 'material',
#  237: 'service',
#  238: 'project',
#  239: 'photo',
#  240: 'stay',
#  241: 'seller',
#  242: 'extra',
#  243: 'deal',
#  244: 'refill',
#  245: 'letter',
#  246: 'simple',
#  247: 'issue',
#  248: 'point',
#  249: 'inch',
#  250: 'business',
#  251: 'idea',
#  252: 'cute',
#  253: 'pad',
#  254: 'friend',
#  255: 'low',
#  256: 'handy',
#  257: 'strong',
#  258: 'probably',
#  259: 'holder',
#  260: 'tell',
#  261: 'handle',
#  262: 'type',
#  263: 'useful',
#  264: 'anyone',
#  265: 'overall',
#  266: 'easel',
#  267: 'value',
#  268: 'student',
#  269: 'remove',
#  270: 'quickly',
#  271: 'move',
#  272: 'kind',
#  273: 'height',
#  274: 'child',
#  275: 'clear',
#  276: 'almost',
#  277: 'check',
#  278: 'number',
#  279: 'purpose',
#  280: 'tool',
#  281: 'roll',
#  282: 'hope',
#  283: 'durable',
#  284: 'yet',
#  285: 'thick',
#  286: 'wonderful',
#  287: 'close',
#  288: 'must',
#  289: 'clip',
#  290: 'machine',
#  291: 'allow',
#  292: 'replace',
#  293: 'unit',
#  294: 'second',
#  295: 'nothing',
#  296: 'front',
#  297: 'couple',
#  298: 'hang',
#  299: 'play',
#  300: 'half',
#  301: 'chair',
#  302: 'turn',
#  303: 'instead',
#  304: 'battery',
#  305: 'bottom',
#  306: 'pull',
#  307: 'folder',
#  308: 'damage',
#  309: 'ok',
#  310: 'next',
#  311: 'customer',
#  312: 'real',
#  313: 'pleased',
#  314: 'bible',
#  315: 'feature',
#  316: 'change',
#  317: 'file',
#  318: 'full',
#  319: 'let',
#  320: 'attach',
#  321: 'metal',
#  322: 'else',
#  323: 'cool',
#  324: 'house',
#  325: 'standard',
#  326: 'save',
#  327: 'punch',
#  328: 'us',
#  329: 'fact',
#  330: 'call',
#  331: 'other',
#  332: 'mine',
#  333: 'leather',
#  334: 'chart',
#  335: 'mean',
#  336: 'surface',
#  337: 'zipper',
#  338: 'fold',
#  339: 'coffee',
#  340: 'spend',
#  341: 'sell',
#  342: 'christmas',
#  343: 'describe',
#  344: 'super',
#  345: 'smooth',
#  346: 'sticker',
#  347: 'wrong',
#  348: 'blue',
#  349: 'plus',
#  350: 'especially',
#  351: 'class',
#  352: 'description',
#  353: 'lose',
#  354: 'regular',
#  355: 'difficult',
#  356: 'enjoy',
#  357: 'tag',
#  358: 'already',
#  359: 'learn',
#  360: 'least',
#  361: 'ago',
#  362: 'tip',
#  363: 'sit',
#  364: 'name',
#  365: 'system',
#  366: 'complaint',
#  367: 'display',
#  368: 'strap',
#  369: 'five',
#  370: 'art',
#  371: 'wallet',
#  372: 'build',
#  373: 'nicely',
#  374: 'reason',
#  375: 'solid',
#  376: 'fan',
#  377: 'free',
#  378: 'wear',
#  379: 'power',
#  380: 'leg',
#  381: 'word',
#  382: 'model',
#  383: 'maybe',
#  384: 'supply',
#  385: 'apart',
#  386: 'ask',
#  387: 'storage',
#  388: 'red',
#  389: 'provide',
#  390: 'someone',
#  391: 'advertise',
#  392: 'decide',
#  393: 'replacement',
#  394: 'x',
#  395: 'key',
#  396: 'life',
#  397: 'software',
#  398: 'completely',
#  399: 'minute',
#  400: 'chalk',
#  401: 'amount',
#  402: 'husband',
#  403: 'envelope',
#  404: 'tv',
#  405: 'favorite',
#  406: 'flat',
#  407: 'craft',
#  408: 'create',
#  409: 'frame',
#  410: 'quick',
#  411: 'writing',
#  412: 'require',
#  413: 'absolutely',
#  414: 'condition',
#  415: 'glad',
#  416: 'poster',
#  417: 'water',
#  418: 'seal',
#  419: 'packaging',
#  420: 'available',
#  421: 'air',
#  422: 'wait',
#  423: 'slide',
#  424: 'longer',
#  425: 'rather',
#  426: 'short',
#  427: 'list',
#  428: 'protect',
#  429: 'teacher',
#  430: 'although',
#  431: 'stock',
#  432: 'paint',
#  433: 'amazing',
#  434: 'either',
#  435: 'loose',
#  436: 'finally',
#  437: 'hour',
#  438: 'laptop',
#  439: 'soft',
#  440: 'car',
#  441: 'whole',
#  442: 'online',
#  443: 'four',
#  444: 'foot',
#  445: 'flimsy',
#  446: 'everyone',
#  447: 'touch',
#  448: 'glue',
#  449: 'cube',
#  450: 'bright',
#  451: 'family',
#  452: 'stamp',
#  453: 'extremely',
#  454: 'plan',
#  455: 'professional',
#  456: 'draw',
#  457: 'version',
#  458: 'area',
#  459: 'guess',
#  460: 'often',
#  461: 'device',
#  462: 'mount',
#  463: 'tear',
#  464: 'bottle',
#  465: 'adjust',
#  466: 'poor',
#  467: 'smell',
#  468: 'glitter',
#  469: 'disappointed',
#  470: 'fantastic',
#  471: 'shape',
#  472: 'delivery',
#  473: 'throw',
#  474: 'person',
#  475: 'travel',
#  476: 'behind',
#  477: 'contact',
#  478: 'bring',
#  479: 'copy',
#  480: 'finish',
#  481: 'screw',
#  482: 'fill',
#  483: 'style',
#  484: 'classroom',
#  485: 'local',
#  486: 'insert',
#  487: 'within',
#  488: 'edge',
#  489: 'secure',
#  490: 'tray',
#  491: 'pick',
#  492: 'brother',
#  493: 'journal',
#  494: 'option',
#  495: 'charge',
#  496: 'zip',
#  497: 'snap',
#  498: 'adjustable',
#  499: 'instruction',
#  500: 'believe',
#  501: 'please',
#  502: 'laminate',
#  503: 'game',
#  504: 'birthday',
#  505: 'simply',
#  506: 'along',
#  507: 'usually',
#  508: 'sometimes',
#  509: 'original',
#  510: 'purse',
#  511: 'base',
#  512: 'become',
#  513: 'match',
#  514: 'strip',
#  515: 'button',
#  516: 'huge',
#  517: 'best',
#  518: 'rubber',
#  519: 'chalkboard',
#  520: 'date',
#  521: 'flip',
#  522: 'offer',
#  523: 'tab',
#  524: 'suppose',
#  525: 'fix',
#  526: 'flexible',
#  527: 'slightly',
#  528: 'adhesive',
#  529: 'coin',
#  530: 'choose',
#  531: 'i',
#  532: 'comfortable',
#  533: 'daily',
#  534: 'staple',
#  535: 'mark',
#  536: 'kit',
#  537: 'length',
#  538: 'figure',
#  539: 'stop',
#  540: 'toy',
#  541: 'organizer',
#  542: 'grip',
#  543: 'anyway',
#  544: 'wax',
#  545: 'live',
#  546: 'mess',
#  547: 'drop',
#  548: 'addition',
#  549: 'outside',
#  550: 'compare',
#  551: 'rip',
#  552: 'laser',
#  553: 'wipe',
#  554: 'soon',
#  555: 'taste',
#  556: 'slip',
#  557: 'result',
#  558: 'duty',
#  559: 'appear',
#  560: 'experience',
#  561: 'decent',
#  562: 'install',
#  563: 'planner',
#  564: 'thought',
#  565: 'wood',
#  566: 'past',
#  567: 'fabric',
#  568: 'miss',
#  569: 'convenient',
#  570: 'image',
#  571: 'disappoint',
#  572: 'fountain',
#  573: 'slot',
#  574: 'drawer',
#  575: 'helpful',
#  576: 'satisfied',
#  577: 'choice',
#  578: 'neat',
#  579: 'loop',
#  580: 'blade',
#  581: 'due',
#  582: 'mail',
#  583: 'serve',
#  584: 'kitchen',
#  585: 'screen',
#  586: 'functional',
#  587: 'tight',
#  588: 'door',
#  589: 'green',
#  590: 'correct',
#  591: 'dollar',
#  592: 'wife',
#  593: 'mouse',
#  594: 'later',
#  595: 'deliver',
#  596: 'mini',
#  597: 'sticky',
#  598: 'similar',
#  599: 'non',
#  600: 'hook',
#  601: 'information',
#  602: 'lead',
#  603: 'center',
#  604: 'plug',
#  605: 'future',
#  606: 'consider',
#  607: 'otherwise',
#  608: 'glass',
#  609: 'support',
#  610: 'cause',
#  611: 'solution',
#  612: 'care',
#  613: 'email',
#  614: 'state',
#  615: 'remember',
#  616: 'wet',
#  617: 'bundle',
#  618: 'beat',
#  619: 'dark',
#  620: 'sort',
#  621: 'shelf',
#  622: 'pink',
#  623: 'scratch',
#  624: 'program',
#  625: 'finger',
#  626: 'okay',
#  627: 'middle',
#  628: 'mention',
#  629: 'true',
#  630: 'pouch',
#  631: 'address',
#  632: 'sound',
#  633: 'course',
#  634: 'variety',
#  635: 'inexpensive',
#  636: 'yes',
#  637: 'single',
#  638: 'hp',
#  639: 'luggage',
#  640: 'college',
#  641: 'spray',
#  642: 'lightweight',
#  643: 'post',
#  644: 'plenty',
#  645: 'multiple',
#  646: 'lock',
#  647: 'cap',
#  648: 'divider',
#  649: 'happen',
#  650: 'document',
#  651: 'reasonable',
#  652: 'onto',
#  653: 'unless',
#  654: 'per',
#  655: 'present',
#  656: 'pop',
#  657: 'shop',
#  658: 'sized',
#  659: 'usb',
#  660: 'cd',
#  661: 'whatever',
#  662: 'face',
#  663: 'double',
#  664: 'printing',
#  665: 'worry',
#  666: 'corner',
#  667: 'immediately',
#  668: 'special',
#  669: 'step',
#  670: 'pro',
#  671: 'record',
#  672: 'search',
#  673: 'unfortunately',
#  674: 'sleeve',
#  675: 'terrible',
#  676: 'floor',
#  677: 'bill',
#  678: 'tiny',
#  679: 'refund',
#  680: 'anywhere',
#  681: 'cup',
#  682: 'crack',
#  683: 'matter',
#  684: 'complete',
#  685: 'epson',
#  686: 'process',
#  687: 'notice',
#  688: 'girl',
#  689: 'guy',
#  690: 'track',
#  691: 'careful',
#  692: 'rate',
#  693: 'pc',
#  694: 'realize',
#  695: 'across',
#  696: 'band',
#  697: 'research',
#  698: 'steel',
#  699: 'whiteboard',
#  700: 'important',
#  701: 'drive',
#  702: 'apply',
#  703: 'ball',
#  704: 'credit',
#  705: 'certainly',
#  706: 'level',
#  707: 'separate',
#  708: 'laminator',
#  709: 'cat',
#  710: 'roller',
#  711: 'push',
#  712: 'cart',
#  713: 'test',
#  714: 'bind',
#  715: 'fairly',
#  716: 'rest',
#  717: 'wide',
#  718: 'function',
#  719: 'plate',
#  720: 'notebinder',
#  721: 'surprise',
#  722: 'grade',
#  723: 'manufacturer',
#  724: 'various',
#  725: 'instal',
#  726: 'eye',
#  727: 'medium',
#  728: 'head',
#  729: 'section',
#  730: 'today',
#  731: 'sign',
#  732: 'calculator',
#  733: 'hot',
#  734: 'mm',
#  735: 'mind',
#  736: 'properly',
#  737: 'entire',
#  738: 'assemble',
#  739: 'maker',
#  740: 'collection',
#  741: 'comment',
#  742: 'form',
#  743: 'totally',
#  744: 'total',
#  745: 'prefer',
#  746: 'mood',
#  747: 'control',
#  748: 'answer',
#  749: 'follow',
#  750: 'cloth',
#  751: 'tower',
#  752: 'backpack',
#  753: 'reviewer',
#  754: 'magnet',
#  755: 'heat',
#  756: 'cardboard',
#  757: 'attractive',
#  758: 'counter',
#  759: 'stainless',
#  760: 'intend',
#  761: 'magnetic',
#  762: 'window',
#  763: 'bunch',
#  764: 'ipod',
#  765: 'difference',
#  766: 'detail',
#  767: 'world',
#  768: 'expectation',
#  769: 'tend',
#  770: 'party',
#  771: 'bend',
#  772: 'electronic',
#  773: 'trouble',
#  774: 'actual',
#  775: 'basic',
#  776: 'personal',
#  777: 'self',
#  778: 'trip',
#  779: 'construction',
#  780: 'keyboard',
#  781: 'ton',
#  782: 'unique',
#  783: 'suggest',
#  784: 'container',
#  785: 'flow',
#  786: 'creamer',
#  787: 'continue',
#  788: 'pattern',
#  789: 'ready',
#  790: 'charger',
#  791: 'dust',
#  792: 'recently',
#  793: 'user',
#  794: 'unlike',
#  795: 'film',
#  796: 'contain',
#  797: 'hate',
#  798: 'weigh',
#  799: 'map',
#  800: 'meet',
#  801: 'spot',
#  802: 'flower',
#  803: 'mead',
#  804: 'sew',
#  805: 'age',
#  806: 'horrible',
#  807: 'site',
#  808: 'measure',
#  809: 'iron',
#  810: 'gold',
#  811: 'count',
#  812: 'switch',
#  813: 'shine',
#  814: 'negative',
#  815: 'buying',
#  816: 'pass',
#  817: 'wedding',
#  818: 'imagine',
#  819: 'bubble',
#  820: 'sharp',
#  821: 'bulky',
#  822: 'website',
#  823: 'hear',
#  824: 'trash',
#  825: 'e',
#  826: 'everyday',
#  827: 'useless',
#  828: 'press',
#  829: 'chore',
#  830: 'nearly',
#  831: 'jack',
#  832: 'peel',
#  833: 'sale',
#  834: 'everywhere',
#  835: 'cross',
#  836: 'bleed',
#  837: 'yellow',
#  838: 'smoothly',
#  839: 'transparency',
#  840: 'leak',
#  841: 'brush',
#  842: 'odor',
#  843: 'canon',
#  844: 'junk',
#  845: 'compartment',
#  846: 'anymore',
#  847: 'young',
#  848: 'forward',
#  849: 'lovely',
#  850: 'fail',
#  851: 'begin',
#  852: 'night',
#  853: 'jam',
#  854: 'con',
#  855: 'artist',
#  856: 'accurate',
#  857: 'stable',
#  858: 'chance',
#  859: 'breadboard',
#  860: 'code',
#  861: 'man',
#  862: 'presentation',
#  863: 'solve',
#  864: 'straight',
#  865: 'purple',
#  866: 'talk',
#  867: 'hit',
#  868: 'compact',
#  869: 'timely',
#  870: 'practice',
#  871: 'meeting',
#  872: 'update',
#  873: 'possible',
#  874: 'effort',
#  875: 'application',
#  876: 'except',
#  877: 'vendor',
#  878: 'wash',
#  879: 'exact',
#  880: 'portable',
#  881: 'grommet',
#  882: 'mom',
#  883: 'market',
#  884: 'complain',
#  885: 'twice',
#  886: 'boy',
#  887: 'main',
#  888: 'colorful',
#  889: 'practical',
#  890: 'tall',
#  891: 'event',
#  892: 'ease',
#  893: 'organization',
#  894: 'arm',
#  895: 'putty',
#  896: 'smoke',
#  897: 'sarah',
#  898: 'previous',
#  899: 'bargain',
#  900: 'plain',
#  901: 'connect',
#  902: 'wonder',
#  903: 'drawing',
#  904: 'surprised',
#  905: 'trick',
#  906: 'warm',
#  907: 'perhaps',
#  908: 'stuck',
#  909: 'lid',
#  910: 'truly',
#  911: 'normal',
#  912: 'safe',
#  913: 'palin',
#  914: 'woman',
#  915: 'promise',
#  916: 'additional',
#  917: 'nee',
#  918: 'colored',
#  919: 'seat',
#  920: 'buck',
#  921: 'bar',
#  922: 'buddy',
#  923: 'alone',
#  924: 'dimension',
#  925: 'hardware',
#  926: 'own',
#  927: 'watch',
#  928: 'understand',
#  929: 'avoid',
#  930: 'load',
#  931: 'garbage',
#  932: 'six',
#  933: 'none',
#  934: 'music',
#  935: 'mostly',
#  936: 'protector',
#  937: 'stapler',
#  938: 'stationery',
#  939: 'gray',
#  940: 'labeler',
#  941: 'question',
#  942: 'holiday',
#  943: 'reusable',
#  944: 'beautifully',
#  945: 'bent',
#  946: 'impressed',
#  947: 'oh',
#  948: 'effective',
#  949: 'fault',
#  950: 'mat',
#  951: 'manner',
#  952: 'catch',
#  953: 'prevent',
#  954: 'compliment',
#  955: 'tote',
#  956: 'coupon',
#  957: 'hair',
#  958: 'spiral',
#  959: 'pound',
#  960: 'text',
#  961: 'lie',
#  962: 'alternative',
#  963: 'smear',
#  964: 'cell',
#  965: 'forever',
#  966: 'sand',
#  967: 'manual',
#  968: 'repair',
#  969: 'equipment',
#  970: 'silver',
#  971: 'invitation',
#  972: 'tracfone',
#  973: 'be',
#  974: 'beware',
#  975: 'glossy',
#  976: 'hide',
#  977: 'impossible',
#  978: 'tough',
#  979: 'clearly',
#  980: 'cabinet',
#  981: 'flap',
#  982: 'dog',
#  983: 'particular',
#  984: 'friendly',
#  985: 'third',
#  986: 'template',
#  987: 'versatile',
#  988: 'produce',
#  989: 'remain',
#  990: 'dvd',
#  991: 'basically',
#  992: 'poorly',
#  993: 'perform',
#  994: 'funny',
#  995: 'pressure',
#  996: 'management',
#  997: 'pre',
#  998: 'ticket',
#  999: 'teach',
#  1000: 'church',
#  ...}

# %%
# We decode the review; note that our indices were offset by 3
# because 0, 1 and 2 are reserved indices for "padding", "start of sequence", and "unknown".
decoded_review = ' '.join([reverse_word_index.get(i - 3, ' ') for i in sequences[0]])

# %%
decoded_review
# Out:
# 'gram snap put assortment use tie briefcase book little stable ezlaminator blue cable kid photo hand good find talk anywhere page work complete send ratchet something sheet something sheet elenco come make month difficult piece card label computer amazing piece work take send extra wood neat sheet elenco   person assortment printing nice paper stable blue assortment cause solution warparty sculpture thing put bag stable cobalt side lock stick one stable let floor first pretty month pencil give need   pencil work perfectly little replacement'

# %%
def sequence_to_text(sequence):
    words =  [reverse_word_index.get(letter) for letter in sequence]
    return words

my_text = list(map(sequence_to_text, sequences))

# %%
len(my_text)
# Out:
# 10835

# %% [markdown]
# # Word2Vec and Simple Neural Network

# %%
word2vec = gensim.models.Word2Vec(my_text,
                                  size=100,
                                  window=5,
                                  min_count=1)
word2vec.train(my_text, total_examples=10835, epochs=10)
# Out:
# W0728 14:38:10.599856 4462671296 base_any2vec.py:1182] Effective 'alpha' higher than previous training cycles
# (3155804, 3562450)

# %%
# vocab size
words = list(word2vec.wv.vocab)
print('Vocabulary size: %d' % len(words))
# Out:
# Vocabulary size: 16456

# %%
similar_words = {search_term: [item[0] for item in word2vec.wv.most_similar([search_term], topn=5)]
                  for search_term in ['laptop', 'tv', 'pen', 'pencil', 'computer', 'bad']}
similar_words
# Out:
# {'laptop': ['consulting', 'charger', 'lifesav', 'kindle', 'igo'],
#  'tv': ['lcd', 'behind', 'coax', 'television', 'mobile'],
#  'pen': ['ballpoint', 'gel', 'fountain', 'nib', 'retractable'],
#  'pencil': ['flexgrip', 'mechanical', 'xact', 'yoropen', 'ballpoint'],
#  'computer': ['pc', 'network', 'entertainment', 'stereo', 'device'],
#  'bad': ['terrible', 'advised', 'wonder', 'complain', 'happen']}

# %%
# let us try some utility functions of gensim word2vec more details here 

word2vec.wv.most_similar('cable', topn =4)
# Out:
# [('wire', 0.875932514667511),
#  ('cord', 0.8740338087081909),
#  ('bundle', 0.852850079536438),
#  ('tie', 0.7950431108474731)]

# %%
word2vec.wv.similar_by_word("cable")
# Out:
# [('wire', 0.875932514667511),
#  ('cord', 0.8740338087081909),
#  ('bundle', 0.852850079536438),
#  ('tie', 0.7950431108474731),
#  ('tangle', 0.7948740720748901),
#  ('electrical', 0.7824217677116394),
#  ('buddy', 0.7772928476333618),
#  ('indespensible', 0.7772332429885864),
#  ('neatly', 0.7732696533203125),
#  ('entertainment', 0.7644191980361938)]

# %%
print(word2vec.wv.similarity('laptop', 'computer'))
# Out:
# 0.6413081

# %%
print(word2vec.wv.similarity('computer', 'great'))
print(word2vec.wv.similarity('tv', 'great'))
print(word2vec.wv.similarity('laptop', 'great'))
print(word2vec.wv.similarity('pen', 'great'))
# Out:
# 0.21472332
# 0.1616706
# 0.07377857
# -0.09397545

# %%
#Let’s see the result of semantically reasonable word vectors (king - man + woman)
#Vord vectors (book - pencil + computer)
word2vec.wv.most_similar_cosmul(positive=['book', 'computer'], negative=['pencil'])
# Out:
# [('software', 1.5975254774093628),
#  ('indiviually', 1.5288289785385132),
#  ('clogged', 1.492851734161377),
#  ('pc', 1.4835437536239624),
#  ('bookold', 1.4140070676803589),
#  ('serviceit', 1.4133350849151611),
#  ('hangover', 1.4058010578155518),
#  ('smartboard', 1.3804036378860474),
#  ('ocr', 1.3777302503585815),
#  ('technicians', 1.3601839542388916)]

# %%
#odd word out
print(word2vec.wv.doesnt_match('laptop cable pencil computer'.split()))
# Out:
# pencil

# %%
similar_words
# Out:
# {'laptop': ['consulting', 'charger', 'lifesav', 'kindle', 'igo'],
#  'tv': ['lcd', 'behind', 'coax', 'television', 'mobile'],
#  'pen': ['ballpoint', 'gel', 'fountain', 'nib', 'retractable'],
#  'pencil': ['flexgrip', 'mechanical', 'xact', 'yoropen', 'ballpoint'],
#  'computer': ['pc', 'network', 'entertainment', 'stereo', 'device'],
#  'bad': ['terrible', 'advised', 'wonder', 'complain', 'happen']}

# %%
from sklearn.manifold import TSNE

words = sum([[k] + v for k, v in similar_words.items()], [])
wvs = word2vec.wv[words]

tsne = TSNE(n_components=2, random_state=0, n_iter=10000, perplexity=2)
np.set_printoptions(suppress=True)
T = tsne.fit_transform(wvs)
labels = words

plt.figure(figsize=(14, 8))
plt.scatter(T[:, 0], T[:, 1], c='orange', edgecolors='r')
for label, x, yt in zip(labels, T[:, 0], T[:, 1]):
    plt.annotate(label, xy=(x+1, yt+1), xytext=(0, 0), textcoords='offset points')

# %%
len(word_index.keys())
# Out:
# 16456

# %%
len(word2vec.wv.vocab)
# Out:
# 16456

# %% [markdown]
# So we created word vectors using Word2Vec and the model has 16456 unique words where each word has a vector length of 100
#
#
# Now we are going to use these dense vectors - word embeddings - in a simple neural network to predict

# %%
=================================

# %%
# total_reviews = df.review_text.values
# max_length = max([len(s.split()) for s in total_reviews])

# %%
total_reviews
# Out:
# array(["I honestly believe that giving this merchant one star was doing him or her a favor. I first purchased this code for my history class. I even paid extra for shipping so that it would come in a timely matter. After receiving the product I noticed there were three oddly placed holes that had been placed by a hole puncher. It also looked as though it already had been opened and put back together. After finally opening the product I saw that three letters were missing due to the hole puncher that was used. I contacted the merchant immediately because I really need the code for my class. The merchant emailed and stated that he/she could give me another code from their inventory. This never happened and I ended getting my code from else where. They are refunding me my money and I feel as though I have wasted a lot of my time. So don't waste yours with this product.Worst purchase of life",
#        'This is a standard size folder that fits standard paper of 8.5x11". The folder was sturdy and laminated, so it will hold up nicely. The only caveat is, if you buy a smaller than standard size backpack (for a toddler, for example), this folder will be a bit large for the backpack, but it can be warped to fit in them. A good buy :)Just what I expected',
#        'The kids love to get these green tickets to take home and show their parents.  I use the tickets as a raffle for good behavior for the month.  The best child gets $25The kids will love it!',
#        ..., "Homeshooler's Dream!",
#        "This schedule has been so awesome! The quality is the highest out there as it is completely flexible (literally and figuratively) for families, individuals, homeschool and more. The marker never smudges and it wipes completely clean, even after months of use. What I like most is that you don't have tons of books of not-working schedules, but instead just use this one schedule and change the events, times, or names with just one swipe. I'm giving this product a five star all the way!Great, flexible no-waste schedule!",
#        "This schedule has been so awesome! The quality is the highest out there as it is completely flexible (literally and figuratively) for families, individuals, homeschool and more. The marker never smudges and it wipes completely clean, even after months of use. It is super helpful having chores scheduled on the fridge for the kids and if they need something to do or wonder what their next chore is they can just go look and take care of it themselves, especially helpful when Mom isn't home or is busy.Great Chore Charts!"],
#       dtype=object)

# %%
[s.split() for s in total_reviews]
# Out:
# [['I',
#   'honestly',
#   'believe',
#   'that',
#   'giving',
#   'this',
#   'merchant',
#   'one',
#   'star',
#   'was',
#   'doing',
#   'him',
#   'or',
#   'her',
#   'a',
#   'favor.',
#   'I',
#   'first',
#   'purchased',
#   'this',
#   'code',
#   'for',
#   'my',
#   'history',
#   'class.',
#   'I',
#   'even',
#   'paid',
#   'extra',
#   'for',
#   'shipping',
#   'so',
#   'that',
#   'it',
#   'would',
#   'come',
#   'in',
#   'a',
#   'timely',
#   'matter.',
#   'After',
#   'receiving',
#   'the',
#   'product',
#   'I',
#   'noticed',
#   'there',
#   'were',
#   'three',
#   'oddly',
#   'placed',
#   'holes',
#   'that',
#   'had',
#   'been',
#   'placed',
#   'by',
#   'a',
#   'hole',
#   'puncher.',
#   'It',
#   'also',
#   'looked',
#   'as',
#   'though',
#   'it',
#   'already',
#   'had',
#   'been',
#   'opened',
#   'and',
#   'put',
#   'back',
#   'together.',
#   'After',
#   'finally',
#   'opening',
#   'the',
#   'product',
#   'I',
#   'saw',
#   'that',
#   'three',
#   'letters',
#   'were',
#   'missing',
#   'due',
#   'to',
#   'the',
#   'hole',
#   'puncher',
#   'that',
#   'was',
#   'used.',
#   'I',
#   'contacted',
#   'the',
#   'merchant',
#   'immediately',
#   'because',
#   'I',
#   'really',
#   'need',
#   'the',
#   'code',
#   'for',
#   'my',
#   'class.',
#   'The',
#   'merchant',
#   'emailed',
#   'and',
#   'stated',
#   'that',
#   'he/she',
#   'could',
#   'give',
#   'me',
#   'another',
#   'code',
#   'from',
#   'their',
#   'inventory.',
#   'This',
#   'never',
#   'happened',
#   'and',
#   'I',
#   'ended',
#   'getting',
#   'my',
#   'code',
#   'from',
#   'else',
#   'where.',
#   'They',
#   'are',
#   'refunding',
#   'me',
#   'my',
#   'money',
#   'and',
#   'I',
#   'feel',
#   'as',
#   'though',
#   'I',
#   'have',
#   'wasted',
#   'a',
#   'lot',
#   'of',
#   'my',
#   'time.',
#   'So',
#   "don't",
#   'waste',
#   'yours',
#   'with',
#   'this',
#   'product.Worst',
#   'purchase',
#   'of',
#   'life'],
#  ['This',
#   'is',
#   'a',
#   'standard',
#   'size',
#   'folder',
#   'that',
#   'fits',
#   'standard',
#   'paper',
#   'of',
#   '8.5x11".',
#   'The',
#   'folder',
#   'was',
#   'sturdy',
#   'and',
#   'laminated,',
#   'so',
#   'it',
#   'will',
#   'hold',
#   'up',
#   'nicely.',
#   'The',
#   'only',
#   'caveat',
#   'is,',
#   'if',
#   'you',
#   'buy',
#   'a',
#   'smaller',
#   'than',
#   'standard',
#   'size',
#   'backpack',
#   '(for',
#   'a',
#   'toddler,',
#   'for',
#   'example),',
#   'this',
#   'folder',
#   'will',
#   'be',
#   'a',
#   'bit',
#   'large',
#   'for',
#   'the',
#   'backpack,',
#   'but',
#   'it',
#   'can',
#   'be',
#   'warped',
#   'to',
#   'fit',
#   'in',
#   'them.',
#   'A',
#   'good',
#   'buy',
#   ':)Just',
#   'what',
#   'I',
#   'expected'],
#  ['The',
#   'kids',
#   'love',
#   'to',
#   'get',
#   'these',
#   'green',
#   'tickets',
#   'to',
#   'take',
#   'home',
#   'and',
#   'show',
#   'their',
#   'parents.',
#   'I',
#   'use',
#   'the',
#   'tickets',
#   'as',
#   'a',
#   'raffle',
#   'for',
#   'good',
#   'behavior',
#   'for',
#   'the',
#   'month.',
#   'The',
#   'best',
#   'child',
#   'gets',
#   '$25The',
#   'kids',
#   'will',
#   'love',
#   'it!'],
#  ['This',
#   'is',
#   'a',
#   'nice',
#   'product',
#   'if',
#   'you',
#   'are',
#   'looking',
#   'for',
#   'a',
#   'quick',
#   'happy',
#   'note.',
#   'I',
#   'keep',
#   'them',
#   'next',
#   'to',
#   'my',
#   'desk',
#   'to',
#   'make',
#   'sure',
#   'sad',
#   'notes',
#   'are',
#   'not',
#   'the',
#   'only',
#   'ones',
#   'that',
#   'go',
#   'home.Nice',
#   'Product'],
#  ['WE',
#   'love',
#   'these,',
#   'we',
#   'get',
#   'to',
#   'give',
#   'a',
#   'prize',
#   'now',
#   'and',
#   'later-',
#   'they',
#   'are',
#   'very',
#   'motivating',
#   'to',
#   'the',
#   'students',
#   'and',
#   'cut',
#   'down',
#   'on',
#   'the',
#   'constant',
#   'prizes',
#   'for',
#   'completing',
#   'a',
#   'book.',
#   'We',
#   'use',
#   'the',
#   'other',
#   'part',
#   'as',
#   'a',
#   'raffle',
#   'ticket',
#   'for',
#   'a',
#   'new',
#   'book.cool',
#   'motivational',
#   'idea'],
#  ['I',
#   'use',
#   'these',
#   'coupons',
#   'at',
#   'the',
#   'end',
#   'of',
#   'each',
#   'cycle',
#   'if',
#   'my',
#   'students',
#   'receive',
#   '100%',
#   'HW',
#   'completion.',
#   'I',
#   'staple',
#   'them',
#   'to',
#   'my',
#   'bulletin',
#   'board,',
#   'and',
#   'use',
#   'the',
#   'stub',
#   'for',
#   'a',
#   'raffle.',
#   'The',
#   'winner',
#   'receives',
#   'breakfast',
#   'on',
#   'me,',
#   'usually',
#   'Dunkin',
#   'Donuts.Great',
#   'Classroom',
#   'Incentive'],
#  ['I',
#   'liked',
#   'the',
#   'look',
#   'of',
#   'this',
#   'paper',
#   'when',
#   'I',
#   'saw',
#   'it',
#   'online,',
#   'upon',
#   'receiving',
#   'it',
#   'was',
#   'surprised',
#   'by',
#   'the',
#   'almost',
#   'neon',
#   'look',
#   'of',
#   'the',
#   'stars.',
#   'The',
#   'paper',
#   'itself',
#   'was',
#   'very',
#   'thin.Bright,',
#   'very',
#   'bright'],
#  ['The',
#   'perfect',
#   'calendar',
#   'for',
#   'this',
#   'particular',
#   'year.',
#   'The',
#   'graphics',
#   'are',
#   'brilliant,',
#   'captions',
#   'are',
#   'simple,',
#   'and',
#   'it',
#   'makes',
#   'one',
#   'look',
#   'to',
#   'the',
#   'next',
#   'month',
#   'with',
#   'hopeful',
#   'anticipation.',
#   'The',
#   'most',
#   'intelligent',
#   'and',
#   'beautiful',
#   'calendar',
#   'ever.',
#   'Great',
#   "Fun!Can't",
#   'Wait!'],
#  ["Can't",
#   'wait',
#   'for',
#   'it',
#   'to',
#   'arrive.',
#   'The',
#   'pictures',
#   'looked',
#   'fantastic,',
#   'this',
#   'should',
#   'be',
#   'a',
#   'fun',
#   'conversation',
#   'piece',
#   'for',
#   'the',
#   'office.Great',
#   'Calendar'],
#  ['Artwork',
#   'is',
#   'great,',
#   'such',
#   'a',
#   'creative',
#   'piece',
#   'to',
#   'have',
#   'on',
#   'your',
#   'cubicle',
#   "wall.I've",
#   'purchased',
#   'two',
#   'already.Buy',
#   'one',
#   'for',
#   'a',
#   'friend,',
#   "they'll",
#   'love',
#   'the',
#   'survival',
#   'tips!LOVE',
#   'IT'],
#  ['This',
#   'is',
#   'the',
#   'coolest',
#   'calendar!',
#   "I'm",
#   'ordering',
#   'several',
#   'to',
#   'give',
#   'as',
#   'gifts.',
#   'The',
#   'idea',
#   'and',
#   'art',
#   'are',
#   'phenomenal.',
#   'Love',
#   'it!Awesome!'],
#  ["I've",
#   'seeen',
#   'the',
#   'calendar',
#   'in',
#   'person',
#   'and',
#   'it',
#   'ROCKS!',
#   'I',
#   'put',
#   'it',
#   'on',
#   'my',
#   "Santa's",
#   'list!',
#   'Graphics',
#   'are',
#   'amazing',
#   'and',
#   'the',
#   '"helpful"',
#   'hints',
#   'are',
#   'great!Hope',
#   'Santa',
#   'brings',
#   'me',
#   'one',
#   'this',
#   'year'],
#  ['Whoever',
#   'created',
#   'this',
#   'has',
#   'a',
#   'serious',
#   'niche',
#   'for',
#   '2012.',
#   'Not',
#   'sure',
#   'where',
#   'you',
#   'came',
#   'up',
#   'with',
#   'the',
#   'photos,',
#   'but',
#   'these',
#   'look',
#   'amazing.',
#   'I',
#   'took',
#   'it',
#   'into',
#   'work',
#   'with',
#   'me',
#   'the',
#   'other',
#   'day',
#   'and',
#   'had',
#   'several',
#   'coworkers',
#   'ask',
#   'me',
#   'about',
#   'it.',
#   'I',
#   'told',
#   'them',
#   'where',
#   'I',
#   'found',
#   'it',
#   'and',
#   'now',
#   'they',
#   'want',
#   'one',
#   'too.',
#   'lol.',
#   'I',
#   'thought',
#   'it',
#   'was',
#   'a',
#   'great',
#   'idea',
#   'myself,',
#   'but',
#   'I',
#   "didn't",
#   'expect',
#   'this',
#   'kind',
#   'of',
#   'response.',
#   'I',
#   'look',
#   'forward',
#   'to',
#   'getting',
#   'next',
#   'years',
#   'DOOMSDAY',
#   'Calendar',
#   'if',
#   'for',
#   'some',
#   'reason',
#   'it',
#   "doesn't",
#   'happen',
#   'when',
#   'they',
#   'say',
#   'it',
#   'will.',
#   'Thanks',
#   'a',
#   'lot!',
#   '-RyanHad',
#   'to',
#   'have',
#   'it,',
#   'now',
#   'I',
#   'have',
#   'to',
#   'get',
#   'more',
#   'for',
#   'coworkers...'],
#  ['Received',
#   'the',
#   'calendar',
#   'very',
#   'quickly.',
#   'Love',
#   'the',
#   'graphics!',
#   'Look',
#   'forward',
#   'to',
#   'looking',
#   'at',
#   'each',
#   'new',
#   'disaster',
#   'every',
#   'month!!',
#   'Would',
#   'highly',
#   'recommend',
#   'it!Love',
#   'the',
#   'graphics!'],
#  ['This',
#   'beautiful',
#   'calendar',
#   'was',
#   'given',
#   'to',
#   'me',
#   'by',
#   'a',
#   'lovely',
#   'man',
#   'in',
#   'Kentucky.',
#   'I',
#   'like',
#   'it',
#   'so',
#   'much',
#   'that',
#   'I',
#   'ordered',
#   'one',
#   'for',
#   'my',
#   'brother.',
#   'Tony',
#   "Leonard's",
#   'exquisite',
#   'photos',
#   'of',
#   'Secretariat',
#   'are',
#   'for',
#   'the',
#   'ages.Big',
#   'Red',
#   '2014',
#   'Calendar'],
#  ['Well',
#   'worth',
#   'the',
#   'money.',
#   'Fantastic',
#   'large',
#   'photos',
#   'on',
#   'very',
#   'nice',
#   'paper.',
#   'Lots',
#   'of',
#   'history,',
#   'facts',
#   'and',
#   'small',
#   'pictures',
#   'included',
#   'inside.Well',
#   'worth',
#   'the',
#   'money!',
#   'Fantastic',
#   'calendar!'],
#  ['I',
#   'have',
#   'a',
#   'room',
#   'called',
#   'the',
#   '&#34;Red&#34;',
#   'room',
#   'dedicated',
#   'to',
#   'Secretariat.',
#   'The',
#   'Calender',
#   'is',
#   'great',
#   'service',
#   '...great',
#   'too',
#   'Thank',
#   'you',
#   'very',
#   'muchI',
#   'need',
#   'to',
#   'order',
#   'another',
#   'one.Secretatiat',
#   '20',
#   'month',
#   'Calender'],
#  ['Secretariat',
#   'is',
#   'my',
#   'favorite',
#   'athelete',
#   'of',
#   'all',
#   'time.',
#   'These',
#   'pictures',
#   'are',
#   'beautiful',
#   'and',
#   'bring',
#   'back',
#   'memories',
#   'of',
#   'that',
#   'incredible',
#   'moment',
#   'in',
#   'history.Beautiful'],
#  ['I',
#   'knew',
#   'Tony',
#   'Leonard',
#   'and',
#   'have',
#   'seen',
#   'many',
#   'of',
#   'his',
#   'famous',
#   'portraits',
#   'and',
#   'equine',
#   'pictures.',
#   'Secretariat',
#   'retired',
#   'to',
#   'a',
#   'horse',
#   'farm',
#   'near',
#   'my',
#   'home.',
#   'He',
#   'raised',
#   'interest',
#   'in',
#   'racing',
#   'dramatically',
#   'These',
#   'pictures',
#   'epitomize',
#   'his',
#   'brilliant',
#   'career.Secretariat',
#   'calendar'],
#  ['I',
#   "didn't",
#   'buy',
#   'as',
#   'a',
#   'Calendar.',
#   'I',
#   'bought',
#   'as',
#   'a',
#   'source',
#   'for',
#   'some',
#   'Horse',
#   'pimctures.',
#   "I've",
#   'always',
#   'had',
#   'a',
#   'love',
#   'of',
#   'these',
#   'magnificent',
#   'animals',
#   'and',
#   'this',
#   'calendar',
#   'helped',
#   'fill-out',
#   'my',
#   'collection',
#   'of',
#   'pictures.Like',
#   'horseys',
#   '?',
#   'You',
#   'enjoy',
#   'the',
#   'pictures'],
#  ['Very',
#   'nice',
#   'looking',
#   'wallet.',
#   'Love',
#   'the',
#   'crocodile',
#   'embossed',
#   'leather.',
#   'Quality',
#   'look.',
#   'Lots',
#   'of',
#   'pockets',
#   'to',
#   'organize',
#   'documents.',
#   'Very',
#   'happy',
#   'with',
#   'my',
#   'purchase.Very',
#   'nice',
#   'travel',
#   'wallet'],
#  ['These,',
#   'and',
#   'all',
#   'the',
#   'other',
#   'Galison',
#   'Mudpuppy',
#   'files',
#   "I've",
#   'recently',
#   'bought,',
#   'are',
#   'cute,',
#   'sturdy',
#   'and',
#   'come',
#   'in',
#   'packs',
#   'of',
#   '8',
#   'files',
#   'with',
#   'tons',
#   'and',
#   'tons',
#   'of',
#   'labels.',
#   'I',
#   'appreciate',
#   'that',
#   'since',
#   'I',
#   'like',
#   'my',
#   'labels',
#   'to',
#   'be',
#   'precise',
#   'and',
#   'clean.',
#   'I',
#   'can',
#   'peel',
#   'off',
#   'an',
#   'old',
#   'label',
#   'and',
#   'slip',
#   'on',
#   'a',
#   'new',
#   'one',
#   'pretty',
#   'easily,',
#   'or',
#   'just',
#   'layer',
#   'away.nice',
#   'setup'],
#  ['This',
#   'has',
#   'worked',
#   'well',
#   'for',
#   'us',
#   'this',
#   'year.',
#   'We',
#   'are',
#   'new',
#   'to',
#   'homeschool',
#   'and',
#   'will',
#   'look',
#   'into',
#   'other',
#   'curriculums',
#   'next',
#   'year.',
#   'This',
#   'would',
#   'be',
#   'great',
#   'if',
#   'it',
#   'came',
#   'with',
#   'workbooks',
#   'or',
#   'something.',
#   'It',
#   'just',
#   "doesn't",
#   'seem',
#   'to',
#   'have',
#   'enough',
#   'practice',
#   'lessons.Good',
#   'for',
#   '1st',
#   'timers.'],
#  ['We',
#   'purchased',
#   'this',
#   'for',
#   'our',
#   'first',
#   'time',
#   'homeschooling.It',
#   'was',
#   'AWFUL!Incredibly',
#   'complicated,',
#   'very',
#   'user',
#   'un-friendly.We',
#   'spent',
#   'countless',
#   'hours',
#   'trying',
#   'to',
#   'set',
#   'it',
#   'up',
#   'to',
#   'get',
#   'the',
#   'features',
#   'advertised,',
#   'but',
#   'were',
#   'unable',
#   'to',
#   'do',
#   'so.Not',
#   'able',
#   'to',
#   'review',
#   'tests,',
#   'give',
#   'assignments,',
#   'or',
#   'even',
#   'pull',
#   'up',
#   'attendance',
#   'reports.',
#   'All',
#   'of',
#   'these',
#   'are',
#   'supposedly',
#   'features',
#   'available.Contacted',
#   'the',
#   'seller,',
#   'hoping',
#   'to',
#   'exchange',
#   'it',
#   'for',
#   'a',
#   'book-based',
#   'curriculum,',
#   'but',
#   'they',
#   'state',
#   '"We',
#   'are',
#   'not',
#   'able',
#   'to',
#   'accept',
#   'returns',
#   'on',
#   'any',
#   'software',
#   'once',
#   'it',
#   'is',
#   'opened',
#   'and',
#   'used",',
#   'which',
#   'would',
#   'be',
#   'reasonable',
#   'with',
#   'a',
#   'product',
#   'that',
#   "WASN'T",
#   'defective.Save',
#   'the',
#   'aggravation.',
#   'If',
#   'you',
#   'spend',
#   'half',
#   'as',
#   'much',
#   'time',
#   'teaching',
#   'the',
#   'curriculum',
#   'out',
#   'of',
#   'a',
#   'regular',
#   'textbook',
#   'that',
#   'it',
#   'would',
#   'take',
#   'to',
#   'get',
#   'minimal',
#   'results',
#   'from',
#   'this',
#   'product,',
#   'your',
#   'child',
#   'will',
#   'be',
#   'far',
#   'ahead',
#   'of',
#   'his',
#   'peers',
#   'in',
#   'public',
#   'or',
#   'private',
#   'schools.The',
#   'only',
#   'reason',
#   'I',
#   'gave',
#   'it',
#   '1',
#   'star',
#   'rating',
#   'is',
#   'I',
#   'was',
#   'unable',
#   'to',
#   'choose',
#   'negative',
#   'stars......Worst....product....EVER'],
#  ['I',
#   'have',
#   'used',
#   'SOS',
#   'for',
#   'homeschooling',
#   'for',
#   '5',
#   'years',
#   'now,',
#   'and',
#   'this',
#   '2012',
#   'version',
#   'is',
#   'horrible.',
#   'There',
#   'are',
#   'so',
#   'many',
#   'problems',
#   'in',
#   'every',
#   'subject.',
#   'Even',
#   'the',
#   'electives',
#   'I',
#   'purchased',
#   'last',
#   'year,',
#   'like',
#   'Family',
#   'and',
#   'Consumer',
#   'Science,',
#   'have',
#   'issues.',
#   'Some',
#   'of',
#   'these',
#   'include:"Tiny',
#   'Tutor"',
#   'videos',
#   'have',
#   'a',
#   'programming',
#   'error',
#   'that',
#   'cuts',
#   'off',
#   'half',
#   'of',
#   'the',
#   'viewable',
#   'screen',
#   'while',
#   'you',
#   'are',
#   'watching',
#   'it,',
#   'AND',
#   'there',
#   'are',
#   'no',
#   'controls',
#   'visible',
#   '(like',
#   'pause,',
#   'play,',
#   'volume)',
#   'as',
#   'there',
#   'had',
#   'been',
#   'in',
#   'previous',
#   'versions.There',
#   'are',
#   'an',
#   'enormous',
#   'amount',
#   'of',
#   'editing',
#   'errors',
#   'throughout',
#   'the',
#   'products',
#   'like',
#   'the',
#   'lesson',
#   'states',
#   'one',
#   'point,',
#   'but',
#   'the',
#   'questions',
#   'in',
#   'the',
#   'lesson',
#   "won't",
#   'give',
#   'you',
#   'credit',
#   'for',
#   'those',
#   'correct',
#   'answers.',
#   'Or',
#   'the',
#   'lessons',
#   'information',
#   'is',
#   'incorrect',
#   'as',
#   'well,',
#   'like',
#   'incorrect',
#   'definitions',
#   'for',
#   'words',
#   'or',
#   'Algebra',
#   'problems',
#   'worked',
#   'out',
#   'with',
#   'errors.This',
#   'problem',
#   'continues',
#   'onto',
#   'the',
#   'Quizzes',
#   'and',
#   'Tests.Now',
#   'this',
#   'curriculum',
#   'allows',
#   'the',
#   'parent',
#   '(administrator)',
#   'to',
#   'go',
#   'in',
#   'and',
#   'make',
#   'changes',
#   'to',
#   'the',
#   'grades',
#   'or',
#   'even',
#   'remove',
#   'the',
#   'question,',
#   'but',
#   'it',
#   'will',
#   'take',
#   'you',
#   'hours',
#   'every',
#   'week',
#   'to',
#   'go',
#   'in',
#   'and',
#   'do',
#   'this',
#   'with',
#   'all',
#   'the',
#   'errors',
#   'I',
#   'am',
#   'finding.',
#   'This',
#   'is',
#   'extremely',
#   'inefficient',
#   'for',
#   'the',
#   'parent',
#   '-',
#   'now',
#   'you',
#   'have',
#   'to',
#   'spend',
#   'all',
#   'your',
#   'time',
#   'fixing',
#   'the',
#   'manufacturers',
#   'problems.Which',
#   'leads',
#   'me',
#   'to',
#   'their',
#   'support.',
#   'Which',
#   'is',
#   'very',
#   'lacking.',
#   'I',
#   'have',
#   'to',
#   'enter',
#   'every',
#   'single',
#   'issue',
#   '-',
#   'separately',
#   '-',
#   'into',
#   'their',
#   'database,',
#   'then',
#   'I',
#   'have',
#   'to',
#   'wait',
#   'for',
#   'months',
#   'until',
#   'they',
#   'finally',
#   'send',
#   'out',
#   'a',
#   '"fix"',
#   'for',
#   'the',
#   'problem,',
#   'unless',
#   'they',
#   'decide',
#   'that',
#   'it',
#   'is',
#   'too',
#   'comprehensive',
#   'and',
#   'will',
#   'just',
#   'correct',
#   'on',
#   'future',
#   'editions',
#   'of',
#   'the',
#   'product',
#   'which',
#   'does',
#   'me',
#   'NO',
#   'good',
#   'now.',
#   'Of',
#   'course,',
#   'by',
#   'that',
#   'point',
#   'I',
#   'have',
#   'MANY',
#   'other',
#   'issues',
#   'anyway',
#   'and',
#   'no',
#   'time',
#   'to',
#   'go',
#   'back',
#   'and',
#   're-teach',
#   'my',
#   'child',
#   'the',
#   'information',
#   'now',
#   'that',
#   'they',
#   'have',
#   'finally',
#   'fixed',
#   'some',
#   'of',
#   'the',
#   'problems',
#   'I',
#   'already',
#   'found!',
#   'How',
#   'about',
#   'pull',
#   'the',
#   'product',
#   '-',
#   'issue',
#   'us',
#   'all',
#   'a',
#   'refund',
#   '-',
#   'then',
#   'make',
#   'the',
#   'corrections',
#   'throughout',
#   'the',
#   'program',
#   'so',
#   'we',
#   'parents',
#   "don't",
#   'have',
#   'to',
#   'keep',
#   'doing',
#   'your',
#   'job',
#   'for',
#   'you!Highly',
#   'Disappointed'],
#  ['Easy',
#   'to',
#   'install',
#   'and',
#   'easy',
#   'for',
#   'my',
#   'child',
#   'to',
#   'access',
#   'all',
#   'subjects.',
#   'Leaning',
#   'made',
#   'easier',
#   'with',
#   "CD's.",
#   'he',
#   'was',
#   'able',
#   'to',
#   'read',
#   'and',
#   'listen',
#   'to',
#   'all',
#   'his',
#   'subjects.',
#   'Worth',
#   'every',
#   'penny!Excellent',
#   'homeschool',
#   'program'],
#  ['This',
#   'is',
#   'a',
#   'good',
#   'solid',
#   'homeschool',
#   'program.',
#   'It',
#   'does',
#   'take',
#   'time',
#   'to',
#   'set',
#   'up',
#   'initially.',
#   '(it',
#   'took',
#   'me',
#   'a',
#   'few',
#   'hours',
#   'one',
#   'evening)',
#   'However',
#   'I',
#   'think',
#   'the',
#   'previous',
#   'comment',
#   'found',
#   'here',
#   'is',
#   'extreme.',
#   'I',
#   'am',
#   'not',
#   'computer',
#   'savvy',
#   'and',
#   'I',
#   'had',
#   'no',
#   'trouble',
#   'setting',
#   'up',
#   'my',
#   "son's",
#   'program.',
#   'Like',
#   'anything',
#   'new',
#   'it',
#   'takes',
#   'a',
#   'little',
#   'while',
#   'to',
#   'learn',
#   'your',
#   'way',
#   'around.',
#   'I',
#   'also',
#   'found',
#   'that',
#   'it',
#   'is',
#   'very',
#   'flexible',
#   'to',
#   'fit',
#   'our',
#   'needs.',
#   '(You',
#   'can',
#   'easily',
#   'adjust',
#   'for',
#   'sick',
#   'days,',
#   're-assign',
#   'things',
#   'etc.)',
#   'It',
#   'does',
#   'require',
#   'that',
#   'your',
#   'child',
#   'spend',
#   'a',
#   'considerable',
#   'amount',
#   'of',
#   'time',
#   'on',
#   'the',
#   'computer',
#   'and',
#   'that',
#   'is',
#   'something',
#   'to',
#   'consider.',
#   'However,',
#   'if',
#   'for',
#   'various',
#   'reasons',
#   'you',
#   'are',
#   'unable',
#   'to',
#   'sit',
#   'beside',
#   'your',
#   'child',
#   'and',
#   'teach',
#   'them,',
#   'then',
#   'this',
#   'program',
#   'allows',
#   'them',
#   'to',
#   'learn',
#   'independently',
#   'AND',
#   'the',
#   'program',
#   'does',
#   'the',
#   'grading',
#   'for',
#   'you.',
#   'There',
#   'are',
#   'certainly',
#   'times',
#   'in',
#   'life',
#   'when',
#   'this',
#   'is',
#   'a',
#   'life',
#   'saver!a',
#   'solid',
#   '"meat',
#   'and',
#   'potato"',
#   'style',
#   'computer',
#   'homeschool',
#   'curriculum'],
#  ['The',
#   'Spanish',
#   'is',
#   'great.',
#   'It',
#   'is',
#   'super',
#   'fun,',
#   'it',
#   'has',
#   'games',
#   'and',
#   'then',
#   'little',
#   'quizes',
#   'to',
#   'help',
#   'the',
#   'child',
#   'remember.',
#   'My',
#   'third',
#   'grade',
#   "can't",
#   'wait',
#   'for',
#   'school',
#   'so',
#   'she',
#   'can',
#   'start',
#   'on',
#   'her',
#   'spanish.Excellant'],
#  ['students', 'loved', 'this', 'lessongreat'],
#  ['Book',
#   'was',
#   'in',
#   'good',
#   'condition,',
#   'but',
#   'as',
#   'with',
#   'the',
#   'first',
#   'book,',
#   'there',
#   'was',
#   'no',
#   'CD...It',
#   'was',
#   'of',
#   'no',
#   'use',
#   'to',
#   'me',
#   'without',
#   'the',
#   'CDNO',
#   'CD'],
#  ['I',
#   'love',
#   'the',
#   'print',
#   'on',
#   'the',
#   'leather',
#   'and',
#   'the',
#   'pages',
#   'are',
#   'yummy',
#   'very',
#   'thick',
#   'and',
#   'inspiring',
#   'to',
#   'write',
#   'poetry',
#   'on.I',
#   'love',
#   'my',
#   'Journal'],
#  ['I',
#   'feel',
#   'good',
#   'taking',
#   'it',
#   'out',
#   'at',
#   'meetings,',
#   'I',
#   'think',
#   'it',
#   'makes',
#   'a',
#   'lovely',
#   'statement.',
#   'Would',
#   'make',
#   'a',
#   'good',
#   'gift',
#   'as',
#   'well.beautiful!'],
#  ['loved',
#   'it...this',
#   'is',
#   'my',
#   'first',
#   'time',
#   'ordering',
#   'this',
#   'type',
#   'of',
#   'engagement',
#   'calendar',
#   'and',
#   'it',
#   'will',
#   'suit',
#   'my',
#   'needs',
#   'very',
#   'well.',
#   'shipped/received',
#   'and',
#   'appreciating',
#   'it',
#   'very',
#   'much!Debbie',
#   'Mumm',
#   '2009',
#   'engagement',
#   'calendar'],
#  ['Thinking',
#   'about',
#   'moving',
#   'to',
#   'Florida',
#   'and',
#   'need',
#   'a',
#   'good',
#   'map',
#   'of',
#   'Manatee',
#   'county.',
#   'This',
#   'one',
#   'turned',
#   'out',
#   'to',
#   'be',
#   'great.Good',
#   'map'],
#  ['My',
#   '3',
#   'year',
#   'old',
#   'loves',
#   'astronomy',
#   'and',
#   'this',
#   'Mars',
#   'Hugg-a-Planet',
#   'is',
#   'perfect!.',
#   'Just',
#   'the',
#   'fact',
#   'that',
#   'it',
#   'is',
#   'labeled',
#   'with',
#   'areas',
#   'on',
#   'Mars',
#   'is',
#   'amazing.',
#   'I',
#   'wish',
#   'they',
#   'had',
#   'all',
#   'planets',
#   'for',
#   'sale',
#   '(even',
#   'without',
#   'the',
#   'labels).MARS',
#   'HUGG-A-PLANET',
#   'IS',
#   'LABELED',
#   'WITH',
#   'ACTUAL',
#   'NAMES',
#   'ON',
#   'MARS!'],
#  ['Sometimes',
#   'you',
#   'just',
#   'need',
#   'some',
#   'good',
#   'advice',
#   'as',
#   'to',
#   'where',
#   'to',
#   'go',
#   'fishing',
#   'or',
#   'to',
#   'get',
#   'gas.',
#   'This',
#   'map',
#   '(and',
#   'all',
#   'the',
#   'others',
#   'in',
#   'the',
#   'series)',
#   'provides',
#   'just',
#   'that.',
#   'The',
#   'heavy',
#   'duty',
#   'paper',
#   "won't",
#   'rip',
#   'and',
#   'you',
#   'can',
#   'fold',
#   'it',
#   'anyway',
#   'you',
#   'like.',
#   'We',
#   'have',
#   'all',
#   'of',
#   'them',
#   'for',
#   'the',
#   'Columbia',
#   'River',
#   'and',
#   'use',
#   'them',
#   'to',
#   'figure',
#   'out',
#   'where',
#   'we',
#   'want',
#   'to',
#   'go,',
#   'and',
#   'then',
#   'work',
#   'out',
#   'our',
#   'route',
#   'with',
#   'our',
#   'charts',
#   'and',
#   'GPS.',
#   'The',
#   'seller',
#   'is',
#   'also',
#   'very',
#   'prompt',
#   'and',
#   'informs',
#   'you',
#   'when',
#   "it's",
#   'shipped.Excellent',
#   'supplement',
#   'to',
#   'charts',
#   'and',
#   'boat',
#   'GPS'],
#  ['Needed',
#   'this',
#   'for',
#   'school.',
#   'The',
#   'bookstore',
#   'was',
#   'selling',
#   'them',
#   'for',
#   '$70.',
#   'This',
#   'was',
#   'much',
#   'cheaper.',
#   'Works',
#   'just',
#   'fine.',
#   'Minus',
#   '1',
#   'star',
#   'because',
#   'it',
#   'came',
#   'with',
#   'a',
#   'partially',
#   'drained',
#   'battery,',
#   'but',
#   'it',
#   'was',
#   'used,',
#   'so',
#   'that',
#   'is',
#   'expected.Great',
#   'price!'],
#  ['I',
#   'had',
#   'to',
#   'buy',
#   'this',
#   'responsecard',
#   'xr',
#   'for',
#   'a',
#   'few',
#   'of',
#   'my',
#   'large',
#   'classes',
#   'that',
#   'required',
#   'it',
#   'to',
#   'take',
#   'attendance,',
#   'it',
#   'works',
#   'perfectly',
#   'and',
#   'have',
#   'not',
#   'had',
#   'any',
#   'problems',
#   'with',
#   'it.Works',
#   'perfectly'],
#  ['I',
#   'got',
#   'it',
#   'for',
#   '4.99$',
#   'plus',
#   '5$',
#   'shipping(not',
#   'sure',
#   'if',
#   'it',
#   'was',
#   'intentional).',
#   'Works',
#   'as',
#   'intended.there',
#   'is',
#   'no',
#   'point',
#   'in',
#   'buying',
#   'a',
#   'new',
#   'one',
#   'when',
#   'you',
#   'can',
#   'buy',
#   'used',
#   'one.Works',
#   'and',
#   'very',
#   'cheap'],
#  ['Does',
#   'a',
#   'satisfactory',
#   'job.',
#   'Compatible',
#   'with',
#   'Kent',
#   'State',
#   'University',
#   'systems.Four',
#   'Stars'],
#  ['The',
#   'product',
#   'has',
#   'been',
#   'working',
#   'great,',
#   'and',
#   'really',
#   'appreciate',
#   'the',
#   'fast',
#   'shipping.',
#   'Only',
#   'thing',
#   'was',
#   'that',
#   'the',
#   'product',
#   'came',
#   'in',
#   'without',
#   'working',
#   'batteries.',
#   'So',
#   'hence',
#   'as',
#   'a',
#   'customer',
#   'I',
#   'wasnt',
#   'completely',
#   'satisfied,',
#   'but',
#   'all',
#   'in',
#   'all',
#   'great',
#   'product.Respond',
#   'Card',
#   'XR',
#   'Review'],
#  ['I',
#   'ordered',
#   'a',
#   'turningpoint',
#   'response',
#   'card',
#   'and',
#   'got',
#   'it',
#   'on',
#   'time.',
#   'The',
#   'sender',
#   'sent',
#   'me',
#   'an',
#   'e-mail',
#   'explaining',
#   'why',
#   'he',
#   'had',
#   'to',
#   'ship',
#   'it',
#   'late,',
#   'everything',
#   'was',
#   'convenient.',
#   'Good',
#   'job!Good',
#   '!'],
#  ['THANK',
#   'YOU',
#   'SO',
#   'MUCH',
#   'IT',
#   'WORKS',
#   'LIKE',
#   'A',
#   'CHARMI',
#   'REALLY',
#   'NEEDED',
#   'ITAND',
#   'IT',
#   'WAS',
#   'AT',
#   'A',
#   'LOW',
#   'PRICE',
#   'AND',
#   'WORKS',
#   'PERFECT.COLLEGE'],
#  ['These',
#   'cards',
#   'are',
#   'quality,',
#   'good',
#   'size',
#   'too',
#   'for',
#   'sending',
#   'photos.',
#   'Very',
#   'pleased',
#   'with',
#   'this',
#   'Amazon',
#   'purchase.',
#   'Will',
#   'look',
#   'for',
#   'more',
#   'Sanderson',
#   'products.I',
#   'love',
#   'dandelions.'],
#  ['I',
#   'recently',
#   'purchased',
#   'these',
#   '2',
#   'volumes',
#   'and',
#   'am',
#   'overjoyed',
#   'with',
#   'the',
#   'content.',
#   'William',
#   'Cunningham',
#   'was',
#   'a',
#   'passionate',
#   'scholar',
#   'in',
#   'the',
#   'reformed',
#   'tradition',
#   '(1805-1861)',
#   'who',
#   'shows',
#   'the',
#   'importance',
#   'and',
#   'significance',
#   'of',
#   'many',
#   'essential',
#   'doctrines',
#   'including',
#   'the',
#   'person',
#   'and',
#   'work',
#   'of',
#   'Christ',
#   'and',
#   'the',
#   'heretical',
#   'views',
#   'such',
#   'as',
#   'the',
#   'Arian',
#   'Controversy',
#   'and',
#   'the',
#   'humanitarian',
#   'view',
#   'of',
#   'Socinianism.',
#   'Cunningham',
#   'also',
#   'gives',
#   'ample',
#   'historical',
#   'proof',
#   'of',
#   'the',
#   'early',
#   'church',
#   'fathers',
#   'biblical',
#   'understanding',
#   'of',
#   'God',
#   'as',
#   'Triune,',
#   'and',
#   'exposes',
#   'the',
#   'error',
#   'of',
#   'Sabellianism.',
#   'In',
#   'addition',
#   'several',
#   'other',
#   'doctrines',
#   'of',
#   'grace',
#   'are',
#   'expounded',
#   'including',
#   'the',
#   'radical',
#   'depravity',
#   'of',
#   'man',
#   'after',
#   'the',
#   'fall,',
#   'justification',
#   'and',
#   'the',
#   'perseverance',
#   'of',
#   'the',
#   'saints.',
#   'I',
#   'recommend',
#   'this',
#   'work',
#   'very',
#   'highly.Great',
#   'Resource',
#   'On',
#   'The',
#   'History',
#   'of',
#   'Indispensable',
#   'Christian',
#   'Doctrines'],
#  ['Nice',
#   'calendar,',
#   'nice',
#   'girl,',
#   'but',
#   'I',
#   'thought',
#   'her',
#   'breasts',
#   'were',
#   'better.',
#   'While',
#   'itis',
#   'nice',
#   'to',
#   'see',
#   'real',
#   'natural',
#   'breasts',
#   'I',
#   'thought',
#   'and',
#   'remember',
#   'seeing',
#   'themshaped',
#   'better',
#   'than',
#   'what',
#   'is',
#   'in',
#   'the',
#   'calendar.I',
#   'though',
#   'she',
#   'was',
#   'bigger'],
#  ['High',
#   'quality',
#   'calender,',
#   'very',
#   'sexy,',
#   'perfect',
#   'for',
#   'man',
#   'cave.',
#   'Was',
#   'hoping',
#   'there',
#   'would',
#   'be',
#   'one',
#   'each',
#   'year',
#   'but',
#   'her',
#   'time',
#   'must',
#   'have',
#   'come',
#   'and',
#   'gone',
#   'as',
#   'this',
#   'was',
#   'the',
#   'only',
#   'year.Stormy',
#   'Daniels',
#   'Calender'],
#  ['If',
#   'you',
#   'like',
#   'real',
#   'men',
#   "you'll",
#   'love',
#   'this',
#   'calendar.',
#   'The',
#   'images',
#   'are',
#   'awesome',
#   'and',
#   'the',
#   'Bear',
#   'Events',
#   'listed',
#   'by',
#   'each',
#   'month',
#   'will',
#   'be',
#   'an',
#   'indispensible',
#   'reference',
#   'throughout',
#   'the',
#   'year.',
#   'I',
#   'actually',
#   'bought',
#   '5',
#   'of',
#   'these',
#   'calendars.',
#   'One',
#   'for',
#   'me',
#   'and',
#   'the',
#   'others',
#   'I',
#   'will',
#   'give',
#   'to',
#   'friends.',
#   "I'm",
#   'sure',
#   "they'll",
#   'love',
#   'it',
#   'as',
#   'much',
#   'as',
#   'I',
#   'do.',
#   '2009',
#   'Bear',
#   'Hunter',
#   'CalendarBest',
#   'Bear',
#   'Calendar',
#   'out',
#   'there!'],
#  ['I',
#   'almost',
#   'gave',
#   'up',
#   'waiting',
#   'for',
#   'this',
#   'calendar',
#   'to',
#   'be',
#   'delivered,',
#   'two',
#   'weeks!!But...it',
#   'was',
#   'worth',
#   'it!Pleased!!!!!!!!!!!!!!!!!!!!!'],
#  ['THIS',
#   'IS',
#   'NO',
#   'CALENDAR',
#   'OF',
#   'TWINKIES.',
#   'THESE',
#   'ARE',
#   'REAL',
#   'MEN......HUSKY',
#   'AND',
#   'HAIRY.',
#   'I',
#   'PURCHASED',
#   'THIS',
#   'AS',
#   'A',
#   'GIFT',
#   'BUT',
#   'HAVE',
#   'DECIDED',
#   'TO',
#   'KEEP',
#   'IT~',
#   'I',
#   'ORDERED',
#   'HIM',
#   'ANOTHER........THE',
#   '2XX',
#   'BEAR',
#   'CALENDAR.',
#   'BEST',
#   'HOLIDAY',
#   'WISHES',
#   'FROM',
#   'DENNISTHEMENACE48',
#   'ON',
#   'EBAY..........DENNISBE',
#   'STILL',
#   'MY',
#   'FOOLISH',
#   'HEART!'],
#  ['the',
#   'quality',
#   'of',
#   'this',
#   'calendar',
#   'is',
#   'great;',
#   'aside',
#   'from',
#   'the',
#   'very',
#   'masculine',
#   'handsome',
#   'men',
#   'featured',
#   'each',
#   'month:',
#   'the',
#   'size',
#   'of',
#   'the',
#   'pages',
#   'and',
#   'pictures',
#   'themselves',
#   'is',
#   'a',
#   'nice',
#   'larger',
#   'than',
#   'usual',
#   'size',
#   '(to',
#   'at',
#   'least',
#   'jot',
#   'notes',
#   'and',
#   'important',
#   'dates',
#   'on);',
#   'and',
#   'the',
#   'quality',
#   'of',
#   'the',
#   'paper',
#   'and',
#   'the',
#   'photo',
#   'prints',
#   'is',
#   'great.',
#   'a',
#   'great',
#   'calendar,',
#   'a',
#   'great',
#   'value',
#   ',',
#   'and',
#   'very',
#   'hot',
#   'mengreat',
#   'calendar',
#   'of',
#   'REAL',
#   'men'],
#  ['Out',
#   'of',
#   'the',
#   '13',
#   'models,',
#   'only',
#   'one',
#   'fails',
#   'to',
#   'do',
#   'anything',
#   'for',
#   'me;',
#   'that',
#   'says',
#   'something',
#   'right',
#   'there.',
#   'The',
#   'models',
#   'are',
#   'older',
#   'than',
#   'the',
#   'usual,',
#   'from',
#   'late',
#   "30's",
#   'and',
#   'up.',
#   'Poses',
#   'are',
#   'relaxed',
#   'and',
#   'natural.',
#   'The',
#   'models',
#   'themselves',
#   'look',
#   'natural,',
#   'not',
#   'excessively',
#   'clipped,',
#   'styled,',
#   'or',
#   'coiffed.',
#   'Fair',
#   'warning',
#   'to',
#   'those',
#   'buying',
#   'this',
#   'as',
#   'a',
#   'gift:',
#   '"Bears"',
#   'means',
#   'real',
#   'men',
#   'with',
#   'a',
#   'lot',
#   'of',
#   'body',
#   'hair',
#   '-',
#   'no',
#   'waxing',
#   'here!',
#   'As',
#   'long',
#   'as',
#   "that's",
#   'what',
#   "you're",
#   'looking',
#   'for,',
#   'you',
#   "won't",
#   'be',
#   'disappointed.I',
#   'only',
#   'wish',
#   'Amazon',
#   'would',
#   'provide',
#   'thumbnails',
#   'of',
#   'the',
#   'models',
#   'so',
#   'buyers',
#   'could',
#   'see',
#   'exactly',
#   'what',
#   'they',
#   'were',
#   'getting.Well',
#   'worth',
#   'the',
#   'money'],
#  ['While',
#   'not',
#   'every',
#   'model',
#   'is',
#   'what',
#   'I',
#   'call',
#   'a',
#   'bear',
#   '-',
#   'in',
#   'fact',
#   'March',
#   'is',
#   'completely',
#   'hairless',
#   '-',
#   'but',
#   'his',
#   'other',
#   'endowments',
#   'do',
#   'compensate...very',
#   'satisfied',
#   'overall.',
#   'Nice',
#   'variety',
#   'of',
#   'shapes',
#   'and',
#   'looks.',
#   'Great',
#   'service',
#   'from',
#   'Amazon',
#   'provider',
#   'also.woof',
#   'woof',
#   'woof'],
#  ['This',
#   'is',
#   'the',
#   '3rd',
#   'time',
#   "I've",
#   'ordered',
#   'an',
#   'Oregon',
#   'calendar',
#   'created',
#   'by',
#   'Steve',
#   'Terrill.',
#   'They',
#   'are',
#   'beautiful',
#   'and',
#   'remind',
#   'me',
#   'of',
#   'many',
#   'of',
#   'the',
#   'places',
#   "I've",
#   'visited',
#   'and',
#   'still',
#   'have',
#   'to',
#   'visit.I',
#   'received',
#   'a',
#   'nice',
#   'thank',
#   'you',
#   'note',
#   'from',
#   'Steve',
#   'with',
#   'my',
#   'latest',
#   'order',
#   'and',
#   'a',
#   'free',
#   'copy',
#   'of',
#   'his',
#   'coastal',
#   'Oregon',
#   'calendar.',
#   'I',
#   'will',
#   'continue',
#   'to',
#   'order',
#   'these',
#   'calendars',
#   'every',
#   'year.Thank',
#   'you',
#   'Steve!!!Steve',
#   "Terrill's",
#   'Oregon',
#   'Calendars'],
#  ['One',
#   'of',
#   'the',
#   'nicest',
#   'picture',
#   'calenders',
#   'of',
#   'Oregon.',
#   'He',
#   'does',
#   'a',
#   'nice',
#   'job',
#   'every',
#   'year.',
#   'Now',
#   'that',
#   'I',
#   'live',
#   'away',
#   'I',
#   'can',
#   'get',
#   'a',
#   'little',
#   '&#34;fix&#34;',
#   'of',
#   'Oregon',
#   'with',
#   'this',
#   'calender.Nice',
#   'calender'],
#  ['First',
#   'I',
#   'want',
#   'to',
#   'state',
#   'that',
#   'this',
#   'is',
#   'a',
#   'review',
#   'of',
#   'the',
#   'product',
#   'and',
#   'not',
#   'the',
#   'seller.',
#   'However',
#   'the',
#   'price',
#   'printed',
#   'on',
#   'the',
#   'back',
#   'is',
#   '$1',
#   'so',
#   'maybe',
#   'the',
#   'seller',
#   'is',
#   'in',
#   'need',
#   'of',
#   'review.This',
#   'calendar',
#   'is',
#   'not',
#   'that',
#   'great,',
#   "it's",
#   'printed',
#   'on',
#   'very',
#   'thin',
#   'paper',
#   'just',
#   'a',
#   'bit',
#   'thicker',
#   'than',
#   'copy',
#   "paper.It's",
#   'sold',
#   'as',
#   'a',
#   '16',
#   'month',
#   'calendar',
#   'so',
#   'you',
#   'are',
#   'excited',
#   'to',
#   'see',
#   'pictures',
#   'of',
#   '16',
#   'cute',
#   'kittens.',
#   'There',
#   'are',
#   'only',
#   '12',
#   'kitten',
#   'pictures',
#   'in',
#   'here!!!!',
#   'One',
#   'kitten',
#   'for',
#   'each',
#   'month,',
#   'the',
#   'cover',
#   'kitten',
#   'is',
#   'reused',
#   'for',
#   'February.',
#   'The',
#   'first',
#   'four',
#   'month',
#   'of',
#   '2013',
#   'are',
#   'crammed',
#   'on',
#   'the',
#   'last',
#   'page',
#   'with',
#   'no',
#   'kitten',
#   'pictures.Not',
#   'quite',
#   '16',
#   'months'],
#  ['I',
#   'ordered',
#   'this',
#   'from',
#   'bestbookscfa,',
#   'and',
#   'the',
#   'delivery',
#   'was',
#   'very',
#   'prompt.',
#   'This',
#   'is',
#   'such',
#   'a',
#   'great',
#   'bargain',
#   'for',
#   'my',
#   'money,',
#   'and',
#   'it',
#   'came',
#   'with',
#   'LOTS',
#   'of',
#   'study',
#   'materials',
#   'to',
#   'help',
#   'me',
#   'pursue',
#   'the',
#   'CFA.',
#   'I',
#   'went',
#   'through',
#   'each',
#   'pdf',
#   '(including',
#   'the',
#   '6',
#   'bonus',
#   'material',
#   'sets,',
#   'which',
#   'was',
#   'more',
#   'than',
#   'I',
#   'was',
#   'expecting)',
#   'to',
#   'make',
#   'sure',
#   'all',
#   'the',
#   'pages',
#   'were',
#   'there,',
#   'and',
#   'nothing',
#   'seems',
#   'to',
#   'be',
#   'missing',
#   "(they're",
#   'each',
#   'about',
#   '300-400+',
#   'pages',
#   'of',
#   'materials).',
#   'I',
#   'really',
#   'appreciate',
#   'this',
#   'because',
#   'it',
#   'allows',
#   'me',
#   'to',
#   'study',
#   'on',
#   'my',
#   'Kindle',
#   'while',
#   'I',
#   'commute',
#   'to',
#   'and',
#   'from',
#   'work.',
#   'Note:',
#   "I'm",
#   'currently',
#   'studying',
#   'for',
#   'level',
#   'one,',
#   'but',
#   'wanted',
#   'some',
#   'insight',
#   'to',
#   'the',
#   'difference',
#   'in',
#   'level',
#   'two,',
#   'so',
#   'I',
#   'bought',
#   'both',
#   'levels',
#   'from',
#   'bestbookscfa.',
#   "I'll",
#   'leave',
#   'my',
#   'review',
#   'for',
#   'the',
#   'level',
#   'one',
#   'materials',
#   'on',
#   'that',
#   'product',
#   'site,',
#   'which',
#   'will',
#   'be',
#   'just',
#   'as',
#   'positive.',
#   'If',
#   'level',
#   'three',
#   'was',
#   'available',
#   "I'd",
#   'purchase',
#   'that',
#   'also.',
#   'If',
#   'I',
#   'remember,',
#   "I'll",
#   'come',
#   'back',
#   'and',
#   'post',
#   'whether',
#   'this',
#   'helps',
#   'me',
#   'pass',
#   'the',
#   'exam',
#   'next',
#   'year.Very',
#   'happy',
#   'customer!'],
#  ['CDs',
#   'include',
#   'all',
#   'Schweser',
#   'written',
#   'notes',
#   'in',
#   'PDF',
#   'form',
#   'but',
#   'every',
#   'page',
#   'is',
#   'stenciled',
#   'with',
#   'an',
#   'international',
#   'phone',
#   'numer',
#   'as',
#   'the',
#   'source',
#   'was',
#   'copy',
#   'protected.Useable'],
#  ['I',
#   'love',
#   'my',
#   'WICKED',
#   'calendar!!',
#   'I',
#   'would',
#   'buy',
#   'one',
#   'from',
#   'here',
#   'every',
#   'year',
#   'as',
#   'the',
#   'service',
#   'was',
#   'stellar',
#   ':)So,',
#   'so',
#   'happy!!'],
#  ['This',
#   'is',
#   'a',
#   'super',
#   'great',
#   'planner!',
#   'I',
#   'love',
#   'Wicked',
#   'so',
#   'much,',
#   'and',
#   'it',
#   'has',
#   'tons',
#   'of',
#   'great',
#   'pictures',
#   'and',
#   'tons',
#   'of',
#   'space',
#   'for',
#   'you',
#   'to',
#   'write',
#   'down',
#   'your',
#   'business.',
#   'I',
#   'expected',
#   'more',
#   'pictures',
#   'of',
#   'Idena',
#   'Menzel',
#   'and',
#   'Kristin',
#   'Chenoweth',
#   '(there',
#   'are',
#   'only',
#   'one)',
#   'but',
#   'whatever.',
#   "I'll",
#   'live.AMAZING'],
#  ['I',
#   'recieved',
#   'this',
#   'for',
#   'christmas',
#   'and',
#   'love',
#   'it.',
#   'The',
#   'pictures',
#   'inside',
#   'are',
#   'full',
#   'color',
#   'and',
#   'great.',
#   'There',
#   'is',
#   'enough',
#   'space',
#   'to',
#   'write',
#   'your',
#   'appointments',
#   'and',
#   'dates',
#   'in.',
#   'My',
#   'question',
#   'is',
#   'this......',
#   'why',
#   'is',
#   'amazon',
#   'selling',
#   'this',
#   'book',
#   'for',
#   '$57',
#   'when',
#   'the',
#   'back',
#   'of',
#   'the',
#   'book',
#   'by',
#   'the',
#   'price',
#   'shown',
#   'at',
#   'the',
#   'ISBN#',
#   'is',
#   'U.S.',
#   '$14.95?good',
#   'book',
#   'odd',
#   'price'],
#  ['Is',
#   'a',
#   'nice',
#   'looking',
#   'bookmark',
#   'that',
#   'shows',
#   'the',
#   'cover',
#   'of',
#   'the',
#   'book',
#   'that',
#   'inspire',
#   'it.Twilight',
#   'New',
#   'Moon',
#   'Book',
#   'Cover-',
#   'Stephenie',
#   'Meyer',
#   'Bookmark'],
#  ['I',
#   'ordered',
#   'this',
#   'little',
#   'book',
#   'to',
#   'keep',
#   'a',
#   'record',
#   'of',
#   'everything',
#   'in',
#   'my',
#   'life',
#   'all',
#   'in',
#   'one',
#   'place.',
#   'I',
#   'had',
#   'one',
#   'that',
#   'was',
#   'a',
#   'dayplanner',
#   'and',
#   'carried',
#   'it',
#   'in',
#   'my',
#   'bag',
#   'everywhere',
#   'for',
#   'a',
#   'year.',
#   'The',
#   'pages',
#   'are',
#   'acid-free,',
#   'the',
#   'magnetic',
#   'latch',
#   'is',
#   'still',
#   'in',
#   'great',
#   'condition',
#   'as',
#   'is',
#   'the',
#   'cover.',
#   "I'm",
#   'buying',
#   'more',
#   'of',
#   'these',
#   'for',
#   'gifts.',
#   'I',
#   'highly',
#   'recommend',
#   'this',
#   'book.Beautiful',
#   'Book'],
#  ['This',
#   'item',
#   'is',
#   'lined,',
#   'and',
#   'it',
#   'does',
#   'not',
#   'say',
#   'that',
#   'in',
#   'the',
#   'product',
#   'description.',
#   'I',
#   'had',
#   'wanted',
#   'a',
#   'blank',
#   'notebook,',
#   'so',
#   'more',
#   'detail',
#   'in',
#   'the',
#   'description',
#   'would',
#   'have',
#   'been',
#   'great.More',
#   'detail'],
#  ['Paperblanks',
#   'Dayplanner-Mini-Foiled-Day',
#   'at',
#   'a',
#   'TimeThis',
#   'was',
#   'a',
#   'gift',
#   'for',
#   'someone',
#   'else',
#   '-',
#   'a',
#   'yearly',
#   'update/replacement.',
#   'This',
#   'is',
#   'just',
#   'the',
#   'right',
#   'format,',
#   'with',
#   'a',
#   'different',
#   'pattern',
#   'on',
#   'the',
#   'cover.',
#   "That's",
#   'something',
#   'that',
#   'Paperblanks',
#   'changes',
#   'from',
#   'year',
#   'to',
#   'year.',
#   'And',
#   'there',
#   'are',
#   'many',
#   'size',
#   'and',
#   'format',
#   'options,',
#   'so',
#   'it',
#   'took',
#   'a',
#   'while',
#   'to',
#   'find',
#   'what',
#   'I',
#   'wanted',
#   'with',
#   'a',
#   'suitable',
#   'cover.',
#   'That',
#   'I',
#   'did',
#   'through',
#   'an',
#   'Amazon',
#   'store,',
#   'and',
#   'the',
#   'service',
#   'was',
#   'good',
#   '-',
#   'I',
#   'received',
#   'it',
#   'quickly',
#   'and',
#   'in',
#   'time',
#   'for',
#   'Christmas',
#   'giving.',
#   'Paperblanks',
#   'products',
#   'are',
#   'of',
#   'impeccable',
#   'quality',
#   'and',
#   'worth',
#   'the',
#   'search.Review:',
#   'Paperblanks',
#   'Dayplanner-Mini-Foiled-Day',
#   'at',
#   'a',
#   'Time'],
#  ['This',
#   'is',
#   'my',
#   'second',
#   'paperblanks',
#   'diary',
#   'and',
#   'I',
#   'was',
#   'not',
#   'disappointed.',
#   'The',
#   'diary',
#   'is',
#   'very',
#   'functional',
#   'and',
#   'really',
#   'meets',
#   'my',
#   'everyday',
#   'work',
#   'needs.',
#   'The',
#   'diary',
#   'is',
#   'big',
#   'enough',
#   'for',
#   'me',
#   'to',
#   'put',
#   'all',
#   'my',
#   'appointments',
#   'into',
#   'it',
#   'but',
#   'also',
#   'small',
#   'enough',
#   'for',
#   'me',
#   'to',
#   'fit',
#   'into',
#   'my',
#   'hand',
#   'bag.',
#   'It',
#   'is',
#   'also',
#   'not',
#   'very',
#   'heavy.',
#   'I',
#   'love',
#   'the',
#   'design',
#   'on',
#   'the',
#   'front',
#   'and',
#   'my',
#   'colleagues',
#   'asked',
#   'me',
#   'where',
#   'I',
#   'bought',
#   'it',
#   'from',
#   'when',
#   'I',
#   'initally',
#   'bought',
#   'it.Lovely',
#   'diary'],
#  ['This',
#   'makes',
#   'a',
#   'wonderful,',
#   'classy',
#   'gift!',
#   'It',
#   'was',
#   'very',
#   'well',
#   'received',
#   'as',
#   'a',
#   'birthday',
#   'gift',
#   'by',
#   'the',
#   'women',
#   'I',
#   'gave',
#   'it',
#   'to.Beautiful',
#   'classy',
#   'journal.'],
#  ['I',
#   'love',
#   'how',
#   'unique',
#   'this',
#   'journal',
#   'is,',
#   'and',
#   'for',
#   'any',
#   'who',
#   'love',
#   'to',
#   'write',
#   'by',
#   'hand,',
#   "I'd",
#   'highly',
#   'recommend',
#   'this',
#   'one.',
#   "It's",
#   'not',
#   'like',
#   'anything',
#   "I've",
#   'seen',
#   'before,',
#   'and',
#   'that',
#   'appealed',
#   'to',
#   'me.Unique',
#   'and',
#   'gorgeous'],
#  ['Placed',
#   'in',
#   'my',
#   'wallet',
#   'and',
#   'is',
#   'so',
#   'convenient,',
#   'I',
#   'love',
#   'the',
#   'design',
#   'I',
#   'only',
#   'wish',
#   'it',
#   'maybe',
#   'was',
#   'plastic',
#   'wrapped',
#   'instead',
#   'of',
#   'plain',
#   'paper',
#   'but',
#   'I',
#   'still',
#   'love',
#   'it...Marilyn',
#   'lover'],
#  ['I',
#   'was',
#   'a',
#   'bit',
#   'disappointed',
#   'in',
#   'this',
#   'book.',
#   'I',
#   'expected',
#   'more',
#   'complex',
#   'and',
#   'well',
#   'planned',
#   'hands-on',
#   'lessons,',
#   'but',
#   'most',
#   'of',
#   'what',
#   'is',
#   'in',
#   'here',
#   'has',
#   'been',
#   'in',
#   'numerous',
#   'other',
#   'math',
#   'books',
#   'for',
#   'teachers.',
#   "It's",
#   'not',
#   'bad,',
#   'just',
#   'a',
#   'bit',
#   'too',
#   'basic',
#   'and',
#   'many',
#   '&#34;recycled&#34;',
#   'ideas.',
#   'I',
#   'expected',
#   'more.Was',
#   'expecting',
#   'more'],
#  ['This',
#   'is',
#   'a',
#   'very',
#   'helpful',
#   'resource',
#   'for',
#   'any',
#   'teacher',
#   'of',
#   'math',
#   'or',
#   'special',
#   'education.',
#   'I',
#   'highly',
#   'recommend',
#   'purchasing',
#   'the',
#   'version',
#   'related',
#   'to',
#   'your',
#   'grade',
#   'and',
#   'possibly',
#   'going',
#   'one',
#   'up',
#   'or',
#   'one',
#   'down',
#   'for',
#   'extension',
#   'or',
#   'intervention',
#   'ideas.Very',
#   'helpful',
#   'for',
#   'teachers'],
#  ['Good',
#   'street',
#   'level',
#   'map',
#   'of',
#   'the',
#   'Hillsbough',
#   'county',
#   'area.',
#   'While',
#   'there',
#   'are',
#   'also',
#   'paper',
#   'fold',
#   'up',
#   'maps',
#   'for',
#   'the',
#   'car,',
#   'this',
#   'is',
#   'a',
#   'small',
#   'book',
#   'form.Tampa',
#   '&',
#   'Hillbough',
#   'street',
#   'map'],
#  ['I',
#   'love',
#   'this',
#   'calander,',
#   'I',
#   'plans',
#   'to',
#   'use',
#   'the',
#   'pictures',
#   'instead',
#   'of',
#   'table',
#   'numbers',
#   'at',
#   'my',
#   'wedding.Love',
#   'it!'],
#  ['I',
#   'was',
#   'pleased',
#   'with',
#   'the',
#   'look',
#   'of',
#   'this',
#   'product.',
#   'Only',
#   'drawback',
#   'was',
#   'that',
#   'I',
#   'thought',
#   'the',
#   'paper',
#   'could',
#   'have',
#   'been',
#   'a',
#   'little',
#   'thicker',
#   'and',
#   'sturdier.Pleased'],
#  ['Love',
#   'this',
#   'calemdar.',
#   'The',
#   'space',
#   'between',
#   'the',
#   'lines',
#   'are',
#   'perfect.',
#   'This',
#   'was',
#   'a',
#   'gift',
#   'for',
#   'my',
#   'elderly',
#   'sister',
#   'in',
#   'law,',
#   'and',
#   'she',
#   'loves',
#   'it.Perfect',
#   'Calendar'],
#  ['This',
#   'perpetual',
#   'calendar',
#   'is',
#   'beautiful.',
#   "It's",
#   'slender',
#   'and',
#   'long,',
#   'so',
#   'it',
#   'easily',
#   'fits',
#   'into',
#   'small',
#   'spaces,',
#   'even',
#   'if',
#   'you',
#   'want',
#   'to',
#   'hang',
#   'it',
#   'inside',
#   'your',
#   'pantry',
#   'on',
#   'the',
#   'side',
#   'wall!',
#   "It's",
#   'easy',
#   'to',
#   'flip',
#   'through',
#   'the',
#   'pages',
#   'to',
#   'see',
#   'the',
#   'upcoming',
#   'birthdays',
#   'and',
#   'anniversaries.',
#   "There's",
#   'plenty',
#   'of',
#   'room',
#   'for',
#   'writing,',
#   'too.',
#   "I've",
#   'given',
#   'this',
#   'as',
#   'a',
#   'gift',
#   'which',
#   'was',
#   'well',
#   'received,',
#   'and',
#   "I'm",
#   'ordering',
#   'another',
#   'for',
#   'myself!Beautiful,',
#   'Slender,',
#   'Functional'],
#  ['These',
#   'are',
#   'the',
#   'best',
#   'birthday',
#   'calenders',
#   'since',
#   'sliced',
#   'bread.',
#   'I',
#   'not',
#   'only',
#   'use',
#   'them',
#   'for',
#   'birthdays',
#   'but',
#   'also',
#   'for',
#   '&#34;events&#34;',
#   'and',
#   'very',
#   'special',
#   'days',
#   'I',
#   'want',
#   'to',
#   'remember.',
#   'I',
#   'gave',
#   'some',
#   'as',
#   'a',
#   'gift',
#   'also',
#   'and',
#   'they',
#   'were',
#   'so',
#   'happy',
#   'had',
#   'never',
#   'seen',
#   'them',
#   'before.These',
#   'are',
#   'the',
#   'best',
#   'birthday',
#   'calenders',
#   'since',
#   'sliced',
#   'bread'],
#  ['The',
#   'spiral',
#   'binding',
#   'on',
#   'this',
#   'calendar',
#   'holds',
#   'the',
#   '12',
#   'calendar',
#   'pages',
#   'so',
#   'that',
#   'they',
#   'are',
#   'slightly',
#   'offset',
#   'and',
#   'not',
#   'neatly',
#   'stacked',
#   'on',
#   'each',
#   'other.',
#   'Therefore,',
#   'when',
#   'hanging',
#   'the',
#   'calendar,',
#   'the',
#   'pages',
#   "don't",
#   'line',
#   'up',
#   'with',
#   'each',
#   'other.',
#   'Calendar',
#   'is',
#   'still',
#   'usable',
#   'but',
#   'looks',
#   'messy.',
#   'Also,',
#   'when',
#   'shipped,',
#   'the',
#   'company',
#   'used',
#   'a',
#   'very',
#   'large',
#   'box',
#   '(unnecessary)',
#   'and',
#   'too',
#   'much',
#   'packing',
#   'material',
#   'which',
#   'is',
#   'a',
#   'wasteful',
#   'use',
#   'of',
#   'trees',
#   'and',
#   'energy',
#   'to',
#   'make',
#   'the',
#   'box.Binding',
#   'of',
#   'poor',
#   'quality'],
#  ['Perputual',
#   'calendar',
#   '---',
#   'just',
#   'what',
#   'I',
#   'wanted.',
#   'No',
#   'years,',
#   'just',
#   'months',
#   'and',
#   'dates',
#   '(one',
#   'month',
#   'per',
#   'page)',
#   'Great',
#   'for',
#   'hanging',
#   'on',
#   'the',
#   'wall',
#   'and',
#   'reminding',
#   'you',
#   'of',
#   'important',
#   'dates',
#   'to',
#   'remember.',
#   'IE',
#   'birthdays,',
#   'anniversary,',
#   'special',
#   'occasions',
#   '(graduation,',
#   'bar/bat',
#   "mitzvah's)",
#   'super',
#   'buy.',
#   'I',
#   'bought',
#   'a',
#   'few',
#   'and',
#   'am',
#   'using',
#   'them',
#   'as',
#   'gifts.Perputual',
#   'calendar'],
#  ['There',
#   'is',
#   'a',
#   'newer,',
#   '2011,',
#   'edition',
#   'of',
#   'this',
#   'map',
#   'now',
#   'available.',
#   'Please',
#   'see',
#   'the',
#   'new',
#   'edition',
#   'on',
#   'Amazon',
#   'atHilton',
#   'Head',
#   'and',
#   'Beaufort',
#   'Street',
#   'MapA',
#   'newer',
#   'edition',
#   'is',
#   'available'],
#  ['Probably',
#   'one',
#   'of',
#   'the',
#   'best',
#   'gifts',
#   'I',
#   'have',
#   'ever',
#   'given',
#   'my',
#   'mom...actually',
#   'got',
#   'the',
#   'Knock',
#   'Knock',
#   '&#34;Awesome&#34;',
#   'book',
#   'for',
#   'my',
#   'dad',
#   'and',
#   'he',
#   'loved',
#   'it',
#   'as',
#   'well...',
#   'Great',
#   'gift',
#   '-',
#   'especially',
#   'to',
#   'give',
#   'something',
#   'a',
#   'little',
#   'different,',
#   'and',
#   'much',
#   'better',
#   'than',
#   'just',
#   'a',
#   'card.Love!'],
#  ['I',
#   'purchased',
#   'a',
#   'few',
#   'calendars',
#   'for',
#   'a',
#   'few',
#   'buddies',
#   'of',
#   'mine.',
#   'I',
#   'liked',
#   'the',
#   'calendar',
#   'so',
#   'much',
#   'I',
#   'think',
#   'I',
#   'am',
#   'going',
#   'to',
#   'buy',
#   'some',
#   'more',
#   'including',
#   'one',
#   'for',
#   'me.',
#   'I',
#   'hope',
#   'Rootsrock',
#   'comes',
#   'out',
#   'with',
#   'some',
#   'other',
#   'content',
#   'like',
#   'video',
#   'footage',
#   'or',
#   'something',
#   'because',
#   'I',
#   "can't",
#   'get',
#   'enough',
#   'of',
#   'these',
#   'girls!',
#   'I',
#   'can',
#   'only',
#   'imagine',
#   "what's",
#   'in',
#   'store',
#   'for',
#   'the',
#   'Ladies',
#   'of',
#   'the',
#   'Caribbean',
#   '-',
#   '2009',
#   'calendar.I',
#   'recommend',
#   'this',
#   'calendar',
#   'as',
#   'a',
#   'holiday',
#   'gift,',
#   '5',
#   'stars!!!!ChrisGreat',
#   'Calendar!',
#   'Nice',
#   'shots',
#   'of',
#   'high',
#   'quality,',
#   'hot',
#   'girls,',
#   'a',
#   'good',
#   'holiday',
#   'gift',
#   'idea.'],
#  ['I',
#   'have',
#   'this',
#   'calendar,',
#   'and',
#   'it',
#   'is',
#   'unbelievable.',
#   'Guys,',
#   "let's",
#   'face',
#   'it,',
#   'Caribbean',
#   'women',
#   "aren't",
#   'exactly',
#   'well',
#   'represented',
#   'in',
#   'the',
#   'fashion',
#   'world.',
#   'If',
#   "that's",
#   'what',
#   "you're",
#   'looking',
#   'for,',
#   'this',
#   "calendar's",
#   'got',
#   'it.',
#   'These',
#   'girls',
#   'are',
#   'hot.Wow!'],
#  ['This',
#   'is',
#   'totally',
#   'a',
#   'hot',
#   'calendar.',
#   'Beautiful',
#   'black',
#   'and',
#   'latin',
#   'women.',
#   'Never',
#   'seen',
#   'anything',
#   'like',
#   'this',
#   'before!',
#   'Rootsrock',
#   'is',
#   'giving',
#   'SI',
#   'a',
#   'run',
#   'for',
#   'its',
#   'money.',
#   'I',
#   'have',
#   'both',
#   'this',
#   'the',
#   'SI',
#   'calendar,',
#   'but',
#   'this',
#   'one',
#   'is',
#   'going',
#   'on',
#   'my',
#   'wall...',
#   'no',
#   'doubt!2008',
#   'Ladies',
#   'of',
#   'the',
#   'Caribbean'],
#  ['If',
#   'you',
#   'want',
#   'to',
#   'look',
#   'at',
#   'gorgeous',
#   'ladies',
#   'year',
#   'round',
#   'BUY',
#   'THIS',
#   'CALENDAR',
#   'you',
#   "won't",
#   'regret',
#   'it.MISS',
#   'FEB.',
#   '2008Best',
#   'Calendar',
#   'Ever!'],
#  ['Roots',
#   'Rock',
#   'Inc',
#   'has',
#   'put',
#   'together',
#   'an',
#   'amazing',
#   'Calendar',
#   'showing',
#   'the',
#   'beauty',
#   'of',
#   'women',
#   'from',
#   'the',
#   'Caribbean.',
#   'It',
#   'has',
#   'a',
#   'stunning',
#   'collection',
#   'of',
#   'images',
#   'with',
#   'gorgeous',
#   'girls',
#   'representing',
#   'the',
#   'diversity',
#   'of',
#   'the',
#   'Carribean.',
#   'There',
#   'is',
#   'something',
#   'for',
#   'everyone',
#   'in',
#   'this',
#   'calendar.',
#   'I',
#   'reccomend',
#   'it',
#   'as',
#   'a',
#   'gift',
#   'or',
#   'just',
#   'a',
#   'collectors',
#   'item',
#   'for',
#   'everyone.',
#   'If',
#   'you',
#   'know',
#   'someone',
#   'who',
#   'loves',
#   'exotic',
#   'women,',
#   'it',
#   "doesn't",
#   'get',
#   'any',
#   'better',
#   'than',
#   'this',
#   'calendar.-',
#   'Alicia',
#   'the',
#   '"cover',
#   'girl"',
#   'representing',
#   'the',
#   'Island',
#   'of',
#   'Jamaica.The',
#   'Beauty',
#   'of',
#   'the',
#   'Caribbean',
#   'from',
#   'the',
#   'Cover',
#   'Girl'],
#  ['Great,',
#   'quick,',
#   'service.',
#   'The',
#   'calendar',
#   'exceeded',
#   'the',
#   'expectations',
#   'of',
#   'my',
#   'daughter,',
#   'who',
#   'is',
#   'a',
#   'devoted',
#   'and',
#   'accomplished',
#   'high',
#   'school',
#   'runner',
#   '(cross-country,',
#   'indoor,',
#   'and',
#   'outdoor',
#   'track).',
#   'She',
#   'plans',
#   'to',
#   'continue',
#   'running',
#   'at',
#   'the',
#   'college',
#   'level,',
#   'and',
#   'this',
#   'calendar',
#   'was',
#   'at',
#   'the',
#   'top',
#   'of',
#   'her',
#   'Christmas',
#   'list.',
#   'She',
#   'likes',
#   'the',
#   'large',
#   'size',
#   'of',
#   'the',
#   'calendar,',
#   'the',
#   'scenic',
#   'and',
#   'inspiring',
#   'pictures,',
#   'and',
#   'all',
#   'the',
#   '"extras",',
#   'especially',
#   'the',
#   'training',
#   'and',
#   'motivational',
#   'tips.Great',
#   'Buy'],
#  ['The',
# ...
#   'on',
#   'Clickbook.Just',
#   'like',
#   'Quark'],
#  ['My',
#   'daughter',
#   'uses',
#   'this',
#   'and',
#   'is',
#   'developing',
#   'great',
#   'financial',
#   'skills.',
#   'It',
#   'encourages',
#   'her',
#   'to',
#   'save',
#   'and',
#   "she's",
#   'learning',
#   'that',
#   'money',
#   "doesn't",
#   'grow',
#   'on',
#   'trees.I',
#   'wish',
#   "I'd",
#   'had',
#   'this',
#   'as',
#   'a',
#   'child'],
#  ['My',
#   'daughter',
#   'received',
#   'Money',
#   'and',
#   'Me',
#   'as',
#   'a',
#   'birthday',
#   'present,',
#   'and',
#   'it',
#   'was',
#   'her',
#   'favorite',
#   'right',
#   'away.',
#   'She',
#   'already',
#   'has',
#   'a',
#   'babysitting',
#   'business,',
#   'and',
#   'this',
#   'journal',
#   'will',
#   'really',
#   'help',
#   'her',
#   'get',
#   'organized.',
#   'She',
#   'loves',
#   'the',
#   'calculator,',
#   'too.Fun',
#   'and',
#   'responsibility',
#   'all',
#   'in',
#   'one'],
#  ['I',
#   'love',
#   'these',
#   'things!',
#   'Get',
#   'your',
#   'marketing',
#   'message',
#   'in',
#   'front',
#   'of',
#   'your',
#   'customers',
#   'every',
#   'day.',
#   'I',
#   'created',
#   '"get',
#   'a',
#   'grip',
#   'on',
#   'your',
#   'banking',
#   'needs"',
#   'theme.',
#   'These',
#   'are',
#   'the',
#   'perfect',
#   'carry-all',
#   'to',
#   'help',
#   'your',
#   'customers',
#   '(and',
#   'potential',
#   'customers)',
#   'carry',
#   'their',
#   'things.',
#   'Finally,',
#   'a',
#   'promo',
#   'item',
#   'that',
#   'is',
#   'NOT',
#   'a',
#   'pen!',
#   'Thanks.',
#   '--MargePerfect',
#   'promo',
#   'and',
#   'gift',
#   'item',
#   'for',
#   'my',
#   'company!'],
#  ['Many',
#   'fell',
#   'apart',
#   'just',
#   'taking',
#   'them',
#   'out',
#   'of',
#   'their',
#   'package',
#   'or',
#   'tore',
#   'just',
#   'opening',
#   'them',
#   'up',
#   'for',
#   'use.',
#   'You',
#   'best',
#   'go',
#   'with',
#   'a',
#   'higher',
#   'quality.',
#   'These',
#   'were',
#   'a',
#   'waste',
#   'or',
#   'resources.NOT',
#   'WHAT',
#   'YOU',
#   'WANT'],
#  ['I',
#   'have',
#   'not',
#   'actually',
#   'used',
#   'this',
#   'product',
#   'since',
#   'I',
#   'have',
#   'not',
#   'gotten',
#   'a',
#   'required',
#   'top',
#   'piece.',
#   'Accompanying',
#   'products',
#   'should',
#   'be',
#   'included.Extentable',
#   'pole',
#   'needs',
#   'a',
#   'top',
#   'piece',
#   'to',
#   'perform'],
#  ['This',
#   'product',
#   'was',
#   'exactly',
#   'what',
#   'my',
#   'husband',
#   'was',
#   'wanting',
#   'and',
#   'the',
#   'price',
#   'was',
#   'right,very',
#   'happy',
#   '!',
#   'I',
#   'do',
#   'wish',
#   'I',
#   'could',
#   'have',
#   'got',
#   'the',
#   'shipping',
#   'a',
#   'bit',
#   'lower',
#   'but',
#   'the',
#   'product',
#   'was',
#   'worth',
#   'every',
#   'pennyExcellent',
#   'item'],
#  ['This',
#   'product',
#   'has',
#   '3',
#   'functions',
#   'within',
#   'one',
#   'stylus:',
#   'PDA',
#   'stylus,',
#   'Laser',
#   'Stylus',
#   'and',
#   'Ball',
#   'pen.',
#   'This',
#   'probably',
#   'works',
#   'well',
#   'for',
#   'what',
#   'it',
#   'could',
#   'do,',
#   'but',
#   "it's",
#   'not',
#   'functionally',
#   'compatible',
#   'with',
#   'the',
#   'Sony',
#   'PSP',
#   'or',
#   'Sony',
#   'Playstation1',
#   '(PS1)',
#   'or',
#   'Playstation2',
#   '(PS2).',
#   'The',
#   'product',
#   'title',
#   'is',
#   'misleading',
#   'to',
#   'consumers,',
#   'since',
#   'the',
#   'PSP,',
#   'PS1',
#   'and',
#   'PS2',
#   'do',
#   'not',
#   'have',
#   'a',
#   'touch',
#   'screen.',
#   'DO',
#   'NOT',
#   'BUY',
#   'FOR',
#   'YOUR',
#   'PSP,',
#   'PS1,',
#   'or',
#   'PS2![...]Misleading',
#   'product',
#   'description'],
#  ['I',
#   'like',
#   'the',
#   'portability',
#   'of',
#   'this',
#   'file',
#   'cart.',
#   'My',
#   'husband',
#   'and',
#   'I',
#   'share',
#   'a',
#   'small',
#   'office',
#   'space',
#   'so',
#   'whenever',
#   'one',
#   'of',
#   'us',
#   'needs',
#   'to',
#   'get',
#   'into',
#   'files,',
#   'we',
#   'are',
#   'usually',
#   'in',
#   'the',
#   "other's",
#   'way.',
#   'With',
#   'the',
#   "Fold'nRoll,",
#   'I',
#   'can',
#   'move',
#   'the',
#   'cart',
#   'to',
#   'wherever',
#   'I',
#   'want.',
#   'At',
#   'the',
#   'end',
#   'of',
#   'the',
#   'year,',
#   'I',
#   'plan',
#   'to',
#   'put',
#   'the',
#   'lid',
#   'on',
#   'the',
#   'bin,',
#   'label',
#   'it',
#   'and',
#   'put',
#   'it',
#   'in',
#   'storage,',
#   'replacing',
#   'with',
#   'another',
#   'Rubbermaid',
#   'bin',
#   'for',
#   'next',
#   "year's",
#   'files.Handy',
#   'file',
#   'system'],
#  ['This',
#   'cart',
#   'has',
#   'a',
#   'small',
#   'footprint',
#   'yet',
#   'holds',
#   'many',
#   'files.',
#   'I',
#   'like',
#   'that',
#   'it',
#   'rolls',
#   'and',
#   'the',
#   'added',
#   'shelf',
#   'on',
#   'the',
#   'bottom',
#   'helps.',
#   'When',
#   'filing',
#   'is',
#   'finished',
#   'you',
#   'can',
#   'store',
#   'the',
#   'bin',
#   'and',
#   'fold',
#   'the',
#   'cart',
#   'until',
#   'you',
#   'need',
#   'another',
#   'bin',
#   'to',
#   'use',
#   'for',
#   'filing.',
#   'Clever',
#   'and',
#   'convenient',
#   'design.An',
#   'organization',
#   'dream',
#   'come',
#   'true'],
#  ['The',
#   'plastic',
#   'bin',
#   'does',
#   'NOT',
#   'hold',
#   'hanging',
#   'letter-size',
#   'files,',
#   'but',
#   'it',
#   'will',
#   'work',
#   'for',
#   'storing',
#   'file',
#   'folders.',
#   'You',
#   'can',
#   'adjust',
#   'the',
#   'rails',
#   'to',
#   'hold',
#   'hanging',
#   'letter-size',
#   'files,',
#   'but',
#   'contrary',
#   'to',
#   'the',
#   'way',
#   'it',
#   'looks,',
#   'you',
#   'will',
#   'only',
#   'have',
#   'about',
#   'one',
#   'foot',
#   'of',
#   'space.',
#   'If',
#   "they'd",
#   'designed',
#   'it',
#   'to',
#   'hold',
#   'hanging',
#   'files',
#   'the',
#   'long',
#   'way,',
#   'it',
#   'would',
#   'hold',
#   'almost',
#   '18"',
#   'of',
#   'files.',
#   'Also,',
#   'the',
#   'bin',
#   'is',
#   'pretty',
#   'junky.',
#   'Really',
#   'not',
#   'worth',
#   'the',
#   'high',
#   'price.',
#   'I',
#   'recommend',
#   'item',
#   '#SAF5228BL',
#   'by',
#   'SAFCO',
#   'instead.',
#   'Much',
#   'better',
#   'quality,',
#   'a',
#   'lower',
#   'price,',
#   'and',
#   'at',
#   'least',
#   'as',
#   'much',
#   'storage',
#   'space',
#   'for',
#   'letter-size',
#   'hanging',
#   'files.Not',
#   'worth',
#   'the',
#   'money.'],
#  ['I',
#   'have',
#   'been',
#   'using',
#   'my',
#   'HP',
#   'iPAQ',
#   'H5555',
#   'for',
#   'many',
#   'years,',
#   'and',
#   'its',
#   'still',
#   'doing',
#   'a',
#   'great',
#   'job.',
#   'I',
#   'have',
#   'had',
#   'to',
#   'replace',
#   'the',
#   'battery',
#   'from',
#   'time-to-time,',
#   'but',
#   'this',
#   'is',
#   'the',
#   'best',
#   'replacement',
#   'I',
#   'have',
#   'ever',
#   'had.',
#   'It',
#   'is',
#   'just',
#   'a',
#   'little',
#   'bigger',
#   'than',
#   'the',
#   'original',
#   'battery,',
#   'but',
#   'not',
#   'too',
#   'big.',
#   'The',
#   'handheld',
#   'computer',
#   'still',
#   'fits',
#   'easily',
#   'into',
#   'its',
#   'case.',
#   'The',
#   'size',
#   'of',
#   'this',
#   'new',
#   'battery',
#   'is',
#   'somewhere',
#   'between',
#   'the',
#   'standard',
#   'issue',
#   'battery',
#   'and',
#   'the',
#   'huge,',
#   'over-sized',
#   'alternative',
#   'offered',
#   'by',
#   'HP.',
#   'I',
#   'guess',
#   'I',
#   'would',
#   'say,',
#   "it's",
#   'not',
#   'too',
#   'big;',
#   'not',
#   'too',
#   'small;',
#   "it's",
#   'just',
#   'about',
#   'right!I',
#   'wish',
#   'this',
#   'was',
#   'issued',
#   'with',
#   'my',
#   'computer',
#   'years',
#   'ago.'],
#  ['This',
#   'battery',
#   "didn't",
#   'work',
#   'as',
#   'a',
#   'replacement',
#   'for',
#   'my',
#   'Zire',
#   '31.',
#   'It',
#   'was',
#   'too',
#   'big',
#   'to',
#   'fit',
#   'in',
#   'the',
#   'space',
#   'and',
#   'when',
#   'I',
#   'soldered',
#   'it,',
#   'it',
#   "didn't",
#   'fix',
#   'the',
#   'problems',
#   'I',
#   'had.',
#   'May',
#   'have',
#   'been',
#   'something',
#   'else,',
#   'but',
#   'the',
#   'size',
#   'issue',
#   'would',
#   'have',
#   'been',
#   'annoying',
#   'if',
#   'it',
#   'had',
#   "worked.Didn't",
#   'work',
#   'for',
#   'me.'],
#  ['Be',
#   'careful',
#   'to',
#   'ascertain',
#   'whether',
#   'or',
#   'not',
#   'the',
#   'battery',
#   'will',
#   'need',
#   'to',
#   'be',
#   'taken',
#   'to',
#   'a',
#   'technician',
#   'as',
#   'it',
#   'does',
#   'not',
#   'always',
#   'plug',
#   'in',
#   'but',
#   'may',
#   'need',
#   'to',
#   'be',
#   'soldered',
#   '(sp).',
#   'That',
#   'was',
#   'in',
#   'my',
#   'case.',
#   'The',
#   'directions',
#   'were',
#   'also',
#   'vague.Zire',
#   'Replacement',
#   'Battery'],
#  ['unable',
#   'to',
#   'use',
#   'as',
#   'is',
#   'had',
#   'to',
#   'cut',
#   'off',
#   'connector',
#   'pda',
#   'does',
#   'not',
#   'have',
#   'a',
#   'similar',
#   'connection',
#   'when',
#   'I',
#   'soldered',
#   'it',
#   'on',
#   'the',
#   'pda',
#   'would',
#   'not',
#   'work',
#   'tried',
#   'with',
#   'two',
#   'batteriesConnector',
#   'problem'],
#  ['good',
#   'product',
#   'but',
#   'not',
#   'what',
#   'I',
#   'ordered,',
#   'or',
#   "didn't",
#   'fit',
#   'what',
#   'it',
#   'said',
#   'it',
#   'did.okay...'],
#  ['Being',
#   'in',
#   'the',
#   'office,',
#   "it's",
#   'difficult',
#   'receiving',
#   'calls',
#   'on',
#   'the',
#   'unit',
#   'while',
#   'charging',
#   'in',
#   'the',
#   'cradle.',
#   'Sure',
#   'I',
#   'could',
#   'invest',
#   'in',
#   'a',
#   'headset',
#   'of',
#   'some',
#   'form',
#   'but',
#   'I',
#   'find',
#   'them',
#   'mildly',
#   'intrusive.',
#   'Add',
#   'that',
#   'to',
#   'the',
#   'fact',
#   'that',
#   'this',
#   'little',
#   'number',
#   'is',
#   'far',
#   'more',
#   'portable',
#   'than',
#   'the',
#   'bulky',
#   'synch',
#   'cradle',
#   'and',
#   'you',
#   'have',
#   'a',
#   'very',
#   'good',
#   'reason',
#   'to',
#   'never',
#   'be',
#   'disconnected',
#   'from',
#   'your',
#   'PDA',
#   'again.',
#   'Great',
#   'for',
#   'leveraging',
#   'GPRS',
#   'while',
#   'on',
#   'the',
#   'road,',
#   'Great',
#   'to',
#   'download/upload',
#   'things',
#   'on',
#   'the',
#   'fly',
#   'and',
#   'with',
#   'the',
#   'proper',
#   'attachments,',
#   'a',
#   'great',
#   'little',
#   'charger',
#   'for',
#   'your',
#   'phone',
#   'whether',
#   'through',
#   'a',
#   'power',
#   'socket,',
#   'laptop',
#   'USB',
#   'or',
#   'car',
#   'charger.More',
#   'versatile',
#   'than',
#   'the',
#   'Cradle'],
#  ['LIION',
#   'BATTERY',
#   'FOR',
#   'A',
#   'PANSCONIC',
#   'CAMERA.',
#   'I',
#   'HAVE',
#   'USED',
#   'THE',
#   'CAMERA',
#   '3',
#   'TIMES',
#   'SINCE',
#   'ADDING',
#   'THE',
#   'NEW',
#   'LIION',
#   'BATTERY.',
#   'SO',
#   'FAR',
#   'IT',
#   'HAS',
#   'WORKED',
#   'VERY',
#   'WELL.',
#   'CHARGE',
#   'IS',
#   'HOLDING',
#   'MUCH',
#   'LONGER',
#   'THEN',
#   'ORIGNAL',
#   'EQUIPMENT',
#   'BATTERY.BATTERY'],
#  ['The',
#   'cable',
#   'does',
#   'not',
#   'fit',
#   'a',
#   'Palm',
#   '515,',
#   'as',
#   'advertised.',
#   'Total',
#   'waste',
#   'of',
#   'timeand',
#   'money,',
#   'I',
#   'guess',
#   'they',
#   'just',
#   'sell',
#   'you',
#   'junk',
#   'that',
#   "doesn't",
#   'work',
#   'from',
#   'some',
#   'chinese',
#   'manufacturer',
#   'and',
#   'hope',
#   'that',
#   'you',
#   'wont',
#   'have',
#   'time',
#   'to',
#   'screw',
#   'around',
#   'sending',
#   'backJunk'],
#  ['First,',
#   'let',
#   'me',
#   'say',
#   'if',
#   "it's",
#   'too',
#   'good',
#   'to',
#   'be',
#   'true',
#   'it',
#   'probably',
#   'is.',
#   'I',
#   'bought',
#   'this',
#   'item',
#   'for',
#   'roughly',
#   '$8',
#   'thinking',
#   'I',
#   'walked',
#   'away',
#   'with',
#   'a',
#   'steal',
#   'but',
#   'the',
#   'joke',
#   'was',
#   'on',
#   'me.',
#   'I',
#   'should',
#   'have',
#   'just',
#   'taken',
#   'my',
#   'eight',
#   'bucks',
#   'and',
#   'set',
#   'it',
#   'on',
#   'fire.',
#   'Does',
#   'the',
#   'cable',
#   'work?',
#   "Couldn't",
#   'tell',
#   'you,',
#   'it',
#   "dosen't",
#   'come',
#   'with',
#   'any',
#   'flippin',
#   'software.',
#   'My',
#   'Ringtone',
#   'program',
#   'says',
#   '"use',
#   'software',
#   'that',
#   'came',
#   'with',
#   'your',
#   'cable"...',
#   'OOOH',
#   'that',
#   'was',
#   'insult',
#   'to',
#   'injury.',
#   'So',
#   'it',
#   'looks',
#   'like',
#   "I'm",
#   'going',
#   'to',
#   'do',
#   'what',
#   'I',
#   'should',
#   'have',
#   'done',
#   'in',
#   'the',
#   'fist',
#   'place,',
#   'spend',
#   'some',
#   'money',
#   'on',
#   'a',
#   'cable',
#   'with',
#   'the',
#   'software',
#   'included.',
#   'If',
#   'you',
#   'have',
#   '$8',
#   'dollars',
#   'you',
#   "don't",
#   'want,',
#   'send',
#   'it',
#   'to',
#   'me',
#   'or',
#   'just',
#   'buy',
#   'this',
#   'cable,',
#   'either',
#   'way',
#   'the',
#   'result',
#   'will',
#   'be',
#   'the',
#   'same.I',
#   'should',
#   'have',
#   'known',
#   'better'],
#  ["That's",
#   'all',
#   'I',
#   'gotta',
#   'say.I',
#   'used',
#   'it.Worked',
#   'perfect.It',
#   'is',
#   'not',
#   'fancy',
#   'but',
#   'is',
#   'worth',
#   'the',
#   'money.worth',
#   'the',
#   '5',
#   'bucks'],
#  ['I',
#   'am',
#   'not',
#   'sure',
#   'if',
#   'I',
#   'missed',
#   'something',
#   'in',
#   'the',
#   'instructions',
#   'on',
#   'the',
#   'use',
#   'of',
#   'this',
#   'product,',
#   'but',
#   'I',
#   'did',
#   'not',
#   'find',
#   'it',
#   'useful.',
#   'The',
#   'product',
#   'has',
#   'no',
#   'real',
#   'instruction,',
#   'just',
#   'listening',
#   'to',
#   'conversations.',
#   'Like',
#   'I',
#   'said',
#   'I',
#   'could',
#   'be',
#   'missing',
#   'something,',
#   'but',
#   "I'm",
#   'sorry',
#   'I',
#   'bought',
#   'this',
#   'Spanish',
#   'instruction',
#   'product.I',
#   'did',
#   'not',
#   'find',
#   'this',
#   'useful'],
#  ['This',
#   'replacement',
#   'battery',
#   'for',
#   'my',
#   'iPAQ',
#   'was',
#   'easy',
#   'to',
#   'order.',
#   'The',
#   'company',
#   'shipped',
#   'the',
#   'item',
#   'very',
#   'quickly',
#   'and',
#   'it',
#   'arrived',
#   'in',
#   'perfect',
#   'condition.',
#   'The',
#   'battery',
#   'was',
#   'easy',
#   'to',
#   'replace.',
#   'It',
#   'came',
#   'with',
#   'instructions',
#   'and',
#   'a',
#   'torx',
#   'screwdriver',
#   'to',
#   'help',
#   'remove',
#   'the',
#   'case',
#   'of',
#   'the',
#   'iPAQ.',
#   'Overall,',
#   'I',
#   'am',
#   'very',
#   'pleased',
#   'with',
#   'this',
#   'product',
#   'and',
#   'the',
#   'company',
#   'from',
#   'whom',
#   'I',
#   'made',
#   'the',
#   'purchase.Great',
#   'product,',
#   'fast',
#   'delivery'],
#  ['It',
#   'his',
#   'putty',
#   'is',
#   'a',
#   'bit',
#   'tougher',
#   'than',
#   'other',
#   'brands',
#   "I've",
#   'used.',
#   'You',
#   'have',
#   'to',
#   'knead',
#   'it',
#   'a',
#   'lot',
#   'before',
#   'using',
#   'to',
#   'get',
#   'it',
#   'to',
#   'be',
#   'sticky.',
#   'I',
#   'also',
#   'need',
#   'more',
#   'of',
#   'it',
#   'than',
#   "I've",
#   'used',
#   'with',
#   'other',
#   'brands.',
#   'When',
#   'I',
#   'hung',
#   'papers',
#   'with',
#   'a',
#   'small',
#   'dot',
#   'like',
#   'I',
#   'have',
#   'in',
#   'the',
#   'past',
#   'the',
#   'paper',
#   'fell',
#   'off',
#   'the',
#   'wall',
#   'within',
#   'a',
#   'few',
#   'days.',
#   'I',
#   'added',
#   'more',
#   'putty',
#   'and',
#   "it's",
#   'fine',
#   'now.',
#   'Only',
#   'used',
#   'to',
#   'hang',
#   'regular',
#   'construction',
#   'paper.A',
#   'bit',
#   'tough',
#   'but',
#   'works'],
#  ["I've",
#   'been',
#   'using',
#   'this',
#   'brand',
#   'for',
#   'a',
#   'long',
#   'time',
#   'now',
#   'and',
#   'I',
#   'never',
#   'had',
#   'any',
#   'problem.',
#   'I',
#   'even',
#   'hang',
#   'paintings',
#   'that',
#   'weight',
#   '2lbs',
#   'and',
#   'it',
#   'works',
#   'perfect,',
#   'I',
#   'just',
#   'use',
#   'more.great',
#   'product!'],
#  ['Did',
#   'you',
#   'know',
#   'that',
#   '10',
#   'of',
#   'these',
#   'strips',
#   'will',
#   'hold',
#   'a',
#   'full-grown',
#   'man',
#   'to',
#   'a',
#   'wall',
#   'or',
#   'ceiling?',
#   'Make',
#   'sure',
#   'to',
#   'shave',
#   'him',
#   'first,',
#   'though,',
#   'or',
#   'it',
#   'gets',
#   'stuck',
#   'in',
#   'the',
#   "man's",
#   'hair',
#   'and',
#   'results',
#   'in',
#   'unsightly',
#   'matting.Fantastic',
#   'product!'],
#  ['I',
#   'have',
#   'used',
#   'is',
#   'all',
#   'over',
#   'my',
#   'apartment',
#   'to',
#   'hold',
#   'things',
#   'up',
#   'and',
#   'it',
#   'works',
#   'really',
#   'well!',
#   'Everything',
#   'I',
#   'have',
#   'put',
#   'up',
#   "hasn't",
#   'fallen',
#   'or',
#   'given',
#   'me',
#   'any',
#   'troubleWorks',
#   'great!'],
#  ['The',
#   'putty',
#   'is',
#   'great.',
#   'I',
#   'have',
#   'used',
#   'it',
#   'to',
#   'attach',
#   'photos',
#   'to',
#   'my',
#   'refrigerator',
#   'which,',
#   'by',
#   'some',
#   'serious',
#   'design',
#   'flaw,',
#   'is',
#   'not',
#   'magnetic',
#   'on',
#   'the',
#   'front.',
#   'I',
#   'have',
#   'stuck',
#   'posters',
#   'on',
#   'the',
#   'wall,',
#   'I',
#   'stuck',
#   'do-dads',
#   'to',
#   'the',
#   'ceiling,',
#   'and',
#   'coupons',
#   'to',
#   'my',
#   'car.I',
#   'have',
#   'stuck',
#   'everything',
#   'to',
#   'everything'],
#  ['I',
#   'really',
#   'like',
#   'this',
#   'poster',
#   'putty',
#   'put',
#   'out',
#   'by',
#   'Duck.',
#   'It',
#   'does',
#   'not',
#   'dry',
#   'up.',
#   'I',
#   'have',
#   'used',
#   'it',
#   'to',
#   'put',
#   'pictures',
#   'on',
#   'my',
#   'walls',
#   '-',
#   'even',
#   'single',
#   'items',
#   'such',
#   'as',
#   'leaves',
#   'that',
#   'are',
#   'preserved,',
#   'on',
#   'a',
#   'plain',
#   'white',
#   'wall,',
#   'which',
#   'really',
#   'spruces',
#   'it',
#   'up.Absolutely',
#   'safe',
#   'to',
#   'use',
#   'on',
#   'your',
#   'wall',
#   'for',
#   'so',
#   'many',
#   'things',
#   '-',
#   'decorating',
#   '-',
#   'pictures',
#   '-',
#   'posters,',
#   'etc.'],
#  ...]

# %%
[len(s.split()) for s in total_reviews]
# Out:
# [164,
#  68,
#  37,
#  35,
#  45,
#  42,
#  33,
#  36,
#  21,
#  26,
#  20,
#  31,
#  106,
#  24,
#  38,
#  25,
#  30,
#  22,
#  37,
#  39,
#  25,
#  60,
#  44,
#  149,
#  327,
#  33,
#  156,
#  34,
#  4,
#  25,
#  23,
#  22,
#  30,
#  21,
#  45,
#  92,
#  38,
#  32,
#  33,
#  11,
#  41,
#  31,
#  21,
#  24,
#  117,
#  36,
#  33,
#  65,
#  16,
#  42,
#  68,
#  102,
#  40,
#  67,
#  32,
#  109,
#  164,
#  25,
#  21,
#  47,
#  58,
#  22,
#  64,
#  31,
#  97,
#  78,
#  24,
#  35,
#  30,
#  50,
#  40,
#  30,
#  18,
#  25,
#  25,
#  69,
#  53,
#  76,
#  52,
#  28,
#  44,
#  90,
#  36,
#  47,
#  21,
#  87,
#  69,
#  43,
#  72,
#  26,
#  27,
#  188,
#  229,
#  192,
#  24,
#  232,
#  23,
#  443,
#  49,
#  123,
#  124,
#  22,
#  28,
#  32,
#  31,
#  74,
#  28,
#  289,
#  30,
#  185,
#  101,
#  59,
#  54,
#  81,
#  62,
#  91,
#  134,
#  117,
#  26,
#  52,
#  53,
#  88,
#  32,
#  60,
#  54,
#  72,
#  88,
#  21,
#  22,
#  38,
#  108,
#  26,
#  34,
#  30,
#  27,
#  36,
#  128,
#  120,
#  61,
#  20,
#  70,
#  43,
#  35,
#  53,
#  21,
#  46,
#  88,
#  43,
#  19,
#  24,
#  59,
#  97,
#  69,
#  33,
#  46,
#  42,
#  21,
#  23,
#  31,
#  86,
#  47,
#  38,
#  138,
#  58,
#  36,
#  61,
#  21,
#  69,
#  26,
#  33,
#  23,
#  68,
#  32,
#  25,
#  49,
#  44,
#  21,
#  24,
#  99,
#  22,
#  30,
#  28,
#  39,
#  42,
#  49,
#  49,
#  97,
#  41,
#  23,
#  44,
#  11,
#  24,
#  211,
#  48,
#  51,
#  36,
#  24,
#  33,
#  68,
#  68,
#  30,
#  23,
#  25,
#  46,
#  52,
#  22,
#  27,
#  163,
#  23,
#  21,
#  79,
#  46,
#  126,
#  54,
#  27,
#  26,
#  50,
#  34,
#  75,
#  47,
#  24,
#  26,
#  189,
#  109,
#  44,
#  35,
#  115,
#  51,
#  49,
#  128,
#  36,
#  50,
#  50,
#  38,
#  34,
#  23,
#  36,
#  58,
#  57,
#  66,
#  172,
#  37,
#  63,
#  136,
#  80,
#  26,
#  22,
#  69,
#  276,
#  108,
#  40,
#  23,
#  23,
#  29,
#  26,
#  32,
#  261,
#  16,
#  90,
#  70,
#  168,
#  29,
#  24,
#  40,
#  86,
#  28,
#  23,
#  23,
#  31,
#  49,
#  64,
#  145,
#  100,
#  175,
#  119,
#  58,
#  68,
#  135,
#  137,
#  153,
#  92,
#  27,
#  30,
#  57,
#  23,
#  41,
#  33,
#  49,
#  51,
#  54,
#  39,
#  43,
#  39,
#  51,
#  22,
#  24,
#  43,
#  34,
#  29,
#  27,
#  66,
#  81,
#  40,
#  37,
#  19,
#  158,
#  35,
#  64,
#  99,
#  132,
#  166,
#  21,
#  24,
#  28,
#  28,
#  36,
#  47,
#  33,
#  20,
#  18,
#  187,
#  24,
#  217,
#  55,
#  23,
#  34,
#  43,
#  28,
#  21,
#  102,
#  45,
#  25,
#  26,
#  153,
#  20,
#  19,
#  26,
#  29,
#  23,
#  28,
#  121,
#  142,
#  31,
#  53,
#  42,
#  248,
#  273,
#  31,
#  20,
#  47,
#  20,
#  72,
#  29,
#  32,
#  49,
#  51,
#  24,
#  69,
#  24,
#  24,
#  37,
#  37,
#  64,
#  25,
#  137,
#  122,
#  24,
#  41,
#  89,
#  25,
#  26,
#  27,
#  31,
#  148,
#  98,
#  52,
#  50,
#  33,
#  32,
#  143,
#  35,
#  43,
#  33,
#  58,
#  21,
#  97,
#  33,
#  57,
#  130,
#  34,
#  32,
#  57,
#  28,
#  63,
#  32,
#  32,
#  35,
#  33,
#  58,
#  123,
#  28,
#  29,
#  38,
#  30,
#  37,
#  25,
#  38,
#  41,
#  21,
#  61,
#  44,
#  50,
#  21,
#  29,
#  23,
#  52,
#  34,
#  75,
#  24,
#  25,
#  54,
#  36,
#  74,
#  21,
#  30,
#  26,
#  62,
#  45,
#  80,
#  22,
#  13,
#  25,
#  23,
#  29,
#  39,
#  25,
#  75,
#  52,
#  26,
#  71,
#  30,
#  27,
#  48,
#  68,
#  82,
#  129,
#  33,
#  45,
#  62,
#  24,
#  31,
#  39,
#  30,
#  34,
#  28,
#  31,
#  83,
#  23,
#  45,
#  25,
#  25,
#  140,
#  57,
#  62,
#  64,
#  68,
#  52,
#  46,
#  27,
#  62,
#  23,
#  30,
#  101,
#  49,
#  45,
#  49,
#  53,
#  56,
#  50,
#  62,
#  92,
#  29,
#  29,
#  24,
#  81,
#  53,
#  101,
#  292,
#  51,
#  33,
#  57,
#  39,
#  32,
#  21,
#  11,
#  25,
#  35,
#  18,
#  27,
#  21,
#  38,
#  80,
#  44,
#  40,
#  35,
#  26,
#  57,
#  39,
#  82,
#  87,
#  112,
#  79,
#  349,
#  38,
#  21,
#  51,
#  22,
#  36,
#  86,
#  70,
#  284,
#  45,
#  54,
#  133,
#  95,
#  24,
#  28,
#  25,
#  23,
#  114,
#  23,
#  63,
#  47,
#  42,
#  152,
#  29,
#  33,
#  52,
#  38,
#  134,
#  88,
#  18,
#  97,
#  151,
#  34,
#  30,
#  56,
#  46,
#  30,
#  26,
#  43,
#  58,
#  92,
#  61,
#  58,
#  29,
#  34,
#  106,
#  26,
#  28,
#  30,
#  19,
#  74,
#  27,
#  59,
#  210,
#  99,
#  29,
#  41,
#  119,
#  123,
#  32,
#  42,
#  153,
#  30,
#  134,
#  86,
#  18,
#  40,
#  49,
#  29,
#  34,
#  30,
#  36,
#  26,
#  74,
#  63,
#  30,
#  61,
#  39,
#  24,
#  39,
#  39,
#  39,
#  31,
#  63,
#  111,
#  58,
#  40,
#  39,
#  97,
#  59,
#  115,
#  98,
#  51,
#  51,
#  548,
#  82,
#  32,
#  28,
#  25,
#  34,
#  38,
#  45,
#  26,
#  44,
#  25,
#  64,
#  130,
#  35,
#  50,
#  34,
#  57,
#  23,
#  22,
#  25,
#  57,
#  25,
#  18,
#  93,
#  192,
#  34,
#  33,
#  49,
#  71,
#  36,
#  26,
#  76,
#  74,
#  26,
#  78,
#  64,
#  52,
#  36,
#  18,
#  84,
#  30,
#  36,
#  42,
#  146,
#  26,
#  24,
#  80,
#  19,
#  68,
#  41,
#  36,
#  35,
#  22,
#  61,
#  63,
#  94,
#  27,
#  110,
#  43,
#  95,
#  83,
#  50,
#  125,
#  18,
#  112,
#  36,
#  10,
#  120,
#  63,
#  132,
#  198,
#  119,
#  64,
#  443,
#  174,
#  27,
#  23,
#  33,
#  65,
#  29,
#  56,
#  66,
#  27,
#  43,
#  21,
#  36,
#  43,
#  23,
#  101,
#  19,
#  21,
#  79,
#  155,
#  30,
#  42,
#  30,
#  80,
#  33,
#  50,
#  28,
#  22,
#  105,
#  87,
#  83,
#  32,
#  291,
#  71,
#  26,
#  43,
#  80,
#  32,
#  42,
#  48,
#  43,
#  26,
#  31,
#  113,
#  59,
#  30,
#  195,
#  33,
#  27,
#  49,
#  128,
#  167,
#  46,
#  380,
#  91,
#  323,
#  26,
#  28,
#  29,
#  254,
#  307,
#  53,
#  31,
#  55,
#  81,
#  54,
#  95,
#  81,
#  85,
#  25,
#  29,
#  41,
#  37,
#  109,
#  51,
#  87,
#  55,
#  97,
#  77,
#  38,
#  39,
#  27,
#  67,
#  50,
#  76,
#  202,
#  55,
#  37,
#  73,
#  103,
#  32,
#  88,
#  107,
#  86,
#  116,
#  89,
#  48,
#  47,
#  25,
#  22,
#  44,
#  30,
#  113,
#  147,
#  23,
#  68,
#  21,
#  144,
#  81,
#  24,
#  74,
#  58,
#  126,
#  21,
#  92,
#  55,
#  50,
#  54,
#  45,
#  28,
#  20,
#  59,
#  112,
#  142,
#  196,
#  43,
#  45,
#  45,
#  27,
#  57,
#  62,
#  33,
#  114,
#  26,
#  41,
#  58,
#  75,
#  23,
#  21,
#  9,
#  22,
#  29,
#  41,
#  36,
#  41,
#  47,
#  22,
#  39,
#  34,
#  54,
#  59,
#  30,
#  46,
#  68,
#  49,
#  52,
#  25,
#  17,
#  22,
#  40,
#  22,
#  76,
#  35,
#  44,
#  24,
#  25,
#  61,
#  43,
#  28,
#  82,
#  50,
#  129,
#  52,
#  30,
#  24,
#  147,
#  514,
#  92,
#  91,
#  35,
#  110,
#  18,
#  38,
#  18,
#  19,
#  45,
#  38,
#  55,
#  207,
#  72,
#  108,
#  33,
#  21,
#  140,
#  41,
#  21,
#  22,
#  15,
#  18,
#  33,
#  283,
#  52,
#  34,
#  51,
#  114,
#  47,
#  80,
#  116,
#  37,
#  49,
#  32,
#  87,
#  49,
#  30,
#  31,
#  87,
#  71,
#  37,
#  104,
#  124,
#  90,
#  28,
#  30,
#  58,
#  29,
#  56,
#  130,
#  37,
#  24,
#  40,
#  49,
#  74,
#  36,
#  31,
#  28,
#  35,
#  114,
#  107,
#  25,
#  50,
#  96,
#  94,
#  78,
#  39,
#  95,
#  116,
#  26,
#  101,
#  60,
#  28,
#  30,
#  46,
#  32,
#  57,
#  36,
#  28,
#  30,
#  111,
#  200,
#  26,
#  78,
#  105,
#  151,
#  24,
#  44,
#  47,
#  50,
#  49,
#  40,
#  64,
#  70,
#  55,
#  112,
#  37,
#  25,
#  67,
#  34,
#  106,
#  18,
#  17,
#  37,
#  78,
#  380,
#  31,
#  17,
#  48,
#  31,
#  63,
#  79,
#  32,
#  104,
#  55,
#  119,
#  31,
#  42,
#  58,
#  34,
#  28,
#  36,
#  70,
#  79,
#  53,
#  100,
#  106,
#  52,
#  43,
#  32,
#  15,
#  106,
#  35,
#  41,
#  134,
#  19,
#  56,
#  65,
#  82,
#  32,
#  39,
#  30,
#  49,
#  62,
#  ...]

# %%
# max_length
# Out:
# 1139

# %%
sequences
# Out:
# [[1610,
#   500,
#   61,
#   1886,
#   5,
#   117,
#   1681,
#   78,
#   32,
#   860,
#   1834,
#   351,
#   46,
#   155,
#   242,
#   160,
#   9,
#   28,
#   869,
#   683,
#   110,
#   7,
#   687,
#   208,
#   4628,
#   103,
#   173,
#   103,
#   173,
#   2592,
#   31,
#   16,
#   144,
#   358,
#   137,
#   58,
#   52,
#   185,
#   436,
#   137,
#   7,
#   50,
#   208,
#   245,
#   568,
#   581,
#   173,
#   2592,
#   2,
#   477,
#   1886,
#   667,
#   26,
#   17,
#   860,
#   351,
#   1886,
#   613,
#   614,
#   5267,
#   5268,
#   44,
#   61,
#   104,
#   860,
#   3763,
#   132,
#   649,
#   154,
#   8,
#   860,
#   322,
#   679,
#   81,
#   116,
#   144,
#   225,
#   64,
#   20,
#   1,
#   225,
#   7,
#   187,
#   32,
#   396],
#  [325,
#   51,
#   307,
#   54,
#   325,
#   14,
#   5269,
#   307,
#   111,
#   1439,
#   39,
#   373,
#   2387,
#   10,
#   40,
#   325,
#   51,
#   752,
#   1229,
#   1102,
#   307,
#   1074,
#   86,
#   752,
#   2057,
#   54,
#   6,
#   10,
#   82],
#  [152,
#   15,
#   8,
#   589,
#   998,
#   47,
#   171,
#   210,
#   1131,
#   2,
#   998,
#   2720,
#   6,
#   2481,
#   141,
#   6,
#   274,
#   8,
#   8279,
#   152,
#   15],
#  [23,
#   7,
#   16,
#   410,
#   119,
#   142,
#   42,
#   310,
#   136,
#   13,
#   139,
#   1887,
#   142,
#   1,
#   5,
#   27,
#   171,
#   23,
#   7],
#  [15,
#   8,
#   61,
#   4629,
#   594,
#   2388,
#   268,
#   193,
#   2217,
#   4629,
#   684,
#   75,
#   2,
#   198,
#   2720,
#   998,
#   106,
#   75,
#   323,
#   4137,
#   251],
#  [2,
#   956,
#   154,
#   2593,
#   268,
#   110,
#   8280,
#   5270,
#   534,
#   3224,
#   90,
#   2,
#   4630,
#   2720,
#   2389,
#   110,
#   4138,
#   507,
#   6297,
#   4139,
#   3,
#   484,
#   4631],
#  [11, 16, 14, 50, 442, 1014, 110, 721, 276, 2870, 16, 117, 14, 228, 450, 450],
#  [36,
#   65,
#   983,
#   35,
#   1200,
#   1731,
#   3764,
#   246,
#   13,
#   5,
#   16,
#   310,
#   141,
#   4632,
#   4140,
#   4141,
#   172,
#   65,
#   191,
#   3,
#   177,
#   99,
#   1,
#   422],
#  [99, 1, 422, 120, 85, 16, 470, 177, 1732, 134, 130, 3, 65],
#  [1581, 3, 1682, 134, 3467, 197, 32, 60, 358, 10, 5, 254, 15, 4633, 362, 15],
#  [323, 65, 30, 181, 61, 80, 251, 370, 5271, 15, 201],
#  [8281,
#   65,
#   474,
#   1162,
#   58,
#   2058,
#   427,
#   1200,
#   433,
#   575,
#   1888,
#   3,
#   282,
#   2058,
#   478,
#   5,
#   35],
#  [2871,
#   408,
#   1132,
#   4142,
#   1,
#   139,
#   28,
#   239,
#   16,
#   433,
#   47,
#   4,
#   63,
#   181,
#   1835,
#   386,
#   260,
#   25,
#   37,
#   5,
#   1295,
#   48,
#   3,
#   251,
#   1,
#   82,
#   272,
#   1355,
#   16,
#   848,
#   8,
#   310,
#   35,
#   8282,
#   65,
#   374,
#   1,
#   649,
#   56,
#   209,
#   64,
#   8283,
#   8,
#   1835],
#  [110,
#   65,
#   270,
#   15,
#   1200,
#   16,
#   848,
#   16,
#   106,
#   3225,
#   109,
#   141,
#   9,
#   199,
#   45,
#   15,
#   1200],
#  [172,
#   65,
#   61,
#   849,
#   861,
#   6298,
#   11,
#   33,
#   30,
#   5,
#   492,
#   6299,
#   5272,
#   3226,
#   239,
#   4143,
#   805,
#   96,
#   388,
#   65],
#  [12,
#   133,
#   81,
#   470,
#   86,
#   239,
#   23,
#   14,
#   64,
#   1834,
#   329,
#   40,
#   85,
#   226,
#   200,
#   12,
#   133,
#   81,
#   470,
#   65],
#  [176,
#   330,
#   388,
#   176,
#   8284,
#   4143,
#   1054,
#   3,
#   237,
#   3,
#   209,
#   8285,
#   17,
#   30,
#   104,
#   5,
#   8286,
#   141,
#   1054],
#  [4143, 405, 8287, 20, 85, 172, 478, 52, 1377, 1539, 1683, 1834, 172],
#  [83,
#   6299,
#   5272,
#   50,
#   74,
#   3468,
#   3765,
#   8288,
#   85,
#   4143,
#   2721,
#   2594,
#   5273,
#   1075,
#   171,
#   1103,
#   1993,
#   3766,
#   6300,
#   85,
#   8289,
#   1731,
#   3767,
#   4143,
#   65],
#  [1,
#   10,
#   65,
#   10,
#   1296,
#   2594,
#   8290,
#   161,
#   15,
#   6301,
#   2134,
#   65,
#   138,
#   482,
#   740,
#   85,
#   11,
#   8291,
#   356,
#   85],
#  [23,
#   16,
#   371,
#   15,
#   4144,
#   1836,
#   333,
#   21,
#   16,
#   64,
#   84,
#   203,
#   650,
#   119,
#   32,
#   23,
#   475,
#   371],
#  [8292,
#   8293,
#   317,
#   792,
#   10,
#   252,
#   111,
#   28,
#   179,
#   317,
#   781,
#   781,
#   49,
#   1022,
#   122,
#   11,
#   49,
#   2059,
#   149,
#   832,
#   97,
#   49,
#   556,
#   106,
#   5,
#   113,
#   105,
#   1186,
#   229,
#   23,
#   1335],
#  [4,
#   12,
#   328,
#   35,
#   106,
#   1497,
#   16,
#   2595,
#   310,
#   35,
#   9,
#   3,
#   28,
#   2596,
#   100,
#   1,
#   87,
#   72,
#   870,
#   1440,
#   6,
#   1733,
#   2135],
#  [32,
#   78,
#   20,
#   3227,
#   1297,
#   1498,
#   3469,
#   793,
#   2136,
#   984,
#   340,
#   3768,
#   437,
#   67,
#   68,
#   8,
#   315,
#   391,
#   1499,
#   1,
#   183,
#   125,
#   713,
#   61,
#   2060,
#   46,
#   306,
#   4145,
#   1145,
#   2872,
#   315,
#   420,
#   477,
#   241,
#   3470,
#   1230,
#   75,
#   511,
#   2595,
#   614,
#   1,
#   183,
#   1889,
#   221,
#   397,
#   137,
#   2,
#   9,
#   651,
#   7,
#   1,
#   1201,
#   326,
#   6302,
#   340,
#   300,
#   33,
#   20,
#   1408,
#   2595,
#   354,
#   1378,
#   9,
#   47,
#   8,
#   1356,
#   557,
#   7,
#   274,
#   158,
#   1357,
#   5274,
#   1734,
#   4146,
#   127,
#   374,
#   61,
#   117,
#   1104,
#   1499,
#   530,
#   814,
#   117,
#   187,
#   7,
#   191],
#  [2,
#   8294,
#   4634,
#   35,
#   457,
#   806,
#   74,
#   79,
#   109,
#   1055,
#   46,
#   8295,
#   32,
#   98,
#   35,
#   11,
#   451,
#   2137,
#   1789,
#   247,
#   226,
#   678,
#   3471,
#   1040,
#   4635,
#   1202,
#   193,
#   300,
#   8296,
#   585,
#   927,
#   22,
#   747,
#   1105,
#   11,
#   5275,
#   299,
#   1358,
#   898,
#   457,
#   5276,
#   401,
#   1379,
#   1202,
#   1380,
#   7,
#   11,
#   1440,
#   614,
#   5,
#   248,
#   941,
#   1440,
#   1,
#   61,
#   704,
#   590,
#   748,
#   1440,
#   601,
#   2061,
#   12,
#   11,
#   2061,
#   3472,
#   381,
#   8297,
#   79,
#   4,
#   1202,
#   79,
#   787,
#   652,
#   8298,
#   713,
#   2595,
#   291,
#   1131,
#   6303,
#   27,
#   13,
#   316,
#   722,
#   46,
#   269,
#   941,
#   47,
#   437,
#   109,
#   214,
#   27,
#   1202,
#   25,
#   453,
#   8299,
#   1131,
#   340,
#   20,
#   525,
#   723,
#   79,
#   602,
#   609,
#   4147,
#   1640,
#   109,
#   637,
#   247,
#   1735,
#   4636,
#   422,
#   141,
#   436,
#   205,
#   525,
#   79,
#   653,
#   392,
#   4148,
#   590,
#   605,
#   1471,
#   7,
#   22,
#   6,
#   633,
#   248,
#   74,
#   247,
#   543,
#   22,
#   20,
#   27,
#   52,
#   999,
#   274,
#   601,
#   436,
#   525,
#   79,
#   358,
#   25,
#   306,
#   7,
#   247,
#   328,
#   679,
#   13,
#   4149,
#   1380,
#   624,
#   1131,
#   1,
#   42,
#   146,
#   199,
#   469],
#  [24,
#   562,
#   24,
#   274,
#   1270,
#   1055,
#   2062,
#   13,
#   24,
#   1890,
#   183,
#   162,
#   1441,
#   1055,
#   133,
#   109,
#   1359,
#   118,
#   1497,
#   624],
#  [6,
#   375,
#   1497,
#   624,
#   47,
#   20,
#   68,
#   1442,
#   47,
#   437,
#   5,
#   2390,
#   140,
#   48,
#   898,
#   741,
#   25,
#   2597,
#   1,
#   182,
#   5277,
#   22,
#   773,
#   68,
#   235,
#   624,
#   11,
#   216,
#   106,
#   47,
#   29,
#   359,
#   59,
#   91,
#   31,
#   25,
#   526,
#   54,
#   17,
#   105,
#   465,
#   3020,
#   63,
#   5278,
#   41,
#   188,
#   412,
#   274,
#   340,
#   5279,
#   401,
#   20,
#   182,
#   100,
#   606,
#   140,
#   724,
#   374,
#   1499,
#   363,
#   3228,
#   274,
#   999,
#   624,
#   291,
#   359,
#   3229,
#   624,
#   722,
#   705,
#   20,
#   396,
#   396,
#   1582,
#   375,
#   3769,
#   8300,
#   483,
#   182,
#   1497,
#   2595],
#  [3770,
#   3,
#   344,
#   177,
#   503,
#   29,
#   6304,
#   138,
#   274,
#   615,
#   985,
#   722,
#   99,
#   1,
#   422,
#   127,
#   211,
#   3770,
#   4150],
#  [268, 15, 8301],
#  [75, 6, 414, 78, 75, 22, 660, 22, 2, 124, 8302, 660],
#  [15, 70, 333, 107, 3771, 285, 1940, 53, 6305, 15, 493],
#  [116, 6, 47, 871, 48, 13, 849, 2063, 9, 13, 6, 80, 12, 172],
#  [15,
#   78,
#   20,
#   1163,
#   262,
#   2873,
#   65,
#   1271,
#   17,
#   12,
#   230,
#   110,
#   1022,
#   33,
#   8303,
#   8304,
#   2873,
#   65],
#  [48, 271, 3230, 17, 6, 799, 8305, 4151, 5, 302, 3, 6, 799],
#  [35,
#   97,
#   15,
#   5280,
#   3021,
#   6306,
#   2391,
#   36,
#   329,
#   49,
#   458,
#   3021,
#   433,
#   220,
#   2391,
#   833,
#   46,
#   124,
#   49,
#   3021,
#   6306,
#   2391,
#   49,
#   774,
#   364,
#   3021],
#  [508,
#   17,
#   6,
#   1941,
#   27,
#   3231,
#   8,
#   1641,
#   799,
#   331,
#   1472,
#   389,
#   180,
#   558,
#   14,
#   1,
#   551,
#   338,
#   543,
#   11,
#   8306,
#   4637,
#   2,
#   538,
#   37,
#   27,
#   4,
#   1942,
#   334,
#   3022,
#   241,
#   31,
#   1146,
#   2482,
#   230,
#   118,
#   3772,
#   334,
#   3023,
#   3022],
#  [17,
#   127,
#   3773,
#   341,
#   33,
#   88,
#   4,
#   93,
#   2598,
#   117,
#   28,
#   3774,
#   3024,
#   304,
#   2,
#   82,
#   3,
#   19],
#  [10, 8307, 6307, 86, 351, 412, 47, 4145, 4, 184, 1, 79, 4, 184],
#  [8, 349, 160, 1, 139, 8308, 4, 760, 22, 248, 10, 106, 5, 10, 2, 5, 4, 88],
#  [2599, 146, 1473, 6308, 614, 3473, 365, 443, 117],
#  [7,
#   4,
#   3,
#   26,
#   1022,
#   234,
#   160,
#   41,
#   7,
#   28,
#   124,
#   4,
#   304,
#   1994,
#   311,
#   973,
#   1,
#   398,
#   576,
#   3,
#   7,
#   1684,
#   55,
#   6307,
#   125],
#  [30,
#   8309,
#   1355,
#   55,
#   8,
#   20,
#   4638,
#   205,
#   825,
#   582,
#   1474,
#   230,
#   1106,
#   175,
#   569,
#   6,
#   146,
#   6],
#  [209, 33, 4, 11, 6309, 26, 17, 8310, 255, 19, 4, 36, 640],
#  [55, 21, 6, 51, 205, 239, 313, 92, 32, 16, 8311, 7, 15, 8312],
#  [792,
#   32,
#   1358,
#   6310,
#   1076,
#   6311,
#   6312,
#   8313,
#   8314,
#   8315,
#   3025,
#   210,
#   5281,
#   6313,
#   74,
#   2064,
#   5282,
#   226,
#   474,
#   4,
#   6314,
#   8316,
#   1041,
#   8317,
#   8318,
#   8319,
#   1041,
#   8320,
#   6312,
#   31,
#   61,
#   3474,
#   3775,
#   1583,
#   1107,
#   1000,
#   1584,
#   6315,
#   928,
#   1837,
#   8321,
#   1500,
#   1202,
#   8322,
#   548,
#   181,
#   5282,
#   4152,
#   8323,
#   226,
#   8324,
#   8325,
#   861,
#   231,
#   5283,
#   8326,
#   6316,
#   45,
#   4,
#   199,
#   3,
#   1360,
#   1834,
#   4639,
#   3026,
#   5282],
#  [23,
#   65,
#   23,
#   688,
#   48,
#   4640,
#   12,
#   6317,
#   23,
#   50,
#   312,
#   1248,
#   4640,
#   48,
#   615,
#   50,
#   8327,
#   12,
#   65,
#   144,
#   96],
#  [128,
#   21,
#   1054,
#   2065,
#   36,
#   861,
#   4153,
#   282,
#   9,
#   5,
#   35,
#   20,
#   288,
#   28,
#   27,
#   35,
#   8328,
#   4154,
#   1054],
#  [11,
#   312,
#   861,
#   15,
#   65,
#   570,
#   201,
#   1585,
#   891,
#   427,
#   141,
#   8329,
#   1313,
#   1380,
#   35,
#   204,
#   10,
#   65,
#   5,
#   331,
#   61,
#   254,
#   139,
#   15,
#   33,
#   1585,
#   4641,
#   8330,
#   1585,
#   65],
#  [276, 61, 422, 65, 595, 60, 214, 133, 313],
#  [22,
#   65,
#   8331,
#   312,
#   861,
#   8332,
#   8333,
#   32,
#   80,
#   392,
#   42,
#   30,
#   104,
#   8334,
#   1585,
#   65,
#   6,
#   942,
#   220,
#   8335,
#   1642,
#   8336,
#   77,
#   4642,
#   1685],
#  [21,
#   65,
#   3,
#   1736,
#   5284,
#   2874,
#   861,
#   315,
#   141,
#   51,
#   107,
#   85,
#   23,
#   86,
#   1686,
#   51,
#   360,
#   1737,
#   142,
#   700,
#   520,
#   21,
#   14,
#   239,
#   70,
#   3,
#   3,
#   65,
#   3,
#   267,
#   733,
#   8337,
#   65,
#   312,
#   861],
#  [382,
#   5,
#   850,
#   216,
#   56,
#   100,
#   94,
#   382,
#   97,
#   1686,
#   1106,
#   4155,
#   4156,
#   3776,
#   1248,
#   382,
#   16,
#   1248,
#   1,
#   4643,
#   289,
#   483,
#   8338,
#   1272,
#   2218,
#   815,
#   80,
#   1585,
#   335,
#   312,
#   861,
#   64,
#   1203,
#   957,
#   22,
#   544,
#   95,
#   16,
#   1,
#   571,
#   220,
#   92,
#   9,
#   389,
#   4157,
#   382,
#   1001,
#   44,
#   50,
#   131,
#   8,
#   12,
#   133,
#   81],
#  [1,
#   109,
#   382,
#   330,
#   1585,
#   329,
#   2875,
#   398,
#   8339,
#   8340,
#   5285,
#   576,
#   265,
#   23,
#   634,
#   471,
#   16,
#   3,
#   237,
#   92,
#   2483,
#   31,
#   5286,
#   5286,
#   5286],
#  [1790,
#   20,
#   30,
#   3777,
#   65,
#   408,
#   4158,
#   6318,
#   172,
#   1540,
#   74,
#   103,
#   1541,
#   77,
#   1541,
#   110,
#   23,
#   209,
#   142,
#   4158,
#   1106,
#   30,
#   377,
#   479,
#   6319,
#   3777,
#   65,
#   787,
#   30,
#   65,
#   109,
#   35,
#   209,
#   4158,
#   4158,
#   6318,
#   3777,
#   65],
#  [5,
#   23,
#   85,
#   1054,
#   3777,
#   23,
#   146,
#   109,
#   35,
#   545,
#   229,
#   8,
#   29,
#   525,
#   3777,
#   1054,
#   23,
#   1054],
#  [78,
#   37,
#   614,
#   125,
#   7,
#   1,
#   241,
#   140,
#   19,
#   70,
#   52,
#   383,
#   241,
#   17,
#   125,
#   65,
#   1,
#   3,
#   70,
#   228,
#   14,
#   126,
#   285,
#   479,
#   14,
#   341,
#   141,
#   65,
#   1231,
#   50,
#   85,
#   252,
#   2600,
#   2600,
#   85,
#   5,
#   2600,
#   141,
#   57,
#   2600,
#   1409,
#   3475,
#   78,
#   443,
#   141,
#   3027,
#   98,
#   107,
#   22,
#   2600,
#   85,
#   1,
#   207,
#   141],
#  [30,
#   6320,
#   472,
#   1146,
#   3,
#   899,
#   81,
#   28,
#   64,
#   1204,
#   236,
#   138,
#   5287,
#   8341,
#   27,
#   4644,
#   226,
#   1443,
#   236,
#   68,
#   82,
#   13,
#   139,
#   107,
#   295,
#   87,
#   568,
#   107,
#   236,
#   26,
#   1022,
#   291,
#   1204,
#   2219,
#   6321,
#   4,
#   142,
#   1687,
#   1204,
#   706,
#   5,
#   37,
#   3778,
#   765,
#   706,
#   60,
#   10,
#   706,
#   6320,
#   163,
#   125,
#   706,
#   5,
#   236,
#   7,
#   807,
#   1164,
#   706,
#   208,
#   420,
#   9,
#   32,
#   31,
#   615,
#   28,
#   52,
#   643,
#   1165,
#   138,
#   816,
#   3232,
#   310,
#   35,
#   119,
#   311],
#  [1890,
#   226,
#   8342,
#   53,
#   142,
#   4644,
#   742,
#   109,
#   107,
#   3476,
#   3233,
#   150,
#   8343,
#   1296,
#   479,
#   428,
#   3234],
#  [15, 8344, 65, 9, 10, 5, 109, 35, 237, 4645, 119],
#  [344,
#   3,
#   563,
#   15,
#   8345,
#   33,
#   781,
#   3,
#   85,
#   781,
#   192,
#   53,
#   250,
#   82,
#   85,
#   8346,
#   8347,
#   8348,
#   8349,
#   5,
#   661,
#   545,
#   433],
#  [1381,
#   342,
#   15,
#   85,
#   200,
#   318,
#   34,
#   3,
#   72,
#   192,
#   53,
#   1361,
#   520,
#   941,
#   92,
#   2601,
#   75,
#   52,
#   75,
#   19,
#   210,
#   8350,
#   1002,
#   6,
#   75,
#   1542,
#   19],
#  [23, 16, 2722, 210, 57, 75, 1940, 3235, 106, 2302, 75, 57, 8351, 6322, 2722],
#  [30,
#   29,
#   75,
#   42,
#   671,
#   175,
#   396,
#   5,
#   103,
#   5,
#   5288,
#   148,
#   101,
#   834,
#   35,
#   107,
#   4159,
#   377,
#   761,
#   1995,
#   77,
#   3,
#   414,
#   57,
#   10,
#   80,
#   199,
#   45,
#   75,
#   172,
#   75],
#  [38, 147, 1, 56, 7, 352, 37, 1003, 169, 766, 352, 9, 3, 766],
#  [3779,
#   5288,
#   596,
#   4160,
#   63,
#   8352,
#   80,
#   390,
#   322,
#   6323,
#   872,
#   393,
#   94,
#   1077,
#   123,
#   788,
#   57,
#   100,
#   3779,
#   316,
#   35,
#   35,
#   74,
#   51,
#   1077,
#   494,
#   47,
#   25,
#   37,
#   1586,
#   57,
#   92,
#   89,
#   237,
#   6,
#   110,
#   270,
#   20,
#   342,
#   61,
#   3779,
#   7,
#   5289,
#   21,
#   133,
#   672,
#   125,
#   3779,
#   5288,
#   596,
#   4160,
#   63,
#   20],
#  [294,
#   3779,
#   1023,
#   1,
#   571,
#   1023,
#   586,
#   26,
#   800,
#   826,
#   4,
#   17,
#   1023,
#   96,
#   72,
#   58,
#   1361,
#   31,
#   40,
#   72,
#   54,
#   157,
#   101,
#   31,
#   1,
#   180,
#   15,
#   115,
#   296,
#   2392,
#   386,
#   10,
#   8353,
#   10,
#   849,
#   1023],
#  [13, 286, 1475, 80, 12, 110, 504, 80, 914, 61, 172, 1475, 493],
#  [15, 782, 493, 15, 53, 157, 9, 199, 45, 5, 1, 11, 216, 50, 2066, 782, 1108],
#  [103, 371, 569, 15, 115, 220, 383, 71, 194, 303, 900, 14, 77, 15, 8354, 1298],
#  [126,
#   469,
#   75,
#   82,
#   3236,
#   12,
#   454,
#   157,
#   1440,
#   1791,
#   1410,
#   75,
#   429,
#   1,
#   187,
#   126,
#   775,
#   74,
#   2723,
#   251,
#   82,
#   82],
#  [575,
#   1360,
#   429,
#   1410,
#   668,
#   2067,
#   199,
#   45,
#   32,
#   457,
#   2068,
#   722,
#   1891,
#   27,
#   5,
#   5,
#   1056,
#   6324,
#   251,
#   575,
#   429],
#  [6,
#   2220,
#   706,
#   799,
#   8355,
#   4151,
#   458,
#   31,
#   14,
#   338,
#   799,
#   440,
#   40,
#   75,
#   742,
#   6325,
#   8356,
#   2220,
#   799],
#  [15, 3477, 454, 2, 85, 303, 73, 278, 817, 15],
#  [313, 16, 7, 1411, 48, 14, 44, 29, 285, 3028, 313],
#  [15, 8357, 192, 147, 36, 80, 2876, 1057, 1187, 15, 36, 65],
#  [2877,
#   65,
#   172,
#   6326,
#   95,
#   105,
#   54,
#   40,
#   192,
#   46,
#   37,
#   298,
#   200,
#   2878,
#   129,
#   197,
#   24,
#   521,
#   107,
#   50,
#   2602,
#   504,
#   2603,
#   644,
#   176,
#   53,
#   61,
#   80,
#   12,
#   110,
#   30,
#   104,
#   172,
#   6326,
#   586],
#  [6,
#   504,
#   1054,
#   122,
#   5290,
#   1611,
#   1,
#   2,
#   504,
#   31,
#   891,
#   668,
#   63,
#   37,
#   615,
#   61,
#   80,
#   31,
#   119,
#   132,
#   50,
#   6,
#   504,
#   1054,
#   122,
#   5290,
#   1611],
#  [958,
#   714,
#   65,
#   39,
#   65,
#   107,
#   527,
#   3780,
#   1,
#   1314,
#   1004,
#   1299,
#   298,
#   65,
#   107,
#   1,
#   147,
#   65,
#   77,
#   1444,
#   16,
#   1249,
#   31,
#   230,
#   206,
#   2,
#   86,
#   69,
#   2303,
#   33,
#   2138,
#   236,
#   3029,
#   2,
#   1792,
#   2393,
#   13,
#   69,
#   714,
#   466,
#   21],
#  [6327,
#   65,
#   37,
#   22,
#   35,
#   141,
#   520,
#   5,
#   141,
#   654,
#   107,
#   3,
#   298,
#   197,
#   1540,
#   700,
#   520,
#   615,
#   2139,
#   504,
#   2603,
#   668,
#   1688,
#   3237,
#   921,
#   8358,
#   8359,
#   344,
#   10,
#   10,
#   2,
#   80,
#   6327,
#   65],
#  [106,
#   1471,
#   799,
#   420,
#   501,
#   50,
#   106,
#   1471,
#   92,
#   8360,
#   728,
#   8361,
#   2220,
#   8362,
#   106,
#   1471,
#   420],
#  [258,
#   5,
#   6,
#   80,
#   191,
#   61,
#   882,
#   204,
#   8,
#   1738,
#   1738,
#   201,
#   75,
#   1739,
#   15,
#   12,
#   3,
#   80,
#   350,
#   61,
#   100,
#   29,
#   123,
#   33,
#   12,
#   55,
#   15],
#  [32,
#   65,
#   922,
#   332,
#   11,
#   65,
#   33,
#   48,
#   27,
#   10,
#   226,
#   5,
#   282,
#   6328,
#   28,
#   1076,
#   11,
#   1040,
#   5291,
#   100,
#   99,
#   1,
#   8,
#   72,
#   688,
#   818,
#   89,
#   1892,
#   4161,
#   65,
#   45,
#   65,
#   942,
#   80,
#   117,
#   8363,
#   65,
#   23,
#   1740,
#   128,
#   21,
#   733,
#   688,
#   6,
#   942,
#   80,
#   251],
#  [65,
#   2394,
#   689,
#   319,
#   328,
#   662,
#   4161,
#   914,
#   1,
#   131,
#   12,
#   2069,
#   1893,
#   767,
#   16,
#   65,
#   8,
#   688,
#   733,
#   1109],
#  [743,
#   733,
#   65,
#   172,
#   145,
#   4162,
#   914,
#   132,
#   50,
#   216,
#   11,
#   6328,
#   61,
#   3781,
#   218,
#   81,
#   3781,
#   65,
#   5,
#   27,
#   197,
#   22,
#   1147,
#   8364,
#   4161],
#  [37, 16, 1108, 1892, 35, 1024, 10, 65, 1, 1587, 568, 4163, 8365, 65, 191],
#  [4164,
#   1162,
#   3238,
#   58,
#   185,
#   433,
#   65,
#   210,
#   2221,
#   914,
#   4161,
#   2879,
#   740,
#   570,
#   1108,
#   688,
#   2069,
#   4165,
#   8366,
#   100,
#   446,
#   65,
#   2724,
#   80,
#   1273,
#   38,
#   446,
#   83,
#   390,
#   15,
#   5292,
#   914,
#   1,
#   8,
#   12,
#   65,
#   8367,
#   57,
#   688,
#   2069,
#   3030,
#   8368,
#   2221,
#   4161,
#   57,
#   688],
#  [3,
#   410,
#   237,
#   65,
#   1643,
#   768,
#   217,
#   6329,
#   3782,
#   128,
#   127,
#   2725,
#   835,
#   1793,
#   3783,
#   1501,
#   690,
#   454,
#   787,
#   218,
#   640,
#   706,
#   65,
#   143,
#   342,
#   427,
#   11,
#   86,
#   51,
#   65,
#   6330,
#   1940,
#   85,
#   242,
#   350,
#   2880,
#   4137,
#   362,
#   3,
#   10],
#  [38,
#   36,
#   495,
#   276,
#   230,
#   141,
#   65,
#   453,
#   2881,
#   277,
#   663,
#   277,
#   160,
#   495,
#   30,
#   260,
#   9,
#   1838,
#   160,
#   212,
#   1,
#   649,
#   6331,
#   160,
#   202],
#  [211,
#   218,
#   1741,
#   5293,
#   959,
#   10,
#   65,
#   282,
#   9,
#   2388,
#   50,
#   109,
#   63,
#   94,
#   85,
#   3,
#   362,
#   1839,
#   46,
#   3766,
#   142,
#   65,
#   9,
#   219,
#   45,
#   264,
#   11,
#   218,
#   17,
#   242,
#   4166,
#   8,
#   549,
#   851,
#   2725],
#  [60, 1164, 315, 65, 257, 1077, 3784, 3, 1941, 85, 12, 212, 31, 2725, 767, 65],
#  [15, 493, 36, 40, 47, 11, 8369, 6332, 36, 252],
#  [16,
#   520,
#   543,
#   23,
#   65,
#   252,
#   689,
#   23,
#   50,
#   227,
#   1689,
#   145,
#   114,
#   715,
#   1166,
#   8370,
#   132,
#   16,
#   6,
#   8371,
#   8,
#   8372,
#   8373,
#   325,
#   459,
#   2070,
#   27,
#   158,
#   9,
#   11,
#   360,
#   50,
#   12,
#   482,
#   2882,
#   5294,
#   85,
#   2395,
#   107,
#   137,
#   141,
#   1445,
#   47,
#   305,
#   1502,
#   335,
#   1690,
#   8374,
#   5295,
#   99,
#   1,
#   193,
#   65,
#   409,
#   85,
#   67,
#   3478,
#   141,
#   8,
#   728,
#   1300,
#   2140,
#   716,
#   85,
#   52,
#   310,
#   689,
#   85,
#   5,
#   141,
#   2726,
#   3479,
#   684,
#   8,
#   534,
#   5296,
#   405,
#   3785,
#   2604,
#   6333,
#   139,
#   9,
#   1,
#   313,
#   187,
#   649,
#   8375,
#   65,
#   3031,
#   121,
#   50,
#   278],
#  [11,
#   75,
#   2484,
#   246,
#   3786,
#   2484,
#   5,
#   1996,
#   1543,
#   121,
#   669,
#   372,
#   3239,
#   1996,
#   458,
#   4646,
#   4137,
#   4647,
#   30,
#   1336,
#   396,
#   1358,
#   1691,
#   669,
#   749,
#   135,
#   97,
#   4648,
#   1996,
#   1997,
#   106,
#   1164,
#   1996,
#   271,
#   848,
#   776,
#   396,
#   1167,
#   669,
#   1474,
#   75,
#   226,
#   749,
#   1232,
#   3480,
#   1996,
#   116,
#   1996,
#   1,
#   2883,
#   47,
#   808,
#   83,
#   2304,
#   386,
#   2727,
#   818,
#   4649,
#   316,
#   1270,
#   2071,
#   316,
#   116,
#   316,
#   61,
#   209,
#   5297,
#   2141,
#   3787,
#   1998,
#   4167,
#   316,
#   75,
#   512,
#   4650,
#   1943,
#   3032,
#   267,
#   1692,
#   960,
#   389,
#   170,
#   154,
#   729,
#   53,
#   655,
#   1996,
#   427,
#   760,
#   292,
#   31,
#   181,
#   4646,
#   1839,
#   172,
#   1644,
#   4651,
#   75,
#   264,
#   1132,
#   316,
#   187,
#   1996,
#   292,
#   1164,
#   5298,
#   1996,
#   1104,
#   117,
#   8376,
#   3240,
#   8377,
#   3241,
#   1645,
#   5299,
#   8378,
#   5300,
#   5299,
#   6334,
#   1042,
#   75,
#   264,
#   1446,
#   8379,
#   94,
#   1996,
#   396],
#  [47,
#   300,
#   35,
#   4162,
#   52,
#   128,
#   127,
#   8380,
#   1646,
#   191,
#   122,
#   430,
#   132,
#   8,
#   91,
#   1204,
#   10,
#   457,
#   65,
#   1078,
#   119,
#   25,
#   457,
#   485,
#   89,
#   1471,
#   787,
#   246,
#   862,
#   4162,
#   2485,
#   4168,
#   1840,
#   6335,
#   521,
#   1471,
#   765,
#   35,
#   87,
#   1691,
#   8381,
#   2485,
#   538,
#   3788,
#   5301,
#   2485,
#   1742,
#   1102,
#   8382,
#   8383,
#   6336,
#   149,
#   176,
#   8384,
#   8385,
#   6336,
#   42,
#   726,
#   492,
#   8386,
#   8387,
#   8388,
#   72,
#   1233,
#   8389,
#   6337,
#   104,
#   777,
#   1743,
#   8390,
#   6338,
#   8391,
#   8392,
#   8393,
#   2486,
#   3789,
#   8394,
#   8395,
#   5302,
#   48,
#   1299,
#   77,
#   5301,
#   2485,
#   521,
#   2884,
#   265,
#   1691,
#   87,
#   123,
#   77,
#   3,
#   3772,
#   1412,
#   1205,
#   1646,
#   9,
#   219,
#   138,
#   3790,
#   3,
#   136,
#   65,
#   1412,
#   4162],
#  [26, 11, 7, 3, 80, 8396, 6339, 402, 15, 136, 4, 119],
#  [78,
#   28,
#   695,
#   169,
#   6340,
#   3773,
#   3481,
#   1541,
#   235,
#   19,
#   2305,
#   3482,
#   169,
#   1078,
#   29,
#   75,
#   1298,
#   572,
#   18,
#   25,
#   169,
#   4,
#   3,
#   2728,
#   3242,
#   3243,
#   8397,
#   572,
#   18,
#   1079,
#   64,
#   66,
#   40,
#   401,
#   1544,
#   156,
#   836,
#   2072,
#   169,
#   19,
#   1025,
#   163,
#   157,
#   107,
#   1003,
#   94,
#   157,
#   107,
#   1043,
#   61,
#   6,
#   767,
#   1058,
#   176,
#   1545,
#   176,
#   650,
#   1691,
#   482,
#   493,
#   53,
#   5,
#   107,
#   460,
#   5,
#   836,
#   1894,
#   50,
#   169,
#   482,
#   960,
#   109,
#   107,
#   31,
#   1382,
#   2729,
#   50,
#   381,
#   6341,
#   66,
#   836,
#   52,
#   129,
#   107,
#   415,
#   25,
#   92,
#   6340,
#   1,
#   522,
#   442,
#   366,
#   220,
#   420,
#   1274,
#   1275,
#   160,
#   48,
#   3,
#   29,
#   169,
#   19,
#   1841,
#   6,
#   8398,
#   19],
#  [575,
#   268,
#   1026,
#   3244,
#   6,
#   1313,
#   5303,
#   2885,
#   1043,
#   330,
#   2605,
#   6342,
#   6342,
#   1,
#   521],
#  [363,
#   484,
#   268,
#   47,
#   3791,
#   633,
#   2487,
#   399,
#   3483,
#   2730,
#   386,
#   645,
#   577,
#   941,
#   61,
#   351,
#   208,
#   399,
#   4,
#   1206,
#   748,
#   6343,
#   1355,
#   253,
#   3484,
#   589,
#   8399,
#   83,
#   1889,
#   208,
#   399,
#   287,
#   941,
#   367,
#   921,
#   1413,
#   3245,
#   8400,
#   724,
#   748,
#   530,
#   590,
#   5,
#   1999,
#   589,
#   1744,
#   3,
#   1088,
#   1337,
#   25,
#   4652,
#   3033,
#   74,
#   97,
#   2730,
#   212,
#   1,
#   26,
#   83,
#   27,
#   28,
#   182,
#   999,
#   2731,
#   4,
#   68,
#   941,
#   386,
#   629,
#   2606,
#   645,
#   577,
#   4,
#   12,
#   140,
#   386,
#   5304,
#   748,
#   278,
#   500,
#   461,
#   850,
#   1107,
#   4169,
#   386,
#   748,
#   1943,
#   5,
#   1206,
#   4653,
#   106,
#   457,
#   291,
#   793,
#   50,
#   748,
#   2073,
#   97,
#   457,
#   827,
#   3485,
#   2730,
#   68,
#   3232,
#   2,
#   2731,
#   48,
#   806,
#   251,
#   268,
#   2886,
#   585,
#   2,
#   8401,
#   3486,
#   8,
#   941,
#   37,
#   47,
#   33,
#   20,
#   794,
#   900,
#   97,
#   6344,
#   22,
#   59,
#   50,
#   278,
#   58,
#   37,
#   316,
#   48,
#   9,
#   33,
#   196,
#   77,
#   2,
#   6344,
#   3232,
#   4654,
#   19,
#   2731,
#   1356,
#   8402,
#   168,
#   8403,
#   358,
#   1362,
#   1895,
#   75,
#   8404,
#   494,
#   155,
#   591,
#   654,
#   633,
#   1110,
#   2,
#   500,
#   3473,
#   155,
#   2488,
#   1,
#   268,
#   48,
#   59,
#   91,
#   5,
#   268,
#   155,
#   8405,
#   74,
#   268,
#   37,
#   2,
#   1588,
#   48,
#   669,
#   848,
#   4652,
#   484,
#   61,
#   35,
#   446,
#   438,
#   901,
#   485,
#   1745,
#   1355,
#   253,
#   6345,
#   4655,
#   422,
#   63,
#   137,
#   438,
#   2074,
#   1745,
#   2730,
#   423,
#   367,
#   585,
#   941,
#   3232,
#   367,
#   585,
#   748,
#   671,
#   1207,
#   8406,
#   282,
#   138,
#   3,
#   251,
#   4,
#   12],
#  [461,
#   183,
#   2222,
#   2,
#   127,
#   1,
#   1414,
#   601,
#   230,
#   461,
#   10,
#   106,
#   5,
#   127,
#   3246,
#   81,
#   220,
#   601,
#   2222,
#   4,
#   2731],
#  [30,
#   5,
#   92,
#   3487,
#   293,
#   1,
#   4,
#   79,
#   837,
#   1383,
#   2731,
#   124,
#   367,
#   22,
#   424,
#   609,
#   837,
#   5,
#   412,
#   2489,
#   2490,
#   484,
#   2887,
#   3247,
#   227,
#   5,
#   2490,
#   1842,
#   4170,
#   330,
#   311,
#   237,
#   46,
#   8,
#   97,
#   293,
#   2222,
#   46,
#   827,
#   2730,
#   2,
#   594,
#   1471,
#   397,
#   22,
#   424,
#   609,
#   97,
#   483,
#   2731,
#   199,
#   783,
#   477,
#   241,
#   815,
#   1589,
#   815,
#   2731,
#   367,
#   1,
#   97,
#   382,
#   1612,
#   295,
#   1089,
#   691,
#   5,
#   8],
#  [999,
#   86,
#   3473,
#   4656,
#   6346,
#   2731,
#   4657,
#   898,
#   3792,
#   4,
#   113,
#   12,
#   1896,
#   4658,
#   6347,
#   365,
#   8407,
#   1503,
#   633,
#   5305,
#   2223,
#   2142,
#   8408,
#   484,
#   1363,
#   609,
#   186,
#   67,
#   562,
#   208,
#   123,
#   438,
#   484,
#   182,
#   1,
#   4,
#   5,
#   97,
#   5,
#   106,
#   5,
#   40,
#   1,
#   94,
#   585,
#   3034,
#   4171,
#   8,
#   52,
#   690,
#   5,
#   206,
#   2731,
#   6346,
#   744,
#   225,
#   20,
#   9,
#   56,
#   429,
#   974,
#   6347,
#   365],
#  [4, 12, 351, 1, 11, 329, 104, 8409, 3035, 3793, 640, 268, 6, 7],
#  [799,
#   275,
#   8410,
#   799,
#   1315,
#   700,
#   5306,
#   1693,
#   799,
#   24,
#   2,
#   275,
#   12,
#   212,
#   799,
#   3794,
#   8411],
#  [77, 16, 262, 1, 1168, 204, 27, 52, 30, 65, 8412, 15],
#  [199,
#   45,
#   3,
#   253,
#   16,
#   3,
#   254,
#   15,
#   1944,
#   20,
#   23,
#   3,
#   19,
#   119,
#   10,
#   3,
#   237,
#   3,
#   19],
#  [110,
#   167,
#   63,
#   30,
#   28,
#   6348,
#   6349,
#   6,
#   160,
#   762,
#   167,
#   1186,
#   819,
#   194,
#   69,
#   819,
#   194,
#   882,
#   137,
#   1447,
#   56,
#   323,
#   100,
#   116,
#   347,
#   1,
#   115,
#   85,
#   571,
#   1,
#   77,
#   23,
#   134,
#   1,
#   85],
#  [118, 237, 1208, 477, 319, 83, 2396, 30, 82, 120, 121, 25, 492, 502, 795],
#  [11,
#   753,
#   33,
#   1234,
#   14,
#   21,
#   1108,
#   186,
#   99,
#   1,
#   260,
#   70,
#   112,
#   1,
#   6350,
#   685,
#   112,
#   1111,
#   8413,
#   8414,
#   1027,
#   687,
#   297,
#   41,
#   34,
#   28,
#   33,
#   1504,
#   559,
#   585,
#   47,
#   299,
#   91,
#   1044,
#   112,
#   104,
#   41,
#   70,
#   16,
#   29,
#   123,
#   94,
#   290,
#   174,
#   56,
#   291,
#   437,
#   174,
#   1941,
#   193,
#   70,
#   27,
#   607,
#   444,
#   95,
#   1384,
#   447,
#   70,
#   3478,
#   1414,
#   8415,
#   31,
#   1384,
#   187,
#   61,
#   71,
#   170,
#   194,
#   239,
#   5307,
#   1384,
#   47,
#   60,
#   208,
#   20,
#   13,
#   1079,
#   406,
#   11,
#   416,
#   281,
#   347,
#   59,
#   13,
#   1384,
#   28,
#   783,
#   422,
#   239,
#   174,
#   281,
#   587,
#   873,
#   46,
#   1384,
#   1,
#   398,
#   6,
#   72,
#   298,
#   197,
#   298,
#   332,
#   5,
#   754,
#   154,
#   1384,
#   29,
#   297,
#   399,
#   1,
#   187,
#   72,
#   13,
#   239,
#   707,
#   197,
#   21,
#   3,
#   70,
#   3,
#   27,
#   462,
#   409,
#   2000,
#   22,
#   79,
#   46,
#   1384,
#   1,
#   187,
#   72,
#   13,
#   1,
#   10,
#   104,
#   281,
#   3,
#   21,
#   187,
#   1384],
#  [3,
#   14,
#   569,
#   70,
#   86,
#   278,
#   70,
#   28,
#   281,
#   1546,
#   22,
#   401,
#   874,
#   3036,
#   220,
#   1,
#   14,
#   1384],
#  [3,
#   64,
#   239,
#   5,
#   20,
#   763,
#   239,
#   70,
#   59,
#   27,
#   499,
#   795,
#   2397,
#   28,
#   112,
#   4,
#   3,
#   685,
#   389,
#   499,
#   68,
#   22,
#   225,
#   70,
#   838,
#   270,
#   122,
#   22,
#   707,
#   14,
#   1045,
#   70,
#   234,
#   507,
#   41,
#   47,
#   95,
#   20,
#   112,
#   14,
#   8416,
#   8,
#   68,
#   6351,
#   1338,
#   212,
#   239,
#   59,
#   302,
#   82,
#   2,
#   377,
#   281,
#   61,
#   30,
#   685,
#   133,
#   1794,
#   70,
#   28,
#   52,
#   22,
#   225,
#   24,
#   68,
#   269,
#   24,
#   68,
#   22,
#   225,
#   24,
#   47,
#   366,
#   1384,
#   814,
#   257,
#   1384,
#   70,
#   852,
#   60,
#   75,
#   138,
#   3,
#   7,
#   28,
#   52,
#   578],
#  [2,
#   60,
#   441,
#   281,
#   106,
#   98,
#   35,
#   685,
#   239,
#   112,
#   70,
#   342,
#   239,
#   98,
#   35,
#   2491,
#   44,
#   260,
#   1,
#   455,
#   70,
#   162,
#   615,
#   3248,
#   3037,
#   14,
#   14,
#   2001,
#   1364,
#   82,
#   31,
#   47,
#   29,
#   4659,
#   25,
#   1414,
#   1044,
#   70,
#   8417,
#   1335,
#   762,
#   113,
#   24,
#   265,
#   5,
#   366,
#   47,
#   64,
#   874,
#   8,
#   1384,
#   70,
#   470,
#   14,
#   16,
#   3,
#   1384],
#  [78,
#   373,
#   179,
#   943,
#   69,
#   413,
#   21,
#   239,
#   14,
#   170,
#   24,
#   2,
#   118,
#   3488,
#   21,
#   29,
#   2598,
#   70,
#   769,
#   42,
#   509,
#   471,
#   281,
#   47,
#   20,
#   2732,
#   1547,
#   28,
#   281,
#   265,
#   576,
#   281,
#   239,
#   14,
#   685],
#  [122,
#   112,
#   397,
#   291,
#   281,
#   664,
#   436,
#   8,
#   281,
#   14,
#   67,
#   26,
#   3,
#   70,
#   74,
#   239,
#   460,
#   942,
#   1647,
#   389,
#   281,
#   1415,
#   19,
#   13,
#   6,
#   243,
#   91,
#   3,
#   1358,
#   942,
#   664],
#  [3,
#   14,
#   664,
#   1794,
#   85,
#   2,
#   8418,
#   31,
#   99,
#   1,
#   260,
#   765,
#   8419,
#   70,
#   5,
#   21,
#   118,
#   673,
#   99,
#   1,
#   8,
#   85,
#   961,
#   406,
#   22,
#   683,
#   1079,
#   180,
#   75,
#   85,
#   77,
#   656,
#   24,
#   2,
#   685,
#   394,
#   4172,
#   239,
#   14,
#   21,
#   85,
#   406,
#   14,
#   3,
#   1384,
#   1,
#   3],
#  [1,
#   48,
#   4,
#   12,
#   112,
#   4,
#   1235,
#   685,
#   349,
#   1,
#   232,
#   685,
#   6352,
#   8,
#   21,
#   239,
#   275,
#   513,
#   239,
#   14,
#   883,
#   94,
#   113,
#   1235,
#   2,
#   685],
#  [14,
#   13,
#   239,
#   16,
#   3,
#   350,
#   70,
#   685,
#   6353,
#   112,
#   8420,
#   500,
#   70,
#   28,
#   324,
#   1,
#   6350,
#   366,
#   508,
#   14,
#   121,
#   1045,
#   112,
#   77,
#   1024,
#   112,
#   863,
#   194,
#   14,
#   2733,
#   1015,
#   66,
#   174,
#   239,
#   33,
#   178,
#   2888,
#   607,
#   9,
#   692,
#   36,
#   117,
#   15,
#   14],
#  [2,
#   685,
#   70,
#   3,
#   30,
#   4172,
#   70,
#   6354,
#   962,
#   2,
#   281,
#   14,
#   37,
#   4172,
#   70,
#   2,
#   170,
#   70,
#   6354,
#   281,
#   14,
#   2734,
#   8421,
#   6,
#   2,
#   281,
#   14,
#   162,
#   125,
#   884,
#   1384,
#   14,
#   246,
#   590,
#   70,
#   319,
#   240,
#   95,
#   281,
#   437,
#   174,
#   505,
#   281,
#   14,
#   2733,
#   1015,
#   1384,
#   4173,
#   14,
#   864,
#   789,
#   193,
#   246,
#   2,
#   281,
#   14],
#  [1,
#   139,
#   12,
#   9,
#   4,
#   112,
#   685,
#   1448,
#   239,
#   6355,
#   8422,
#   3,
#   112,
#   204,
#   28,
#   281,
#   2143,
#   291,
#   423,
#   2144,
#   281,
#   70,
#   349,
#   1276,
#   204,
#   291,
#   3489,
#   664,
#   281,
#   262,
#   14,
#   3,
#   24,
#   6356,
#   199,
#   45,
#   70,
#   21,
#   975,
#   239,
#   14,
#   31,
#   1539,
#   560,
#   22,
#   6357,
#   79,
#   158,
#   1476,
#   239,
#   11,
#   793,
#   9,
#   2139,
#   473,
#   136,
#   5308,
#   1005,
#   149,
#   4,
#   3,
#   685,
#   6355,
#   6353],
#  [8423,
#   3795,
#   70,
#   685,
#   1448,
#   239,
#   112,
#   326,
#   64,
#   66,
#   2,
#   281,
#   303,
#   3795,
#   170,
#   239,
#   14],
#  [58,
#   14,
#   197,
#   130,
#   310,
#   85,
#   112,
#   685,
#   4660,
#   1613,
#   14,
#   975,
#   281,
#   85,
#   837,
#   29,
#   141,
#   132,
#   10,
#   14,
#   139,
#   177,
#   2,
#   14,
#   837,
#   141],
#  [14,
#   5309,
#   820,
#   128,
#   21,
#   70,
#   6,
#   577,
#   717,
#   8424,
#   1384,
#   6358,
#   144,
#   47,
#   64,
#   20,
#   874,
#   4,
#   1,
#   48,
#   9,
#   530,
#   4172,
#   1794,
#   70,
#   56,
#   193,
#   170,
#   9,
#   24,
#   243,
#   23,
#   21,
#   64,
#   1384],
#  [1209,
#   975,
#   239,
#   14,
#   66,
#   174,
#   2306,
#   85,
#   34,
#   21,
#   513,
#   354,
#   6359,
#   734,
#   70,
#   1,
#   2145,
#   178,
#   792,
#   32,
#   255,
#   21,
#   1111,
#   128,
#   2398,
#   14,
#   19,
#   178,
#   1794,
#   170,
#   81,
#   557,
#   8425,
#   66,
#   1301,
#   1,
#   174,
#   270,
#   336,
#   597,
#   1,
#   486,
#   239,
#   2000,
#   275,
#   71,
#   403,
#   85,
#   6360,
#   1,
#   345,
#   685,
#   239,
#   14,
#   1731,
#   85,
#   8426,
#   34],
#  [2, 55, 13, 408, 80, 69, 1795, 166, 4, 3, 2, 111, 284, 338, 105, 4],
#  [7,
#   4,
#   12,
#   685,
#   112,
#   1,
#   839,
#   68,
#   70,
#   5,
#   107,
#   20,
#   929,
#   963,
#   47,
#   63,
#   66,
#   174,
#   108,
#   22,
#   839,
#   68,
#   28,
#   275,
#   8427,
#   24,
#   2,
#   3,
#   7],
#  [37,
#   795,
#   4,
#   112,
#   86,
#   1897,
#   27,
#   692,
#   170,
#   170,
#   257,
#   1,
#   1301,
#   96,
#   1897,
#   40,
#   693,
#   112,
#   53,
#   70,
#   434,
#   5,
#   4,
#   12,
#   220,
#   88],
#  [1,
#   1363,
#   5277,
#   902,
#   9,
#   4,
#   735,
#   16,
#   352,
#   125,
#   1,
#   139,
#   550,
#   7,
#   420,
#   564,
#   9,
#   61,
#   67,
#   405,
#   427,
#   22,
#   1301,
#   22,
#   79,
#   843,
#   8428,
#   8429,
#   3490,
#   8430,
#   4,
#   3,
#   4,
#   93,
#   123,
#   552,
#   112],
#  [44,
#   61,
#   255,
#   1104,
#   9,
#   3249,
#   56,
#   352,
#   69,
#   99,
#   1,
#   2,
#   112,
#   2,
#   1210,
#   112,
#   282,
#   570,
#   9,
#   70,
#   12,
#   104,
#   195,
#   2,
#   3250,
#   70,
#   132,
#   174,
#   46,
#   63,
#   594,
#   277,
#   616,
#   78,
#   70,
#   8431,
#   213,
#   839,
#   795,
#   1,
#   263],
#  [839, 27, 552, 1648, 112, 892, 174, 667, 9, 199, 45, 7, 8432, 7],
#  [2, 795, 428, 57, 70, 650, 283, 4, 12, 875, 6, 21, 795],
#  [2,
#   408,
#   7,
#   986,
#   1589,
#   198,
#   487,
#   2735,
#   2736,
#   51,
#   39,
#   5310,
#   23,
#   24,
#   2,
#   112,
#   132,
#   853,
#   23,
#   149,
#   479,
#   36],
#  [5311,
#   41,
#   4,
#   5,
#   238,
#   17,
#   5312,
#   903,
#   25,
#   561,
#   728,
#   1548,
#   1642,
#   17,
#   839,
#   795,
#   16,
#   96,
#   1339,
#   3038,
#   904,
#   19,
#   765,
#   392,
#   10,
#   92,
#   2,
#   207,
#   97,
#   112,
#   638,
#   2307,
#   2737,
#   112,
#   2492,
#   557,
#   388,
#   125,
#   66,
#   1301,
#   6361,
#   2,
#   1449,
#   244,
#   66,
#   165,
#   171,
#   244,
#   2,
#   2307,
#   5,
#   107,
#   20,
#   557,
#   8433,
#   28,
#   455,
#   21,
#   5,
#   119,
#   474,
#   32,
#   78,
#   20,
#   793],
#  [430, 69, 796, 839, 551, 1076, 93, 4, 3, 99, 1, 618, 19, 21, 3, 10],
#  [7, 3, 13, 479, 2075, 722, 1897, 1, 33, 171, 2307, 66, 132, 174, 119, 7, 119],
#  [4,
#   3,
#   552,
#   112,
#   1250,
#   88,
#   6,
#   265,
#   10,
#   9,
#   45,
#   7,
#   186,
#   37,
#   839,
#   326,
#   20,
#   8,
#   4,
#   552,
#   112],
#  [69, 839, 5313, 163, 176, 5314, 429, 87, 527, 180, 26, 11, 23],
#  [127, 1, 4661, 81, 3, 7, 3, 19, 291, 429, 4, 1744, 1, 340, 686, 3, 429, 4662],
#  [61,
#   443,
#   117,
#   6362,
#   20,
#   1,
#   2,
#   112,
#   284,
#   5,
#   112,
#   1897,
#   1112,
#   2737,
#   492,
#   13,
#   479,
#   4,
#   3,
#   2,
#   53,
#   164,
#   944,
#   2,
#   1497,
#   583,
#   279,
#   9,
#   4,
#   3,
#   127,
#   238,
#   8434,
#   130,
#   862,
#   1,
#   79,
#   963,
#   163,
#   214,
#   553,
#   1,
#   67,
#   553,
#   216,
#   479,
#   652,
#   507,
#   17,
#   95,
#   1385,
#   20,
#   119,
#   32,
#   9,
#   10,
#   158,
#   6],
#  [78,
#   351,
#   128,
#   21,
#   795,
#   1045,
#   8435,
#   2307,
#   128,
#   1746,
#   124,
#   8436,
#   1694,
#   255,
#   19,
#   795,
#   87,
#   372,
#   257,
#   1945,
#   495,
#   610,
#   151,
#   185,
#   8437,
#   1897,
#   31,
#   1004,
#   1251,
#   1316,
#   795,
#   70,
#   33,
#   24,
#   4663,
#   1148,
#   1945,
#   495,
#   372,
#   1251,
#   1316,
#   795,
#   202,
#   236,
#   25,
#   586,
#   128,
#   1746,
#   1843,
#   6363,
#   552,
#   2307,
#   534,
#   255,
#   202,
#   195,
#   1277,
#   8438,
#   46,
#   637,
#   170,
#   1045,
#   6364,
#   715,
#   2076,
#   142,
#   839,
#   795,
#   1,
#   1188,
#   8439,
#   514,
#   1251,
#   1316,
#   8440,
#   795,
#   3,
#   21,
#   839,
#   795],
#  [32,
#   408,
#   1747,
#   239,
#   1748,
#   112,
#   58,
#   66,
#   1747,
#   295,
#   11,
#   85,
#   66,
#   4174,
#   185,
#   546,
#   16,
#   181,
#   123,
#   839,
#   48,
#   5,
#   56,
#   66,
#   1648,
#   50,
#   1,
#   427,
#   1,
#   66,
#   1648,
#   112],
#  [4, 11, 56, 9, 275, 70, 3, 21, 4, 3, 891, 17, 3],
#  [1,
#   2,
#   4664,
#   279,
#   3471,
#   250,
#   2,
#   268,
#   425,
#   2,
#   64,
#   479,
#   14,
#   1189,
#   268,
#   289,
#   170,
#   2596,
#   107,
#   2,
#   616,
#   164,
#   213,
#   748,
#   941,
#   863,
#   79,
#   839,
#   13,
#   170,
#   2596,
#   943,
#   330,
#   1844,
#   1844,
#   3,
#   279],
#  [170,
#   27,
#   1796,
#   112,
#   39,
#   652,
#   66,
#   207,
#   12,
#   1251,
#   1316,
#   7,
#   21,
#   6,
#   592,
#   2,
#   7,
#   103,
#   1416,
#   508,
#   452,
#   3251,
#   55,
#   13,
#   4,
#   3,
#   112],
#  [7,
#   28,
#   270,
#   118,
#   414,
#   2,
#   1647,
#   111,
#   72,
#   27,
#   2307,
#   256,
#   1,
#   650,
#   1027,
#   420,
#   410,
#   237],
#  [25,
#   8441,
#   5,
#   1080,
#   23,
#   285,
#   4,
#   3,
#   552,
#   112,
#   174,
#   234,
#   1059,
#   13,
#   479,
#   1210,
#   47,
#   64,
#   424,
#   174,
#   963,
#   834,
#   576,
#   10,
#   144,
#   1080],
#  [326, 64, 81, 10, 303, 27, 657, 5315, 19, 21, 8442],
#  [592,
#   2,
#   839,
#   795,
#   1505,
#   1548,
#   484,
#   70,
#   2,
#   552,
#   112,
#   181,
#   598,
#   7,
#   5,
#   6,
#   19,
#   183,
#   25,
#   680,
#   325,
#   130,
#   384,
#   3,
#   19],
#  [17,
#   839,
#   795,
#   3252,
#   1897,
#   36,
#   795,
#   131,
#   56,
#   689,
#   479,
#   657,
#   138,
#   930,
#   290,
#   29,
#   2492,
#   1,
#   227,
#   147,
#   523,
#   2,
#   6365,
#   210,
#   329,
#   5,
#   14,
#   2601,
#   248,
#   1,
#   17,
#   523,
#   45,
#   795,
#   760,
#   2,
#   36,
#   795],
#  [16,
#   611,
#   3252,
#   5316,
#   122,
#   3252,
#   1649,
#   839,
#   795,
#   1500,
#   417,
#   4175,
#   279,
#   132,
#   353,
#   147,
#   616,
#   4,
#   3,
#   544,
#   1278,
#   5316,
#   4,
#   544,
#   1278,
#   511,
#   3252,
#   5316],
#  [3, 644, 1252, 1211, 254, 8443, 191, 288, 8444, 19],
#  [118, 7, 2, 32, 130, 1279, 539, 148, 195, 341, 1, 6, 1251, 1316, 839, 795],
#  [2,
#   839,
#   207,
#   20,
#   158,
#   6,
#   24,
#   987,
#   2,
#   34,
#   552,
#   112,
#   4,
#   2002,
#   42,
#   735,
#   839,
#   653,
#   6,
#   112,
#   767,
#   50,
#   1189,
#   6,
#   839,
#   112,
#   1897],
#  [7,
#   479,
#   290,
#   1,
#   4,
#   171,
#   112,
#   162,
#   38,
#   352,
#   311,
#   125,
#   48,
#   9,
#   61,
#   67,
#   171,
#   112,
#   1,
#   311,
#   125,
#   614,
#   4,
#   112,
#   8445,
#   17,
#   3491,
#   1946,
#   38,
#   352,
#   311,
#   125,
#   17,
#   316,
#   13,
#   83,
#   139,
#   4,
#   3,
#   479,
#   290,
#   1,
#   171,
#   112,
#   1,
#   335,
#   2,
#   272,
#   112],
#  [16,
#   6,
#   78,
#   70,
#   39,
#   70,
#   12,
#   72,
#   691,
#   2001,
#   387,
#   664,
#   140,
#   1189,
#   492,
#   6366,
#   87,
#   1113,
#   105,
#   180,
#   2,
#   99,
#   1,
#   2,
#   3253,
#   174,
#   164,
#   616,
#   164,
#   213,
#   124,
#   1301,
#   383,
#   552,
#   112,
#   1897,
#   1,
#   79,
#   126,
#   2492,
#   6367,
#   2399,
#   223,
#   923,
#   2],
#  [1,
#   110,
#   1212,
#   2146,
#   2493,
#   795,
#   2,
#   128,
#   2003,
#   795,
#   1897,
#   571,
#   8446,
#   110,
#   303,
#   1212],
#  [1450,
#   708,
#   7,
#   36,
#   13,
#   357,
#   80,
#   302,
#   286,
#   1,
#   821,
#   745,
#   526,
#   178,
#   1060,
#   308,
#   661,
#   320,
#   131,
#   82],
#  [2,
#   408,
#   5317,
#   639,
#   357,
#   1681,
#   891,
#   181,
#   167,
#   5,
#   357,
#   308,
#   72,
#   1253,
#   412,
#   708,
#   302,
#   111,
#   16,
#   3,
#   4,
#   3],
#  [196, 88, 44, 25, 130, 384, 89, 2889, 36, 1006, 639, 357, 4, 3],
#  [24, 13, 782, 509, 639, 357, 446, 451, 115, 37, 3, 639, 357],
#  [10, 4, 130, 106, 502, 290, 29, 228, 2889, 1357, 30, 68, 2889, 502, 290, 793],
#  [10,
#   13,
#   2738,
#   101,
#   357,
#   1061,
#   1000,
#   4,
#   3,
#   5,
#   2147,
#   144,
#   1,
#   162,
#   93,
#   70,
#   50,
#   755,
#   418,
#   17,
#   128,
#   755,
#   708,
#   418,
#   39,
#   3,
#   2,
#   1317,
#   53,
#   52,
#   143,
#   71,
#   4176,
#   9,
#   683,
#   1503,
#   1003,
#   482,
#   11,
#   3,
#   19,
#   101,
#   357],
#  [1,
#   2,
#   778,
#   284,
#   27,
#   158,
#   13,
#   5317,
#   357,
#   502,
#   4,
#   3,
#   119,
#   32,
#   13,
#   33,
#   24,
#   801,
#   101,
#   4665,
#   1169,
#   4,
#   3],
#  [121,
#   418,
#   809,
#   809,
#   68,
#   255,
#   755,
#   4,
#   6,
#   40,
#   79,
#   1415,
#   1417,
#   658,
#   661,
#   17,
#   17,
#   6,
#   146],
#  [32,
#   167,
#   167,
#   2148,
#   777,
#   418,
#   630,
#   20,
#   708,
#   33,
#   12,
#   243,
#   122,
#   195,
#   8,
#   630,
#   579,
#   2494,
#   2148,
#   777,
#   418,
#   634,
#   591,
#   2148,
#   20,
#   33,
#   7,
#   31,
#   36,
#   51,
#   639,
#   2,
#   250,
#   55,
#   200,
#   630,
#   2148,
#   777,
#   5318,
#   86,
#   204,
#   16,
#   527,
#   86,
#   250,
#   55,
#   4645,
#   243,
#   95,
#   708,
#   10,
#   5,
#   13,
#   2148,
#   98,
#   35,
#   810,
#   69,
#   243,
#   3,
#   7,
#   3,
#   19],
#  [131,
#   343,
#   2,
#   250,
#   55,
#   27,
#   93,
#   140,
#   78,
#   67,
#   708,
#   1842,
#   2,
#   71,
#   3039,
#   1,
#   16,
#   6,
#   27,
#   2,
#   708,
#   2,
#   755,
#   57,
#   357,
#   14,
#   2890,
#   1045,
#   302,
#   93,
#   412,
#   708],
#  [10,
#   122,
#   454,
#   177,
#   370,
#   238,
#   152,
#   25,
#   2,
#   639,
#   357,
#   17,
#   10,
#   86,
#   1081,
#   3,
#   2224,
#   179],
#  [44,
#   2,
#   733,
#   3492,
#   236,
#   1,
#   17,
#   630,
#   121,
#   85,
#   147,
#   193,
#   358,
#   44,
#   327,
#   173,
#   2592,
#   41,
#   17,
#   32,
#   9,
#   71,
#   579,
#   1058,
#   630,
#   121,
#   147,
#   70,
#   85],
#  [263, 59, 13, 639, 357, 451, 3, 59, 475, 172, 639, 357, 283, 782, 23],
#  [128,
#   21,
#   142,
#   288,
#   2,
#   502,
#   290,
#   235,
#   177,
#   115,
#   639,
#   357,
#   778,
#   27,
#   13,
#   1302,
#   357,
#   342,
#   80,
#   2,
#   594,
#   1213,
#   19,
#   257,
#   28,
#   10,
#   17,
#   9,
#   13,
#   3,
#   407,
#   238,
#   1114,
#   177],
#  [357, 6, 524, 2, 9, 10, 357, 47, 778],
#  [4,
#   3,
#   13,
#   639,
#   357,
#   2602,
#   778,
#   2,
#   8447,
#   1695,
#   61,
#   229,
#   1170,
#   415,
#   25,
#   639,
#   357],
#  [11, 357, 12, 13, 28, 256, 132, 83, 108, 17, 3, 166, 263],
#  [28,
#   37,
#   564,
#   44,
#   556,
#   55,
#   200,
#   630,
#   1,
#   694,
#   17,
#   204,
#   502,
#   357,
#   418,
#   1,
#   502,
#   290,
#   77,
#   67,
#   538,
#   27,
#   124,
#   546,
#   30,
#   131,
#   17,
#   1,
#   131,
#   82],
#  [635, 2077, 106, 5, 109, 778, 1446, 275, 24, 54, 8448, 778, 635, 72],
#  [4, 3, 218, 708, 885, 8, 6, 3796, 3797, 368, 3, 1443, 36, 531, 9, 357, 8449],
#  [92,
#   427,
#   924,
#   7,
#   1090,
#   347,
#   590,
#   924,
#   394,
#   1898,
#   3040,
#   822,
#   673,
#   6,
#   243,
#   86,
#   1003,
#   639,
#   357,
#   126,
#   3493,
#   454,
#   302,
#   250,
#   55,
#   357,
#   347,
#   924],
#  [110,
#   7,
#   69,
#   308,
#   22,
#   502,
#   630,
#   579,
#   226,
#   469,
#   475,
#   1793,
#   63,
#   476,
#   17,
#   30,
#   100,
#   322,
#   4666,
#   22,
#   21,
#   747],
#  [502, 384, 4, 3, 220, 89, 3494, 44, 50, 6, 166, 4, 3],
#  [201, 13, 1418, 7, 49, 250, 109, 5, 502, 184, 3, 29, 502, 630],
#  [204,
#   10,
#   104,
#   279,
#   408,
#   283,
#   8450,
#   357,
#   8451,
#   8452,
#   91,
#   2225,
#   350,
#   8453,
#   4,
#   3,
#   279,
#   2,
#   1016,
#   250,
#   55,
#   1003,
#   182,
#   1,
#   46,
#   17,
#   290,
#   13,
#   2891,
#   756,
#   2890,
#   384,
#   1650,
#   809,
#   6,
#   267,
#   774,
#   639,
#   357,
#   9,
#   16,
#   180,
#   1947,
#   236,
#   144,
#   1,
#   87,
#   11,
#   9,
#   223,
#   3041,
#   261,
#   6,
#   267,
#   156,
#   558],
#  [2, 817, 1681, 4, 3, 45, 17, 2226, 290, 684, 8454, 4177],
#  [6,
#   4667,
#   7,
#   2,
#   101,
#   357,
#   2607,
#   101,
#   4178,
#   9,
#   8,
#   180,
#   1947,
#   95,
#   2,
#   639,
#   357,
#   6,
#   7,
#   410,
#   472],
#  [347,
#   54,
#   357,
#   51,
#   122,
#   1,
#   2,
#   163,
#   69,
#   1,
#   1474,
#   275,
#   61,
#   117,
#   6368,
#   733,
#   502,
#   630,
#   639,
#   531,
#   9],
#  [17,
#   49,
#   80,
#   101,
#   4,
#   238,
#   61,
#   1797,
#   4,
#   184,
#   16,
#   3,
#   22,
#   79,
#   502,
#   212,
#   715,
#   270,
#   9,
#   8455,
#   2,
#   22,
#   366],
#  [502,
#   630,
#   1419,
#   26,
#   2227,
#   2,
#   6368,
#   708,
#   4,
#   184,
#   988,
#   455,
#   16,
#   128,
#   21,
#   502,
#   357,
#   99,
#   1,
#   422,
#   49,
#   639,
#   776,
#   3042,
#   101,
#   2227],
#  [1,
#   139,
#   95,
#   39,
#   3041,
#   261,
#   5,
#   778,
#   158,
#   71,
#   2149,
#   734,
#   285,
#   1149,
#   3041,
#   2001,
#   1651,
#   412,
#   100,
#   2892,
#   383,
#   3798,
#   734,
#   1006,
#   284,
#   1651,
#   8456,
#   4,
#   391],
#  [11,
#   2,
#   639,
#   357,
#   770,
#   1681,
#   179,
#   905,
#   639,
#   357,
#   4,
#   12,
#   88,
#   10,
#   92,
#   815,
#   3043,
#   122,
#   7,
#   507,
#   230,
#   328,
#   242,
#   19,
#   3,
#   7],
#  [58,
#   250,
#   55,
#   200,
#   13,
#   46,
#   124,
#   502,
#   290,
#   505,
#   1079,
#   1150,
#   73,
#   58,
#   630,
#   250,
#   55,
#   57,
#   8457,
#   58,
#   809,
#   143,
#   1549,
#   630,
#   1439,
#   488,
#   17,
#   9,
#   809,
#   91,
#   488,
#   250,
#   55,
#   12,
#   418,
#   26,
#   546,
#   8,
#   579,
#   58,
#   752,
#   639,
#   102,
#   188,
#   4,
#   3,
#   27,
#   257,
#   24,
#   408],
#  [657,
#   2400,
#   3799,
#   89,
#   7,
#   453,
#   313,
#   147,
#   19,
#   639,
#   357,
#   2,
#   1232,
#   64,
#   41,
#   2004,
#   639,
#   143,
#   21,
#   256,
#   157,
#   3,
#   7],
#  [2, 175, 4, 171, 2226, 257, 152, 15, 13, 41, 15, 41],
#  [71,
#   3254,
#   228,
#   105,
#   5319,
#   6369,
#   352,
#   1190,
#   418,
#   129,
#   556,
#   364,
#   357,
#   303,
#   137,
#   129,
#   364,
#   357,
#   105,
#   8,
#   616,
#   8458,
#   228],
#  [120, 310, 63, 4, 184, 708, 369, 117],
#  [410,
#   6,
#   59,
#   1232,
#   639,
#   1439,
#   250,
#   55,
#   399,
#   199,
#   8459,
#   502,
#   146,
#   502,
#   639,
#   357],
#  [27,
#   778,
#   11,
#   58,
#   8460,
#   639,
#   357,
#   276,
#   175,
#   1,
#   277,
#   101,
#   148,
#   8461,
#   101,
#   1027,
#   188,
#   2,
#   635,
#   865,
#   3044,
#   708,
#   45,
#   12,
#   10,
#   92,
#   636,
#   17,
#   708,
#   24,
#   2,
#   502,
#   12,
#   124,
#   2608,
#   421,
#   819,
#   776,
#   166,
#   246,
#   2,
#   221,
#   631,
#   49,
#   171,
#   631,
#   58,
#   200,
#   674,
#   250,
#   38,
#   250,
#   55,
#   158,
#   576,
#   814,
#   50,
#   71,
#   228,
#   228,
#   502,
#   357,
#   50,
#   430,
#   39,
#   665,
#   2739,
#   100,
#   463,
#   44,
#   306,
#   353,
#   76,
#   140,
#   158,
#   6,
#   265,
#   45,
#   6,
#   21,
#   24,
#   2,
#   99,
#   1,
#   618,
#   19,
#   872,
#   792,
#   221,
#   778,
#   1793,
#   357,
#   277,
#   639,
#   8462,
#   148,
#   2401,
#   297,
#   2402,
#   316,
#   349,
#   242,
#   2001,
#   101,
#   8,
#   27,
#   1280,
#   8,
#   171,
#   357,
#   77,
#   320,
#   1590,
#   24,
#   2,
#   635],
#  [131,
#   16,
#   88,
#   204,
#   6,
#   7,
#   630,
#   36,
#   1006,
#   2,
#   774,
#   639,
#   357,
#   28,
#   579,
#   531,
#   973,
#   119,
#   32,
#   3,
#   131,
#   16],
#  [8,
#   80,
#   506,
#   708,
#   402,
#   282,
#   4668,
#   9,
#   8,
#   126,
#   8463,
#   1,
#   48,
#   251,
#   4,
#   119,
#   7,
#   263,
#   64,
#   123,
#   41,
#   28,
#   256],
#  [228,
#   19,
#   459,
#   309,
#   3495,
#   531,
#   9,
#   262,
#   639,
#   357,
#   696,
#   1114,
#   475,
#   2078,
#   228,
#   583,
#   279],
#  [71, 1, 46, 14, 571, 1, 225, 8464, 2079, 48],
#  [451,
#   27,
#   886,
#   2228,
#   778,
#   8465,
#   8466,
#   186,
#   63,
#   175,
#   47,
#   535,
#   2,
#   357,
#   3,
#   7,
#   3,
#   7],
#  [3040,
#   733,
#   502,
#   630,
#   639,
#   531,
#   9,
#   357,
#   579,
#   2889,
#   179,
#   3040,
#   8467,
#   630,
#   639,
#   531,
#   9,
#   357,
#   579,
#   2889,
#   179,
#   28,
#   20,
#   915,
#   353,
#   639,
#   357,
#   2080,
#   436,
#   25,
#   59,
#   292,
#   357,
#   124,
#   3,
#   202,
#   649,
#   502,
#   630,
#   2,
#   250,
#   601,
#   8468],
#  [11,
#   329,
#   28,
#   1007,
#   110,
#   303,
#   47,
#   502,
#   58,
#   639,
#   357,
#   2,
#   809,
#   8469,
#   128,
#   755,
#   294,
#   418,
#   579,
#   1,
#   1028,
#   4,
#   12,
#   48,
#   817,
#   1451,
#   356,
#   8470,
#   357,
#   630],
#  [2,
#   20,
#   2607,
#   101,
#   357,
#   40,
#   357,
#   1,
#   8,
#   945,
#   105,
#   24,
#   2,
#   250,
#   55,
#   36,
#   2607,
#   101,
#   357],
#  [2, 20, 58, 101, 357, 1892, 2607, 101, 8471, 36, 36, 2607, 357],
#  [23, 21, 651, 19, 4, 12, 865, 3044, 708, 31, 9, 1, 2005, 32, 23, 21],
#  [48,
#   777,
#   502,
#   850,
#   687,
#   17,
#   290,
#   684,
#   2229,
#   809,
#   4,
#   12,
#   36,
#   1899,
#   17,
#   357,
#   410,
#   24,
#   250,
#   776,
#   162,
#   766,
#   17,
#   502,
#   290,
#   809],
#  [502,
#   8472,
#   36,
#   131,
#   37,
#   579,
#   355,
#   2,
#   502,
#   250,
#   55,
#   121,
#   2609,
#   55,
#   579,
#   91,
#   261,
#   10,
#   13,
#   3496,
#   1386,
#   639,
#   357,
#   770,
#   1681,
#   504,
#   770],
#  [218, 639, 357, 8, 393, 4, 93, 708, 811, 4, 93],
#  [3,
#   19,
#   4,
#   391,
#   326,
#   81,
#   1,
#   10,
#   1236,
#   2495,
#   101,
#   357,
#   502,
#   531,
#   9,
#   55,
#   246,
#   3,
#   19,
#   4,
#   391],
#  [1,
#   928,
#   366,
#   104,
#   125,
#   94,
#   51,
#   250,
#   55,
#   502,
#   181,
#   2308,
#   325,
#   51,
#   250,
#   55,
#   12,
#   1016,
#   149,
#   488,
#   250,
#   55,
#   22,
#   79,
#   24,
#   46,
#   35,
#   97,
#   183,
#   297,
#   1356,
#   499,
#   167,
#   28,
#   60,
#   167,
#   200,
#   5,
#   796,
#   502,
#   795,
#   180,
#   558,
#   71,
#   357,
#   9,
#   45,
#   3255,
#   143,
#   887,
#   101,
#   12,
#   60,
#   200,
#   101,
#   795,
#   357,
#   30,
#   42,
#   24,
#   89,
#   607,
#   198,
#   87,
#   27,
#   834,
#   1442,
#   10,
#   179,
#   67,
#   457,
#   16,
#   92,
#   811,
#   101,
#   297,
#   591,
#   811,
#   101,
#   1415,
#   94,
#   51],
#  [6, 7, 19, 7, 3, 94, 19, 415, 10, 9, 413, 10, 6, 7, 19],
#  [413, 22, 59, 55, 486, 240, 200, 134, 275, 795, 58, 185, 806],
#  [2893,
#   4179,
#   6370,
#   6371,
#   35,
#   61,
#   106,
#   1452,
#   101,
#   1170,
#   70,
#   34,
#   446,
#   364,
#   250,
#   51,
#   49,
#   2081,
#   630,
#   364,
#   96,
#   450,
#   888,
#   2309,
#   162,
#   1591,
#   1452,
#   50,
#   17,
#   1682,
#   1,
#   639,
#   1503,
#   41,
#   364,
#   1798,
#   275,
#   639,
#   357],
#  [352,
#   3497,
#   3498,
#   30,
#   443,
#   82,
#   443,
#   357,
#   110,
#   630,
#   502,
#   250,
#   55,
#   486,
#   2006,
#   630,
#   6,
#   283,
#   221,
#   989,
#   208,
#   167,
#   3498,
#   352],
#  [10,
#   27,
#   456,
#   639,
#   357,
#   58,
#   101,
#   651,
#   670,
#   8,
#   64,
#   144,
#   8,
#   28,
#   91,
#   8473,
#   1,
#   171,
#   708,
#   225,
#   81,
#   28,
#   8474,
#   1652,
#   435,
#   58,
#   570,
#   218,
#   290,
#   1,
#   290,
#   312,
#   1062,
#   2610,
#   27,
#   130,
#   1237,
#   8,
#   212,
#   495,
#   5,
#   1,
#   79,
#   1091,
#   701,
#   70,
#   657,
#   1,
#   708,
#   225,
#   81],
#  [502,
#   630,
#   3,
#   71,
#   76,
#   3256,
#   101,
#   187,
#   821,
#   1,
#   1506,
#   434,
#   630,
#   101,
#   12,
#   15,
#   630,
#   133,
#   32,
#   2611,
#   2,
#   1696,
#   1092,
#   3800,
#   188,
#   320,
#   101,
#   113,
#   6],
#  [4, 3, 250, 55, 58, 55, 502, 61, 52, 8, 639, 357, 2496, 29, 2894, 38],
#  [30, 106, 708, 292, 639, 357, 6, 3499, 502, 133, 19, 6, 267, 19],
#  [3,
#   7,
#   11,
#   2,
#   639,
#   357,
#   770,
#   1681,
#   179,
#   905,
#   639,
#   357,
#   4,
#   12,
#   88,
#   10,
#   92,
#   815,
#   3043,
#   122,
#   7,
#   507,
#   230,
#   328,
#   242,
#   19,
#   639,
#   357],
#  [475,
#   5320,
#   15,
#   13,
#   29,
#   80,
#   1170,
#   8,
#   250,
#   55,
#   302,
#   4665,
#   357,
#   755,
#   708,
#   3,
#   80,
#   1899],
#  [2080,
#   763,
#   6372,
#   49,
#   10,
#   333,
#   357,
#   9,
#   202,
#   778,
#   10,
#   39,
#   184,
#   13,
#   242,
#   221,
#   778,
#   171,
#   102,
#   1254,
#   4665,
#   1169,
#   1590,
#   3,
#   471,
#   310,
#   778,
#   1077,
#   24,
#   2,
#   8475,
#   3041,
#   778],
#  [8,
#   175,
#   82,
#   32,
#   24,
#   2,
#   2,
#   46,
#   124,
#   708,
#   2,
#   727,
#   906,
#   809,
#   103,
#   357,
#   134,
#   750,
#   428,
#   809,
#   4,
#   3,
#   250,
#   55,
#   51,
#   6,
#   267],
#  [8476, 71, 639, 357, 4, 23, 2007, 32, 290, 45, 31, 3, 19, 4],
#  [3, 13, 639, 357, 1900, 38, 2, 4, 160, 52, 1697, 475, 3801, 4, 3],
#  [357,
#   987,
#   283,
#   78,
#   10,
#   297,
#   35,
#   361,
#   13,
#   639,
#   357,
#   390,
#   61,
#   328,
#   708,
#   22,
#   251,
#   122,
#   1303,
#   13,
#   364,
#   357,
#   101,
#   357,
#   80,
#   357,
#   188,
#   283,
#   46,
#   29,
#   5,
#   2738,
#   1452,
#   127,
#   101,
#   31,
#   1074,
#   8477,
#   708,
#   46,
#   20,
#   1698,
#   58,
#   287,
#   185,
#   24,
#   832,
#   52,
#   357,
#   218,
#   290,
#   28,
#   3,
#   670,
#   357,
#   283,
#   39,
#   12,
#   1,
#   832,
#   771,
#   105,
#   2,
#   74,
#   41,
#   349,
#   28,
#   579,
#   854,
#   854,
#   258,
#   670,
#   357,
#   285,
#   72,
#   171,
#   708,
#   508,
#   218,
#   290,
#   6373,
#   1171,
#   418,
#   20,
#   91,
#   13,
#   8478,
#   5321,
#   101,
#   29,
#   5,
#   8479,
#   15,
#   15,
#   15,
#   15,
#   1340,
#   244],
#  [777,
#   474,
#   408,
#   639,
#   357,
#   182,
#   58,
#   389,
#   357,
#   502,
#   28,
#   71,
#   579,
#   58,
#   639,
#   3,
#   183,
#   58,
#   601,
#   37,
#   357,
#   408,
#   182,
#   193,
#   58,
#   71,
#   259,
#   502,
#   410,
#   24,
#   199,
#   45,
#   7,
#   474,
#   1,
#   272,
#   474,
#   1,
#   8480,
#   290,
#   1,
#   32,
#   7,
#   45],
#  [30,
#   1791,
#   167,
#   433,
#   7,
#   32,
#   2,
#   354,
#   160,
#   1507,
#   48,
#   8,
#   63,
#   209,
#   15,
#   131,
#   16,
#   19,
#   3,
#   15],
#  [180,
#   558,
#   263,
#   51,
#   2,
#   8481,
#   1681,
#   80,
#   357,
#   639,
#   531,
#   9,
#   74,
#   2,
#   408,
#   48,
#   21,
#   887,
#   349,
#   1682,
#   357],
#  [285,
#   635,
#   3492,
#   290,
#   2077,
#   77,
#   228,
#   357,
#   430,
#   47,
#   121,
#   8482,
#   306,
#   385,
#   10,
#   228,
#   496,
#   114,
#   639,
#   357,
#   262,
#   177,
#   13,
#   502,
#   290,
#   146,
#   12,
#   1799,
#   2895,
#   58,
#   104,
#   5,
#   129,
#   38,
#   194,
#   91,
#   261,
#   489,
#   159,
#   115,
#   718,
#   13,
#   156,
#   558,
#   430,
#   47,
#   64,
#   551,
#   38,
#   47,
#   64,
#   306],
#  [1,
#   82,
#   48,
#   9,
#   183,
#   423,
#   55,
#   134,
#   14,
#   94,
#   186,
#   364,
#   288,
#   2,
#   502,
#   290,
#   30,
#   13,
#   4,
#   1,
#   28,
#   499,
#   355,
#   320,
#   354,
#   101,
#   8483,
#   1063],
#  [1114,
#   328,
#   475,
#   13,
#   639,
#   357,
#   513,
#   44,
#   25,
#   639,
#   270,
#   2612,
#   2,
#   70,
#   250,
#   55,
#   200,
#   630,
#   58,
#   250,
#   631,
#   964,
#   150,
#   278,
#   357,
#   4,
#   3,
#   201],
#  [2,
#   809,
#   418,
#   727,
#   755,
#   68,
#   60,
#   399,
#   2057,
#   6374,
#   809,
#   27,
#   406,
#   1,
#   809,
#   418,
#   58,
#   809,
#   143,
#   163,
#   2,
#   134,
#   1341,
#   55,
#   809,
#   186,
#   2,
#   639,
#   27,
#   1845,
#   357,
#   2401,
#   44,
#   1,
#   618,
#   19,
#   1746,
#   230,
#   3802,
#   374,
#   1,
#   8,
#   369,
#   117,
#   167,
#   1,
#   230,
#   308,
#   1,
#   357,
#   69,
#   1,
#   516,
#   247,
#   122,
#   17,
#   357,
#   32,
#   318,
#   69,
#   5322,
#   8484,
#   17],
#  [230,
#   120,
#   343,
#   23,
#   475,
#   357,
#   235,
#   752,
#   357,
#   122,
#   35,
#   97,
#   235,
#   161,
#   353,
#   2309,
#   127,
#   9,
#   45,
#   1131,
#   23,
#   7],
#  [15,
#   24,
#   13,
#   357,
#   2,
#   325,
#   809,
#   644,
#   13,
#   724,
#   357,
#   639,
#   1742,
#   38,
#   644,
#   4180,
#   13,
#   106,
#   5,
#   271,
#   106,
#   631,
#   3,
#   88,
#   2740,
#   357],
#  [32,
#   44,
#   502,
#   6375,
#   639,
#   357,
#   4,
#   12,
#   17,
#   1417,
#   126,
#   70,
#   357,
#   13,
#   139,
#   9,
#   502,
#   736,
#   3500,
#   139,
#   28,
#   256,
#   605,
#   24,
#   2],
#  [1,
#   2,
#   284,
#   554,
#   3803,
#   1114,
#   475,
#   454,
#   2,
#   639,
#   357,
#   2602,
#   1114,
#   6376,
#   50,
#   12,
#   39,
#   87,
#   283],
#  [1133,
#   205,
#   71,
#   228,
#   16,
#   11,
#   1342,
#   1699,
#   579,
#   6,
#   99,
#   1,
#   33,
#   357,
#   502,
#   630,
#   2082,
#   931],
#  [36, 37, 13, 36, 342, 655, 24, 2, 175, 17, 226, 364, 357],
#  [592,
#   579,
#   357,
#   91,
#   639,
#   171,
#   551,
#   135,
#   573,
#   114,
#   27,
#   2889,
#   71,
#   8485,
#   228,
#   4181,
#   844,
#   1,
#   13,
#   324],
#  [12,
#   372,
#   286,
#   540,
#   976,
#   41,
#   235,
#   25,
#   148,
#   5323,
#   2497,
#   372,
#   1846,
#   976,
#   200,
#   1508,
#   283,
#   540,
#   2,
#   280,
#   2890,
#   8486,
#   440,
#   1477,
#   4669,
#   8487,
#   372,
#   2310,
#   98,
#   3,
#   29,
#   6377],
#  [32,
#   69,
#   235,
#   131,
#   17,
#   138,
#   1800,
#   2150,
#   69,
#   12,
#   13,
#   283,
#   646,
#   16,
#   69,
#   598,
#   5,
#   1115,
#   13,
#   5,
#   98,
#   965,
#   3,
#   1800,
#   2150],
#  [11,
#   1029,
#   2230,
#   40,
#   1800,
#   8488,
#   8489,
#   274,
#   1134,
#   721,
#   476,
#   588,
#   1749,
#   69,
#   111,
#   373,
#   480,
#   1995,
#   466,
# ...
#   633,
#   748,
#   5452,
#   330,
#   20,
#   12,
#   5,
#   1265,
#   2387,
#   4783,
#   793,
#   600,
#   1,
#   5,
#   60,
#   4783,
#   1438,
#   1472,
#   4,
#   736,
#   118,
#   1112,
#   812],
#  [3, 7, 2, 171, 130, 2, 230, 270, 13, 146, 24, 171, 524],
#  [9018,
#   35,
#   78,
#   20,
#   1169,
#   595,
#   2162,
#   324,
#   33,
#   176,
#   143,
#   403,
#   1169,
#   742,
#   271,
#   364,
#   631,
#   2162,
#   210,
#   303,
#   2443,
#   206,
#   158,
#   2162,
#   221,
#   1522,
#   601,
#   130,
#   1,
#   83,
#   74,
#   2162,
#   1,
#   272,
#   473,
#   331,
#   229,
#   2162,
#   110,
#   2162,
#   601,
#   33,
#   176,
#   143],
#  [2,
#   2656,
#   2243,
#   18,
#   6589,
#   276,
#   35,
#   25,
#   3514,
#   345,
#   1218,
#   18,
#   66,
#   9019,
#   1631,
#   3,
#   53,
#   1118,
#   5453,
#   11,
#   277,
#   1629,
#   650,
#   199,
#   45,
#   38,
#   331,
#   11,
#   345,
#   46,
#   53,
#   86,
#   9020,
#   734,
#   411,
#   728,
#   118,
#   577,
#   2243,
#   18,
#   6589],
#  [7, 54, 184, 4, 3, 1520, 50, 9021, 87, 218, 66, 234, 898, 244, 4, 3],
#  [161, 10, 18, 473, 30, 66, 1, 9022, 9023],
#  [26,
#   11,
#   1262,
#   217,
#   61,
#   2,
#   3302,
#   3579,
#   171,
#   2777,
#   2,
#   86,
#   5,
#   733,
#   950,
#   3580,
#   176,
#   73,
#   68,
#   40,
#   1262,
#   3302,
#   593,
#   1262],
#  [54,
#   9024,
#   54,
#   365,
#   780,
#   6590,
#   184,
#   23,
#   16,
#   34,
#   29,
#   450,
#   85,
#   309,
#   48,
#   13,
#   3,
#   80,
#   3,
#   2938],
#  [596,
#   593,
#   253,
#   1,
#   10,
#   653,
#   37,
#   23,
#   1262,
#   593,
#   1290,
#   30,
#   444,
#   444,
#   458,
#   1262,
#   2225,
#   8,
#   249,
#   249,
#   596,
#   1262,
#   85,
#   92,
#   568,
#   9025,
#   27,
#   210,
#   319,
#   1001,
#   974,
#   9026],
#  [204, 2, 53, 125, 11, 116, 16, 1504, 34, 23, 345, 116, 593, 15, 593, 253],
#  [3302, 513, 9027, 1262, 184, 48, 26, 1475, 220, 88, 44, 10, 1305, 1475],
#  [312, 16, 34, 3540, 129, 1, 2, 593, 303, 58, 97, 1173, 1154, 9028],
#  [230,
#   328,
#   80,
#   127,
#   2259,
#   429,
#   1,
#   772,
#   2174,
#   360,
#   162,
#   499,
#   58,
#   1138,
#   105,
#   26,
#   116,
#   187,
#   604,
#   9029,
#   44,
#   1,
#   8,
#   1355,
#   499,
#   967,
#   22,
#   138,
#   29,
#   601,
#   9030,
#   402,
#   44,
#   16,
#   1355,
#   1,
#   4,
#   9031,
#   198,
#   559,
#   1215,
#   4730,
#   1201,
#   472,
#   472,
#   141,
#   361,
#   26,
#   17,
#   969,
#   127,
#   649,
#   1,
#   4,
#   1014,
#   137,
#   69],
#  [32,
#   9032,
#   3890,
#   365,
#   443,
#   35,
#   361,
#   2,
#   3581,
#   1818,
#   6591,
#   891,
#   122,
#   993,
#   12,
#   644,
#   1573,
#   72,
#   1096,
#   152,
#   349,
#   1131,
#   188,
#   2350,
#   304,
#   3024,
#   1,
#   2,
#   13,
#   139,
#   47,
#   891,
#   60,
#   35,
#   361,
#   293,
#   423,
#   52,
#   5454,
#   6411,
#   102,
#   308,
#   365,
#   77,
#   4,
#   104,
#   1688,
#   152,
#   1738,
#   284,
#   102,
#   231,
#   385,
#   2533,
#   77,
#   787,
#   718,
#   448,
#   594,
#   77,
#   993,
#   140,
#   60,
#   214,
#   361,
#   304,
#   559,
#   2267,
#   495,
#   278,
#   63,
#   9033,
#   284,
#   3830,
#   304,
#   77,
#   4,
#   379,
#   2351,
#   1086,
#   46,
#   304,
#   436,
#   2267,
#   365,
#   545,
#   768,
#   9,
#   45,
#   115,
#   3582,
#   9,
#   628,
#   3890,
#   180,
#   60,
#   40,
#   1138,
#   192,
#   287,
#   185,
#   2329,
#   691,
#   306,
#   9034,
#   103,
#   157,
#   1626,
#   146],
#  [7, 4, 12, 230, 2001, 830, 663, 202, 27, 89, 9035, 20, 27, 89],
#  [225,
#   81,
#   7,
#   1,
#   193,
#   173,
#   14,
#   12,
#   10,
#   2,
#   1497,
#   1402,
#   791,
#   2011,
#   1,
#   4,
#   9,
#   221,
#   44,
#   1,
#   25,
#   1244,
#   151,
#   326,
#   81,
#   56,
#   8,
#   155,
#   5455,
#   242,
#   591,
#   10,
#   128,
#   21,
#   290,
#   326,
#   81],
#  [1,
#   10,
#   332,
#   92,
#   10,
#   1477,
#   833,
#   98,
#   214,
#   37,
#   60,
#   69,
#   3891,
#   6,
#   6592,
#   62,
#   1,
#   46,
#   67,
#   5,
#   1190,
#   9,
#   341,
#   162,
#   125,
#   9,
#   1,
#   5456,
#   652,
#   9036,
#   474,
#   124,
#   360,
#   67,
#   1090,
#   88,
#   67,
#   844,
#   327,
#   208,
#   170,
#   20,
#   87,
#   2394,
#   507,
#   327,
#   6592,
#   149,
#   23,
#   88,
#   88,
#   88],
#  [32,
#   3891,
#   62,
#   13,
#   75,
#   2444,
#   127,
#   4,
#   74,
#   206,
#   27,
#   1117,
#   1306,
#   7,
#   48,
#   2,
#   3891,
#   62,
#   13,
#   2653,
#   9,
#   24,
#   1655,
#   89,
#   88,
#   95,
#   218,
#   2,
#   153,
#   62,
#   67,
#   714,
#   182,
#   14,
#   2,
#   45,
#   170,
#   20,
#   79,
#   714,
#   290,
#   173,
#   1,
#   327,
#   2238,
#   13,
#   546,
#   676,
#   67,
#   306,
#   523,
#   170,
#   47,
#   965,
#   99,
#   1,
#   58,
#   3891,
#   144,
#   653,
#   173,
#   327,
#   2238,
#   95,
#   1249,
#   686,
#   13,
#   5,
#   2653,
#   181,
#   17,
#   220,
#   1,
#   225,
#   81,
#   290,
#   1,
#   133,
#   81],
#  [6593, 12, 13, 4629, 128, 1299, 61, 117, 2023, 9037, 9038, 393, 1438],
#  [9039,
#   115,
#   3514,
#   12,
#   13,
#   6,
#   16,
#   889,
#   42,
#   2064,
#   411,
#   1328,
#   5,
#   103,
#   326,
#   33,
#   2233,
#   350,
#   475,
#   31,
#   863,
#   247,
#   463,
#   9040,
#   1663,
#   84,
#   15,
#   132,
#   475],
#  [208,
#   9041,
#   1673,
#   333,
#   194,
#   18,
#   67,
#   195,
#   154,
#   28,
#   52,
#   1,
#   623,
#   18,
#   428,
#   2352,
#   547,
#   333,
#   23,
#   349,
#   6],
#  [723,
#   56,
#   881,
#   507,
#   335,
#   54,
#   173,
#   360,
#   102,
#   109,
#   723,
#   54,
#   173,
#   358,
#   1310,
#   441,
#   827,
#   231,
#   94,
#   347,
#   51],
#  [56,
#   208,
#   249,
#   1630,
#   71,
#   111,
#   423,
#   134,
#   240,
#   320,
#   143,
#   1858,
#   29,
#   228,
#   173,
#   1467,
#   17,
#   113,
#   879,
#   295,
#   884,
#   17,
#   104,
#   5,
#   9,
#   10,
#   5,
#   6,
#   881],
#  [255,
#   202,
#   71,
#   881,
#   4,
#   142,
#   412,
#   249,
#   173,
#   562,
#   1,
#   10,
#   173,
#   50,
#   11,
#   231,
#   94,
#   173,
#   255,
#   202,
#   881,
#   4,
#   82],
#  [186,
#   2,
#   2,
#   137,
#   808,
#   38,
#   17,
#   206,
#   13,
#   808,
#   143,
#   104,
#   474,
#   142,
#   1085,
#   204,
#   249,
#   220,
#   162,
#   125,
#   32,
#   1,
#   249,
#   137,
#   474,
#   142,
#   231,
#   94,
#   1902,
#   59,
#   808],
#  [32,
#   881,
#   10,
#   406,
#   585,
#   404,
#   2635,
#   197,
#   224,
#   881,
#   36,
#   149,
#   4661,
#   16,
#   197,
#   224,
#   28,
#   379,
#   1599,
#   1433,
#   69,
#   19,
#   881,
#   2531,
#   197,
#   1433,
#   151,
#   881,
#   36,
#   2],
#  [249,
#   173,
#   7,
#   423,
#   94,
#   173,
#   22,
#   1858,
#   39,
#   758,
#   31,
#   99,
#   1,
#   2,
#   99,
#   1,
#   137,
#   173,
#   59,
#   59,
#   143,
#   1,
#   28,
#   423,
#   17,
#   205,
#   52,
#   827],
#  [15,
#   65,
#   315,
#   246,
#   284,
#   256,
#   661,
#   53,
#   164,
#   2,
#   3516,
#   18,
#   298,
#   761,
#   514,
#   1926,
#   138,
#   615,
#   520,
#   677,
#   3892,
#   1361,
#   11,
#   31,
#   298,
#   317,
#   980,
#   130,
#   138,
#   615,
#   1361,
#   1170,
#   330,
#   1697,
#   2,
#   183,
#   25,
#   9042,
#   92,
#   30,
#   803,
#   27,
#   822,
#   30,
#   106,
#   5,
#   109,
#   35,
#   133,
#   776,
#   250,
#   2],
#  [3583,
#   3,
#   2551,
#   9043,
#   280,
#   1338,
#   17,
#   232,
#   156,
#   69,
#   31,
#   24,
#   2,
#   373,
#   489,
#   14,
#   3,
#   557,
#   109,
#   20,
#   23,
#   280],
#  [95,
#   20,
#   122,
#   10,
#   2,
#   1,
#   9044,
#   4194,
#   745,
#   4194,
#   307,
#   262,
#   1836,
#   9045,
#   2102,
#   6332],
#  [422,
#   1761,
#   402,
#   525,
#   41,
#   853,
#   9046,
#   525,
#   297,
#   123,
#   20,
#   1035,
#   4784,
#   1556,
#   1658,
#   853,
#   28,
#   442,
#   50,
#   186,
#   48,
#   122,
#   22,
#   5,
#   1948,
#   27,
#   539,
#   422,
#   104,
#   2657,
#   525,
#   10,
#   123,
#   2658,
#   398,
#   1560],
#  [10, 292, 104, 2658, 1215, 5, 1, 98, 63, 1, 183, 8, 4, 225, 81, 1297],
#  [1,
#   16,
#   143,
#   147,
#   2658,
#   130,
#   2,
#   40,
#   1218,
#   5,
#   171,
#   2,
#   5457,
#   1244,
#   598,
#   650,
#   1522,
#   236,
#   183,
#   5457,
#   830,
#   1602,
#   318,
#   14,
#   119,
#   72,
#   293,
#   539,
#   3866,
#   48,
#   907,
#   4784,
#   126,
#   17,
#   323,
#   1385,
#   46,
#   214,
#   594,
#   22,
#   424,
#   5457,
#   2789,
#   2,
#   9047,
#   2658,
#   1,
#   218,
#   848,
#   907,
#   8,
#   3893,
#   382,
#   6594,
#   1,
#   3040,
#   255,
#   21,
#   98,
#   1602,
#   318],
#  [3, 19, 3092, 179, 6, 22, 9048, 19, 38],
#  [2256, 30, 442, 28, 11, 9049, 260, 82, 313],
#  [11,
#   740,
#   34,
#   21,
#   1,
#   6,
#   2790,
#   507,
#   3096,
#   23,
#   14,
#   583,
#   279,
#   168,
#   34,
#   1339,
#   124,
#   4785,
#   1,
#   6,
#   2790],
#  [84,
#   307,
#   3,
#   42,
#   14,
#   149,
#   185,
#   428,
#   350,
#   17,
#   47,
#   317,
#   1489,
#   430,
#   5458,
#   13,
#   317,
#   84,
#   11,
#   2353,
#   129,
#   1758,
#   658,
#   406,
#   84,
#   105,
#   39,
#   300,
#   249,
#   1004,
#   245,
#   658,
#   650,
#   300,
#   1758,
#   658,
#   5,
#   129,
#   1,
#   1303,
#   317,
#   84,
#   3,
#   42,
#   14,
#   231,
#   14,
#   1,
#   231],
#  [926,
#   438,
#   8,
#   106,
#   5,
#   109,
#   60,
#   35,
#   211,
#   2,
#   6595,
#   554,
#   78,
#   28,
#   11,
#   375,
#   175,
#   769,
#   4,
#   293,
#   123,
#   433,
#   15,
#   78,
#   438,
#   26,
#   37,
#   1,
#   866,
#   718,
#   420,
#   4,
#   876,
#   383,
#   488,
#   1070,
#   1745,
#   95,
#   1392,
#   1070,
#   132,
#   2327,
#   4,
#   12,
#   13,
#   293,
#   3,
#   51,
#   475,
#   3041,
#   293,
#   8,
#   2,
#   6596,
#   182,
#   1,
#   8,
#   6597,
#   474,
#   296,
#   478,
#   9050,
#   52,
#   179,
#   33,
#   12,
#   325,
#   438,
#   5459,
#   31,
#   976,
#   6596,
#   919,
#   84,
#   312,
#   304,
#   240,
#   379,
#   360,
#   932,
#   437,
#   934,
#   1329,
#   46,
#   450,
#   585,
#   68,
#   8,
#   360,
#   443,
#   437,
#   78,
#   438,
#   926,
#   304,
#   1,
#   1488,
#   218,
#   2659,
#   95,
#   2,
#   293,
#   440,
#   9051,
#   2220,
#   5418,
#   218,
#   9052,
#   440,
#   1916,
#   22,
#   764,
#   585,
#   644,
#   450,
#   440,
#   2766,
#   17,
#   186,
#   2660,
#   1147,
#   51,
#   585,
#   40,
#   2445,
#   130,
#   4,
#   10,
#   23,
#   1708,
#   367,
#   5460,
#   1869,
#   2023,
#   9053,
#   1070,
#   780,
#   593,
#   5461,
#   4,
#   3,
#   430,
#   1070,
#   780,
#   5461,
#   1032,
#   550,
#   3,
#   438,
#   5461,
#   790,
#   4,
#   93,
#   2032,
#   2177,
#   9054,
#   790,
#   790,
#   1513,
#   1391,
#   604,
#   43,
#   291,
#   148,
#   5,
#   790,
#   4,
#   440,
#   2402,
#   767,
#   31,
#   495,
#   964,
#   150,
#   202,
#   81,
#   250,
#   793,
#   475,
#   64,
#   2,
#   182,
#   767,
#   113,
#   2268,
#   103,
#   436,
#   25,
#   293,
#   138,
#   303,
#   2022,
#   3,
#   438,
#   158],
#  [16,
#   111,
#   9055,
#   16,
#   11,
#   453,
#   95,
#   43,
#   76,
#   108,
#   1,
#   54,
#   4,
#   6,
#   2417,
#   1869,
#   76,
#   426,
#   9056,
#   2939,
#   76],
#  [1, 889, 85, 210, 64, 76, 1866, 5, 76, 9057, 541],
#  [1733,
#   9,
#   56,
#   877,
#   1146,
#   230,
#   38,
#   195,
#   106,
#   29,
#   86,
#   82,
#   279,
#   760,
#   28,
#   6598,
#   4,
#   93,
#   149,
#   247,
#   298,
#   76,
#   89,
#   76,
#   541],
#  [33, 96, 9058, 82, 146, 42, 136, 203, 178, 1127, 24, 1222, 4293, 146],
#  [8,
#   182,
#   2174,
#   2105,
#   2,
#   20,
#   34,
#   144,
#   879,
#   7,
#   2169,
#   521,
#   58,
#   76,
#   91,
#   511,
#   521,
#   52,
#   76,
#   11,
#   1511,
#   11,
#   1,
#   50,
#   76,
#   263,
#   7,
#   4],
#  [15,
#   29,
#   76,
#   1806,
#   60,
#   171,
#   130,
#   136,
#   15,
#   171,
#   130,
#   60,
#   1246,
#   60,
#   593,
#   60,
#   780,
#   546,
#   76,
#   9,
#   8,
#   59,
#   4,
#   701,
#   1136,
#   10,
#   5,
#   68,
#   208,
#   44,
#   1,
#   119,
#   136,
#   578,
#   203,
#   76,
#   1707,
#   136,
#   203],
#  [2, 297, 476, 1372, 458, 451, 176, 67, 747, 546, 3, 86, 43, 4786, 82, 1528],
#  [249,
#   1160,
#   249,
#   285,
#   71,
#   121,
#   47,
#   444,
#   325,
#   1056,
#   76,
#   194,
#   5,
#   126,
#   612,
#   8,
#   76,
#   406,
#   3097,
#   441,
#   76,
#   604,
#   9059,
#   3335,
#   9,
#   263,
#   4294,
#   2106,
#   76,
#   1074,
#   96,
#   40,
#   2354,
#   2,
#   3584,
#   31,
#   28,
#   249,
#   1160,
#   600,
#   579,
#   1980,
#   702,
#   42,
#   41,
#   103,
#   263,
#   1330,
#   76,
#   2791,
#   125],
#  [37,
#   1339,
#   150,
#   152,
#   161,
#   4787,
#   3894,
#   4788,
#   11,
#   3585,
#   531,
#   9,
#   150,
#   100,
#   1764,
#   27,
#   1358,
#   108,
#   46,
#   1201,
#   1358,
#   6599,
#   27,
#   5,
#   866,
#   38,
#   1,
#   6],
#  [794,
#   9060,
#   5462,
#   1080,
#   1331,
#   624,
#   935,
#   175,
#   232,
#   2107,
#   624,
#   2792,
#   202,
#   5462,
#   319,
#   319,
#   70,
#   2178,
#   63,
#   563,
#   107,
#   371,
#   2653,
#   1000,
#   3224,
#   3586,
#   3251,
#   55,
#   416,
#   250,
#   55,
#   9061,
#   3336,
#   2144,
#   9062,
#   660,
#   57,
#   1259,
#   762,
#   660,
#   4723,
#   317,
#   46,
#   5,
#   1206,
#   2653,
#   70,
#   4190,
#   130,
#   875,
#   22,
#   424,
#   777,
#   4789,
#   340,
#   9063,
#   1331,
#   4,
#   1653,
#   1064,
#   457,
#   28,
#   693,
#   457,
#   46,
#   8,
#   4790,
#   457,
#   377,
#   1541,
#   348,
#   6600,
#   822,
#   1206,
#   5462,
#   11,
#   6601],
#  [217, 2, 1997, 3, 3895, 2150, 2230, 326, 359, 81, 1, 1266, 1792, 220, 9, 274],
#  [217,
#   110,
#   81,
#   504,
#   655,
#   405,
#   94,
#   229,
#   358,
#   5463,
#   250,
#   493,
#   26,
#   138,
#   8,
#   203,
#   15,
#   732,
#   177,
#   3896,
#   5],
#  [15,
#   41,
#   8,
#   2894,
#   1184,
#   296,
#   311,
#   109,
#   63,
#   408,
#   8,
#   542,
#   5464,
#   17,
#   1386,
#   36,
#   148,
#   138,
#   311,
#   2090,
#   311,
#   148,
#   41,
#   436,
#   4295,
#   38,
#   1,
#   18,
#   209,
#   9064,
#   4295,
#   80,
#   38,
#   206],
#  [74, 231, 385, 47, 167, 463, 137, 2, 6, 27, 128, 21, 225, 1360, 1, 37],
#  [1,
#   204,
#   2,
#   7,
#   122,
#   1,
#   8,
#   412,
#   143,
#   134,
#   9065,
#   7,
#   226,
#   9066,
#   1981,
#   17,
#   143,
#   134,
#   993],
#  [7,
#   131,
#   402,
#   37,
#   19,
#   94,
#   119,
#   220,
#   44,
#   4791,
#   160,
#   126,
#   255,
#   7,
#   133,
#   109,
#   9067,
#   38],
#  [7,
#   718,
#   487,
#   5,
#   1448,
#   2015,
#   1448,
#   552,
#   1448,
#   703,
#   18,
#   258,
#   4,
#   12,
#   44,
#   1,
#   4792,
#   1473,
#   2023,
#   5465,
#   2023,
#   9068,
#   5466,
#   9069,
#   4296,
#   7,
#   1119,
#   1429,
#   2137,
#   122,
#   5465,
#   5466,
#   4296,
#   1,
#   447,
#   585,
#   1,
#   10,
#   5465,
#   5466,
#   4296,
#   1429,
#   7,
#   352],
#  [11,
#   3572,
#   317,
#   712,
#   402,
#   1252,
#   40,
#   130,
#   192,
#   1479,
#   5,
#   328,
#   17,
#   8,
#   317,
#   507,
#   331,
#   59,
#   9070,
#   271,
#   712,
#   2108,
#   37,
#   154,
#   35,
#   454,
#   58,
#   909,
#   1602,
#   49,
#   58,
#   387,
#   292,
#   104,
#   3867,
#   1602,
#   310,
#   35,
#   317,
#   256,
#   317,
#   365],
#  [712,
#   40,
#   3098,
#   284,
#   39,
#   74,
#   317,
#   11,
#   281,
#   168,
#   621,
#   305,
#   138,
#   317,
#   2912,
#   89,
#   1602,
#   338,
#   712,
#   17,
#   104,
#   1602,
#   2,
#   317,
#   1982,
#   569,
#   115,
#   893,
#   1713,
#   28,
#   629],
#  [71,
#   1602,
#   1,
#   39,
#   3587,
#   245,
#   51,
#   317,
#   4,
#   3897,
#   317,
#   307,
#   465,
#   1366,
#   39,
#   298,
#   245,
#   51,
#   317,
#   4297,
#   59,
#   16,
#   5,
#   444,
#   192,
#   9,
#   115,
#   39,
#   298,
#   317,
#   95,
#   59,
#   9,
#   39,
#   276,
#   317,
#   31,
#   1602,
#   113,
#   9071,
#   26,
#   1,
#   133,
#   128,
#   19,
#   45,
#   38,
#   9072,
#   9073,
#   303,
#   33,
#   12,
#   21,
#   255,
#   19,
#   360,
#   33,
#   387,
#   192,
#   245,
#   51,
#   298,
#   317,
#   1,
#   133,
#   81],
#  [2,
#   638,
#   4298,
#   9074,
#   74,
#   35,
#   77,
#   3,
#   146,
#   292,
#   304,
#   20,
#   20,
#   6,
#   393,
#   191,
#   29,
#   96,
#   509,
#   304,
#   1,
#   96,
#   4734,
#   182,
#   77,
#   54,
#   105,
#   102,
#   51,
#   106,
#   304,
#   1126,
#   325,
#   247,
#   304,
#   516,
#   658,
#   962,
#   522,
#   638,
#   459,
#   9,
#   56,
#   1,
#   96,
#   1,
#   40,
#   94,
#   220,
#   247,
#   182,
#   35,
#   361],
#  [304,
#   1,
#   4,
#   393,
#   6602,
#   96,
#   54,
#   192,
#   3337,
#   1,
#   525,
#   79,
#   108,
#   100,
#   322,
#   51,
#   247,
#   9,
#   1382,
#   4,
#   1,
#   4],
#  [691,
#   9075,
#   1165,
#   1,
#   304,
#   17,
#   47,
#   6603,
#   1,
#   161,
#   604,
#   108,
#   17,
#   6604,
#   5467,
#   102,
#   1015,
#   31,
#   6605,
#   6602,
#   393,
#   304],
#  [1499,
#   2,
#   193,
#   2636,
#   2015,
#   1,
#   598,
#   1666,
#   6604,
#   2015,
#   9,
#   1,
#   4,
#   67,
#   60,
#   9076,
#   79],
#  [6, 7, 1, 30, 1, 54, 56, 626],
#  [130,
#   355,
#   4299,
#   330,
#   293,
#   495,
#   5468,
#   139,
#   44,
#   2650,
#   2106,
#   742,
#   25,
#   6606,
#   4793,
#   168,
#   329,
#   29,
#   278,
#   158,
#   880,
#   821,
#   6607,
#   5468,
#   6,
#   374,
#   132,
#   2793,
#   2015,
#   3,
#   9077,
#   9078,
#   2032,
#   3,
#   1306,
#   2940,
#   41,
#   1486,
#   1414,
#   2143,
#   3,
#   29,
#   790,
#   150,
#   1165,
#   379,
#   4300,
#   438,
#   659,
#   440,
#   790,
#   987,
#   5468],
#  [6608,
#   304,
#   9079,
#   1027,
#   2,
#   1027,
#   20,
#   122,
#   168,
#   106,
#   6608,
#   304,
#   158,
#   4,
#   12,
#   495,
#   39,
#   33,
#   95,
#   9080,
#   969,
#   304,
#   304],
#  [43,
#   1,
#   54,
#   2620,
#   391,
#   744,
#   225,
#   9081,
#   81,
#   459,
#   341,
#   844,
#   1,
#   4,
#   1656,
#   723,
#   282,
#   1458,
#   1,
#   20,
#   481,
#   91,
#   205,
#   9082],
#  [78,
#   319,
#   56,
#   6,
#   629,
#   258,
#   10,
#   38,
#   2269,
#   48,
#   1018,
#   229,
#   1530,
#   1488,
#   47,
#   2552,
#   920,
#   68,
#   1704,
#   43,
#   4,
#   44,
#   1,
#   260,
#   6609,
#   28,
#   9083,
#   397,
#   9084,
#   624,
#   56,
#   2,
#   397,
#   28,
#   43,
#   6610,
#   6611,
#   4794,
#   16,
#   11,
#   27,
#   212,
#   5469,
#   103,
#   340,
#   81,
#   43,
#   397,
#   226,
#   591,
#   1,
#   37,
#   205,
#   10,
#   43,
#   434,
#   59,
#   557,
#   83,
#   196],
#  [8, 1346, 56, 2, 4, 36, 1, 1236, 133, 81, 133, 920],
#  [1,
#   139,
#   568,
#   100,
#   499,
#   2,
#   7,
#   1,
#   25,
#   263,
#   7,
#   22,
#   312,
#   499,
#   1441,
#   1732,
#   11,
#   56,
#   44,
#   568,
#   100,
#   1039,
#   10,
#   3770,
#   499,
#   7,
#   1,
#   25,
#   263],
#  [393,
#   304,
#   4298,
#   24,
#   30,
#   206,
#   230,
#   38,
#   270,
#   120,
#   36,
#   414,
#   304,
#   24,
#   292,
#   28,
#   499,
#   9085,
#   2661,
#   138,
#   269,
#   102,
#   4298,
#   265,
#   313,
#   7,
#   206,
#   13,
#   32,
#   3,
#   7,
#   234,
#   472],
#  [895,
#   126,
#   978,
#   195,
#   2,
#   3898,
#   64,
#   2,
#   8,
#   597,
#   31,
#   17,
#   2,
#   195,
#   298,
#   14,
#   40,
#   1669,
#   11,
#   566,
#   14,
#   231,
#   197,
#   487,
#   63,
#   168,
#   895,
#   93,
#   2,
#   298,
#   354,
#   779,
#   14,
#   1074,
#   978,
#   4],
#  [2, 195, 95, 20, 132, 79, 46, 298, 1398, 189, 9086, 4, 36, 2, 3, 7],
#  [83,
#   514,
#   39,
#   318,
#   5470,
#   861,
#   197,
#   2355,
#   13,
#   139,
#   3338,
#   78,
#   144,
#   8,
#   908,
#   861,
#   957,
#   557,
#   3296,
#   950,
#   470,
#   7],
#  [2, 2158, 39, 41, 4, 26, 12, 175, 58, 1, 231, 61, 9087, 3],
#  [895,
#   3,
#   2,
#   320,
#   239,
#   1926,
#   1132,
#   115,
#   1520,
#   1,
#   761,
#   296,
#   908,
#   416,
#   197,
#   151,
#   1739,
#   2355,
#   956,
#   440,
#   151,
#   175,
#   175],
#  [26,
#   11,
#   416,
#   895,
#   58,
#   2356,
#   1,
#   174,
#   2,
#   58,
#   85,
#   197,
#   46,
#   637,
#   38,
#   163,
#   4795,
#   900,
#   227,
#   197,
#   26,
#   9088,
#   413,
#   912,
#   2,
#   197,
#   74,
#   41,
#   1422,
#   85,
#   416,
#   188],
#  ...]

# %%
===============================================

# %%
from keras.preprocessing.sequence import pad_sequences
max_length = 200 # fix the length of each review 
max_words = len(word_index.keys()) # fix number of words 

training_samples = 8000
validation_samples = 2835
data = pad_sequences(sequences, maxlen=max_length)

#labels = np.asarray(y)
print('Shape of data tensor:', data.shape)
print('Shape of label tensor:', y.shape)

# Split the data into a training set and a validation set
# But first, shuffle the data, since we started from data
# where sample are ordered (all negative first, then all positive).
indices = np.arange(data.shape[0])
np.random.shuffle(indices)
data = data[indices]
labels = y[indices]

x_train = data[:training_samples]
y_train = y[:training_samples]
x_val = data[training_samples: training_samples + validation_samples]
y_val = y[training_samples: training_samples + validation_samples]
print('Shape of training data: ', x_train.shape)
print('Shape of validation data: ', x_val.shape)
# Out:
# Shape of data tensor: (10835, 200)
# Shape of label tensor: (10835,)
# Shape of training data:  (8000, 200)
# Shape of validation data:  (2835, 200)

# %%
x_train
# Out:
# array([[   0,    0,    0, ..., 1272,    4,   12],
#        [   0,    0,    0, ..., 1415,  136,   68],
#        [   0,    0,    0, ...,   35,    2,  170],
#        ...,
#        [   0,    0,    0, ...,    3,   87,   19],
#        [   0,    0,    0, ..., 2595, 5089, 2186],
#        [   0,    0,    0, ..., 5568,  965, 1061]], dtype=int32)

# %%
embedding_dim = 100

embedding_matrix = np.zeros((max_words+1, embedding_dim))
for word , i in word_index.items():
    embedding_vector = word2vec.wv[word]
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# The Embedding layer is best understood as a dictionary mapping integer indices (which stand for specific words) to dense vectors. It takes as input integers, it looks up these integers into an internal dictionary, and it returns the associated vectors. It's effectively a dictionary lookup.
#
# The Embedding layer takes as input a 2D tensor of integers, of shape (samples, sequence_length), where each entry is a sequence of integers. It can embed sequences of variable lengths, so for instance we could feed into our embedding layer above batches that could have shapes (32, 10) (batch of 32 sequences of length 10) or (64, 15) (batch of 64 sequences of length 15). All sequences in a batch must have the same length, though (since we need to pack them into a single tensor), so sequences that are shorter than others should be padded with zeros, and sequences that are longer should be truncated.
#
# This layer returns a 3D floating point tensor, of shape (samples, sequence_length, embedding_dimensionality). Such a 3D tensor can then be processed by a RNN layer or a 1D convolution layer
#
# When you instantiate an Embedding layer, its weights (its internal dictionary of token vectors) are initially random, just like with any other layer. During training, these word vectors will be gradually adjusted via backpropagation, structuring the space into something that the downstream model can exploit. Once fully trained, your embedding space will show a lot of structure -- a kind of structure specialized for the specific problem you were training your model for.

# %%
embedding_matrix.shape
# Out:
# (16457, 100)

# %%
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense


model = Sequential()
model.add(Embedding(max_words+1, embedding_dim, input_length=max_length))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 200, 100)          1645700
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 20000)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                640032
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 2,285,765
# Trainable params: 2,285,765
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.layers[0].set_weights([embedding_matrix])
model.layers[0].trainable = False

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(x_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(x_val, y_val))
# Out:
# Train on 8000 samples, validate on 2835 samples
# Epoch 1/10
# 8000/8000 [==============================] - 1s 139us/step - loss: 0.5571 - acc: 0.7762 - val_loss: 0.5926 - val_acc: 0.7393
# Epoch 2/10
# 8000/8000 [==============================] - 1s 108us/step - loss: 0.4994 - acc: 0.7817 - val_loss: 0.6221 - val_acc: 0.7326
# Epoch 3/10
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.4318 - acc: 0.7990 - val_loss: 0.6703 - val_acc: 0.7280
# Epoch 4/10
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3468 - acc: 0.8361 - val_loss: 0.7513 - val_acc: 0.7086
# Epoch 5/10
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.2534 - acc: 0.8884 - val_loss: 0.9348 - val_acc: 0.6709
# Epoch 6/10
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.1700 - acc: 0.9366 - val_loss: 1.2086 - val_acc: 0.6660
# Epoch 7/10
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.1069 - acc: 0.9663 - val_loss: 1.3529 - val_acc: 0.6494
# Epoch 8/10
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.0615 - acc: 0.9846 - val_loss: 1.5991 - val_acc: 0.6254
# Epoch 9/10
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.0360 - acc: 0.9931 - val_loss: 1.7739 - val_acc: 0.6392
# Epoch 10/10
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.0210 - acc: 0.9957 - val_loss: 2.0289 - val_acc: 0.6554

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# The model quickly starts overfitting, unsurprisingly given the small number of training samples. Validation accuracy has high variance for the same reason, but seems to reach high 50s.
